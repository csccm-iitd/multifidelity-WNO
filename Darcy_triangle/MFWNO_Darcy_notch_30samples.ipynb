# %% [markdown]
# # It trains MFWNO on MF Darcy data (2D time-independent problem)
# ### HF data size = 30

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
torch.cuda.empty_cache()
import matplotlib.pyplot as plt
from utils import *

from timeit import default_timer
from pytorch_wavelets import DWT, IDWT # (or import DWT, IDWT)
from pytorch_wavelets import DTCWTForward, DTCWTInverse

# %%
torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# # WNO

# %%
class WaveConv2dCwt(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet1, wavelet2):
        super(WaveConv2dCwt, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        # !! It is computationally expensive than the discrete "WaveConv2d" !!
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet_level1 = wavelet1
        self.wavelet_level2 = wavelet2        
        dummy_data = torch.randn( 1,1,*size ) 
        dwt_ = DTCWTForward(J=self.level, biort=self.wavelet_level1,
                            qshift=self.wavelet_level2)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        self.modes21 = mode_coef[-1].shape[-3]
        self.modes22 = mode_coef[-1].shape[-2]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights0 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights15r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights15c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """        
        # Compute dual tree continuous Wavelet coefficients 
        cwt = DTCWTForward(J=self.level, biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x_ft, x_coeff = cwt(x)
        
        out_ft = torch.zeros_like(x_ft, device= x.device)
        out_coeff = [torch.zeros_like(coeffs, device= x.device) for coeffs in x_coeff]
        
        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights0)
        # Multiply the final detailed wavelet coefficients        
        out_coeff[-1][:,:,0,:,:,0] = self.mul2d(x_coeff[-1][:,:,0,:,:,0].clone(), self.weights15r)
        out_coeff[-1][:,:,0,:,:,1] = self.mul2d(x_coeff[-1][:,:,0,:,:,1].clone(), self.weights15c)
        out_coeff[-1][:,:,1,:,:,0] = self.mul2d(x_coeff[-1][:,:,1,:,:,0].clone(), self.weights45r)
        out_coeff[-1][:,:,1,:,:,1] = self.mul2d(x_coeff[-1][:,:,1,:,:,1].clone(), self.weights45c)
        out_coeff[-1][:,:,2,:,:,0] = self.mul2d(x_coeff[-1][:,:,2,:,:,0].clone(), self.weights75r)
        out_coeff[-1][:,:,2,:,:,1] = self.mul2d(x_coeff[-1][:,:,2,:,:,1].clone(), self.weights75c)
        out_coeff[-1][:,:,3,:,:,0] = self.mul2d(x_coeff[-1][:,:,3,:,:,0].clone(), self.weights105r)
        out_coeff[-1][:,:,3,:,:,1] = self.mul2d(x_coeff[-1][:,:,3,:,:,1].clone(), self.weights105c)
        out_coeff[-1][:,:,4,:,:,0] = self.mul2d(x_coeff[-1][:,:,4,:,:,0].clone(), self.weights135r)
        out_coeff[-1][:,:,4,:,:,1] = self.mul2d(x_coeff[-1][:,:,4,:,:,1].clone(), self.weights135c)
        out_coeff[-1][:,:,5,:,:,0] = self.mul2d(x_coeff[-1][:,:,5,:,:,0].clone(), self.weights165r)
        out_coeff[-1][:,:,5,:,:,1] = self.mul2d(x_coeff[-1][:,:,5,:,:,1].clone(), self.weights165c)
        
        # Return to physical space        
        icwt = DTCWTInverse(biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x = icwt((out_ft, out_coeff))
        return x

# %%
class WNO2d_mf(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d_mf, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet1 = wavelet[0]
        self.wavelet2 = wavelet[1]
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv1 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv2 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv3 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %% [markdown]
# # Training and Data

# %%
ntrain = 30
ntest = 40
epochs = 500
last_m = 600
batch_size = 5

n_total = ntrain + ntest
learning_rate = 0.001

step_size = 50
gamma = 0.75

wavelet = ['near_sym_a', 'qshift_a']  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 4

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# %%
""" Read data """
PATH = 'data/Darcy_Triangular_FNO_multifid_hmax018_hmin016.mat'
reader = MatReader(PATH)

x_train = np.array(reader.read_field('boundCoeff')[:,::r,::r][:,:s,:s])
y_train = np.array(reader.read_field('sol')[:,::r,::r][:,:s,:s])
y_train_l = np.array(reader.read_field('lressol')[:,::r,::r][:,:s,:s])
x_or_h = x_train[last_m-n_total:last_m].reshape((n_total,s,s,1))
y_or_h = y_train[last_m-n_total:last_m]
y_or_l = y_train_l[last_m-n_total:last_m].reshape((n_total,s,s,1))

# %%
y_or_l.shape

# %%
x_mf = np.concatenate((x_or_h,y_or_l),axis=-1)
y_mf = y_or_h - y_or_l.reshape((n_total,s,s))

x_mf = torch.tensor( x_mf, dtype=torch.float ) 
y_mf = torch.tensor( y_mf, dtype=torch.float ) 
    
generator = torch.Generator().manual_seed(453)
dataset = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_mf, y_mf),
                                    [ntrain, ntest], generator=generator)
train_dataset_mf, test_dataset_mf = dataset[0], dataset[1]

# %%
# Split the training and testing datasets

x_train_mf, y_train_mf = train_dataset_mf[:][0], train_dataset_mf[:][1]
x_test_mf, y_test_mf = test_dataset_mf[:][0], test_dataset_mf[:][1]

# %%
x_test_mf.shape

# %%
x_normalizer_mf = UnitGaussianNormalizer(x_train_mf)
x_train_mf = x_normalizer_mf.encode(x_train_mf)
x_test_mf = x_normalizer_mf.encode(x_test_mf)

y_normalizer = UnitGaussianNormalizer(y_train_mf)
y_train_mf = y_normalizer.encode(y_train_mf)

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                             batch_size=batch_size, shuffle=False)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %% [markdown]
# # MF Model

# %%
# %%
""" The MD-WNO model definition """
model_mf = WNO2d_mf(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer.to(device)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        y = y_normalizer.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.to(device), y.to(device)

            out = model_mf(x).reshape(x.shape[0], s, s)
            out = y_normalizer.decode(out)

            test_l2 += myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()

    train_mse /= len(train_loader_mf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-224, Time-1.2612, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-0.0680
# Epoch-225, Time-1.3002, Train-MSE-0.0000, Train-L2-0.0430, Test-L2-0.0667
# Epoch-226, Time-1.2842, Train-MSE-0.0000, Train-L2-0.0426, Test-L2-0.0651
# Epoch-227, Time-1.2746, Train-MSE-0.0000, Train-L2-0.0406, Test-L2-0.0650
# Epoch-228, Time-1.2850, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-0.0683
# Epoch-229, Time-1.2986, Train-MSE-0.0000, Train-L2-0.0432, Test-L2-0.0682
# Epoch-230, Time-1.3503, Train-MSE-0.0000, Train-L2-0.0431, Test-L2-0.0643
# Epoch-231, Time-1.2939, Train-MSE-0.0000, Train-L2-0.0414, Test-L2-0.0652
# Epoch-232, Time-1.2632, Train-MSE-0.0000, Train-L2-0.0407, Test-L2-0.0674
# Epoch-233, Time-1.2380, Train-MSE-0.0000, Train-L2-0.0427, Test-L2-0.0667
# Epoch-234, Time-1.2168, Train-MSE-0.0000, Train-L2-0.0424, Test-L2-0.0648
# Epoch-235, Time-1.2379, Train-MSE-0.0000, Train-L2-0.0403, Test-L2-0.0640
# Epoch-236, Time-1.3211, Train-MSE-0.0000, Train-L2-0.0405, Test-L2-0.0676
# Epoch-237, Time-1.2554, Train-MSE-0.0000, Train-L2-0.0426, Test-L2-0.0678
# Epoch-238, Time-1.2370, Train-MSE-0.0000, Train-L2-0.0427, Test-L2-0.0642
# Epoch-239, Time-1.2335, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-0.0645
# Epoch-240, Time-1.2512, Train-MSE-0.0000, Train-L2-0.0400, Test-L2-0.0663
# Epoch-241, Time-1.2473, Train-MSE-0.0000, Train-L2-0.0419, Test-L2-0.0663
# Epoch-242, Time-1.3089, Train-MSE-0.0000, Train-L2-0.0419, Test-L2-0.0640
# Epoch-243, Time-1.3225, Train-MSE-0.0000, Train-L2-0.0399, Test-L2-0.0636
# Epoch-244, Time-1.3373, Train-MSE-0.0000, Train-L2-0.0396, Test-L2-0.0664
# Epoch-245, Time-1.2567, Train-MSE-0.0000, Train-L2-0.0416, Test-L2-0.0665
# Epoch-246, Time-1.2412, Train-MSE-0.0000, Train-L2-0.0418, Test-L2-0.0636
# Epoch-247, Time-1.2272, Train-MSE-0.0000, Train-L2-0.0403, Test-L2-0.0637
# Epoch-248, Time-1.1666, Train-MSE-0.0000, Train-L2-0.0398, Test-L2-0.0661
# Epoch-249, Time-1.2428, Train-MSE-0.0000, Train-L2-0.0411, Test-L2-0.0654
# Epoch-250, Time-1.2865, Train-MSE-0.0000, Train-L2-0.0398, Test-L2-0.0630
# Epoch-251, Time-1.2191, Train-MSE-0.0000, Train-L2-0.0371, Test-L2-0.0611
# Epoch-252, Time-1.2127, Train-MSE-0.0000, Train-L2-0.0363, Test-L2-0.0630
# Epoch-253, Time-1.2067, Train-MSE-0.0000, Train-L2-0.0367, Test-L2-0.0625
# Epoch-254, Time-1.2095, Train-MSE-0.0000, Train-L2-0.0367, Test-L2-0.0613
# Epoch-255, Time-1.2199, Train-MSE-0.0000, Train-L2-0.0359, Test-L2-0.0612
# Epoch-256, Time-1.1866, Train-MSE-0.0000, Train-L2-0.0346, Test-L2-0.0601
# Epoch-257, Time-1.2146, Train-MSE-0.0000, Train-L2-0.0350, Test-L2-0.0621
# Epoch-258, Time-1.3114, Train-MSE-0.0000, Train-L2-0.0361, Test-L2-0.0617
# Epoch-259, Time-1.3138, Train-MSE-0.0000, Train-L2-0.0358, Test-L2-0.0605
# Epoch-260, Time-1.2863, Train-MSE-0.0000, Train-L2-0.0350, Test-L2-0.0601
# Epoch-261, Time-1.2809, Train-MSE-0.0000, Train-L2-0.0341, Test-L2-0.0606
# Epoch-262, Time-1.3052, Train-MSE-0.0000, Train-L2-0.0352, Test-L2-0.0616
# Epoch-263, Time-1.2272, Train-MSE-0.0000, Train-L2-0.0357, Test-L2-0.0609
# Epoch-264, Time-1.2687, Train-MSE-0.0000, Train-L2-0.0348, Test-L2-0.0593
# Epoch-265, Time-1.2545, Train-MSE-0.0000, Train-L2-0.0340, Test-L2-0.0603
# Epoch-266, Time-1.3072, Train-MSE-0.0000, Train-L2-0.0343, Test-L2-0.0613
# Epoch-267, Time-1.2840, Train-MSE-0.0000, Train-L2-0.0354, Test-L2-0.0607
# Epoch-268, Time-1.3564, Train-MSE-0.0000, Train-L2-0.0351, Test-L2-0.0598
# Epoch-269, Time-1.3162, Train-MSE-0.0000, Train-L2-0.0339, Test-L2-0.0590
# Epoch-270, Time-1.2305, Train-MSE-0.0000, Train-L2-0.0339, Test-L2-0.0612
# Epoch-271, Time-1.2804, Train-MSE-0.0000, Train-L2-0.0352, Test-L2-0.0611
# Epoch-272, Time-1.2711, Train-MSE-0.0000, Train-L2-0.0352, Test-L2-0.0596
# Epoch-273, Time-1.2811, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-0.0594
# Epoch-274, Time-1.2785, Train-MSE-0.0000, Train-L2-0.0337, Test-L2-0.0603
# Epoch-275, Time-1.2367, Train-MSE-0.0000, Train-L2-0.0349, Test-L2-0.0609
# Epoch-276, Time-1.2545, Train-MSE-0.0000, Train-L2-0.0351, Test-L2-0.0598
# Epoch-277, Time-1.2567, Train-MSE-0.0000, Train-L2-0.0341, Test-L2-0.0587
# Epoch-278, Time-1.2532, Train-MSE-0.0000, Train-L2-0.0336, Test-L2-0.0604
# Epoch-279, Time-1.2455, Train-MSE-0.0000, Train-L2-0.0346, Test-L2-0.0608
# Epoch-280, Time-1.2532, Train-MSE-0.0000, Train-L2-0.0352, Test-L2-0.0598
# Epoch-281, Time-1.1891, Train-MSE-0.0000, Train-L2-0.0345, Test-L2-0.0587
# Epoch-282, Time-1.2257, Train-MSE-0.0000, Train-L2-0.0334, Test-L2-0.0597
# Epoch-283, Time-1.2386, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-0.0608
# Epoch-284, Time-1.3002, Train-MSE-0.0000, Train-L2-0.0352, Test-L2-0.0600
# Epoch-285, Time-1.2275, Train-MSE-0.0000, Train-L2-0.0346, Test-L2-0.0584
# Epoch-286, Time-1.2277, Train-MSE-0.0000, Train-L2-0.0335, Test-L2-0.0593
# Epoch-287, Time-1.2476, Train-MSE-0.0000, Train-L2-0.0339, Test-L2-0.0608
# Epoch-288, Time-1.3348, Train-MSE-0.0000, Train-L2-0.0350, Test-L2-0.0600
# Epoch-289, Time-1.3135, Train-MSE-0.0000, Train-L2-0.0348, Test-L2-0.0586
# Epoch-290, Time-1.2850, Train-MSE-0.0000, Train-L2-0.0333, Test-L2-0.0583
# Epoch-291, Time-1.2031, Train-MSE-0.0000, Train-L2-0.0332, Test-L2-0.0601
# Epoch-292, Time-1.2743, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-0.0602
# Epoch-293, Time-1.2675, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-0.0588
# Epoch-294, Time-1.3443, Train-MSE-0.0000, Train-L2-0.0336, Test-L2-0.0590
# Epoch-295, Time-1.2502, Train-MSE-0.0000, Train-L2-0.0334, Test-L2-0.0597
# Epoch-296, Time-1.1953, Train-MSE-0.0000, Train-L2-0.0341, Test-L2-0.0603
# Epoch-297, Time-1.1995, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-0.0592
# Epoch-298, Time-1.2126, Train-MSE-0.0000, Train-L2-0.0333, Test-L2-0.0587
# Epoch-299, Time-1.2299, Train-MSE-0.0000, Train-L2-0.0331, Test-L2-0.0598
# Epoch-300, Time-1.2171, Train-MSE-0.0000, Train-L2-0.0327, Test-L2-0.0583
# Epoch-301, Time-1.2525, Train-MSE-0.0000, Train-L2-0.0316, Test-L2-0.0572
# Epoch-302, Time-1.2739, Train-MSE-0.0000, Train-L2-0.0306, Test-L2-0.0569
# Epoch-303, Time-1.2360, Train-MSE-0.0000, Train-L2-0.0297, Test-L2-0.0564
# Epoch-304, Time-1.2018, Train-MSE-0.0000, Train-L2-0.0298, Test-L2-0.0571
# Epoch-305, Time-1.2123, Train-MSE-0.0000, Train-L2-0.0302, Test-L2-0.0570
# Epoch-306, Time-1.2185, Train-MSE-0.0000, Train-L2-0.0299, Test-L2-0.0563
# Epoch-307, Time-1.1883, Train-MSE-0.0000, Train-L2-0.0295, Test-L2-0.0563
# Epoch-308, Time-1.1909, Train-MSE-0.0000, Train-L2-0.0290, Test-L2-0.0562
# Epoch-309, Time-1.1927, Train-MSE-0.0000, Train-L2-0.0293, Test-L2-0.0568
# Epoch-310, Time-1.2297, Train-MSE-0.0000, Train-L2-0.0297, Test-L2-0.0563
# Epoch-311, Time-1.4679, Train-MSE-0.0000, Train-L2-0.0293, Test-L2-0.0557
# Epoch-312, Time-1.2372, Train-MSE-0.0000, Train-L2-0.0289, Test-L2-0.0559
# Epoch-313, Time-1.2248, Train-MSE-0.0000, Train-L2-0.0288, Test-L2-0.0562
# Epoch-314, Time-1.2248, Train-MSE-0.0000, Train-L2-0.0292, Test-L2-0.0564
# Epoch-315, Time-1.1729, Train-MSE-0.0000, Train-L2-0.0294, Test-L2-0.0558
# Epoch-316, Time-1.2174, Train-MSE-0.0000, Train-L2-0.0288, Test-L2-0.0553
# Epoch-317, Time-1.2425, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0560
# Epoch-318, Time-1.2264, Train-MSE-0.0000, Train-L2-0.0289, Test-L2-0.0562
# Epoch-319, Time-1.2262, Train-MSE-0.0000, Train-L2-0.0292, Test-L2-0.0560
# Epoch-320, Time-1.2547, Train-MSE-0.0000, Train-L2-0.0291, Test-L2-0.0554
# Epoch-321, Time-1.3034, Train-MSE-0.0000, Train-L2-0.0284, Test-L2-0.0553
# Epoch-322, Time-1.2735, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0563
# Epoch-323, Time-1.2635, Train-MSE-0.0000, Train-L2-0.0292, Test-L2-0.0559
# Epoch-324, Time-1.2261, Train-MSE-0.0000, Train-L2-0.0291, Test-L2-0.0554
# Epoch-325, Time-1.2471, Train-MSE-0.0000, Train-L2-0.0286, Test-L2-0.0552
# Epoch-326, Time-1.2741, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.0555
# Epoch-327, Time-1.2449, Train-MSE-0.0000, Train-L2-0.0287, Test-L2-0.0561
# Epoch-328, Time-1.2033, Train-MSE-0.0000, Train-L2-0.0290, Test-L2-0.0552
# Epoch-329, Time-1.2158, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0550
# Epoch-330, Time-1.3533, Train-MSE-0.0000, Train-L2-0.0281, Test-L2-0.0555
# Epoch-331, Time-1.2848, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0556
# Epoch-332, Time-1.3038, Train-MSE-0.0000, Train-L2-0.0288, Test-L2-0.0555
# Epoch-333, Time-1.2364, Train-MSE-0.0000, Train-L2-0.0286, Test-L2-0.0548
# Epoch-334, Time-1.2550, Train-MSE-0.0000, Train-L2-0.0282, Test-L2-0.0551
# Epoch-335, Time-1.3029, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.0557
# Epoch-336, Time-1.3177, Train-MSE-0.0000, Train-L2-0.0287, Test-L2-0.0552
# Epoch-337, Time-1.3064, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0550
# Epoch-338, Time-1.2680, Train-MSE-0.0000, Train-L2-0.0282, Test-L2-0.0550
# Epoch-339, Time-1.3159, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.0553
# Epoch-340, Time-1.3211, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0553
# Epoch-341, Time-1.3006, Train-MSE-0.0000, Train-L2-0.0284, Test-L2-0.0546
# Epoch-342, Time-1.2858, Train-MSE-0.0000, Train-L2-0.0279, Test-L2-0.0548
# Epoch-343, Time-1.2695, Train-MSE-0.0000, Train-L2-0.0280, Test-L2-0.0554
# Epoch-344, Time-1.2509, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0553
# Epoch-345, Time-1.2795, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0549
# Epoch-346, Time-1.2380, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.0548
# Epoch-347, Time-1.1865, Train-MSE-0.0000, Train-L2-0.0282, Test-L2-0.0548
# Epoch-348, Time-1.1830, Train-MSE-0.0000, Train-L2-0.0285, Test-L2-0.0554
# Epoch-349, Time-1.2338, Train-MSE-0.0000, Train-L2-0.0287, Test-L2-0.0548
# Epoch-350, Time-1.2383, Train-MSE-0.0000, Train-L2-0.0279, Test-L2-0.0542
# Epoch-351, Time-1.2118, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.0542
# Epoch-352, Time-1.2366, Train-MSE-0.0000, Train-L2-0.0263, Test-L2-0.0535
# Epoch-353, Time-1.3259, Train-MSE-0.0000, Train-L2-0.0259, Test-L2-0.0535
# Epoch-354, Time-1.2158, Train-MSE-0.0000, Train-L2-0.0256, Test-L2-0.0533
# Epoch-355, Time-1.2141, Train-MSE-0.0000, Train-L2-0.0254, Test-L2-0.0533
# Epoch-356, Time-1.3232, Train-MSE-0.0000, Train-L2-0.0253, Test-L2-0.0532
# Epoch-357, Time-1.3361, Train-MSE-0.0000, Train-L2-0.0254, Test-L2-0.0533
# Epoch-358, Time-1.2000, Train-MSE-0.0000, Train-L2-0.0253, Test-L2-0.0531
# Epoch-359, Time-1.1984, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0530
# Epoch-360, Time-1.2328, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0530
# Epoch-361, Time-1.1754, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0531
# Epoch-362, Time-1.2206, Train-MSE-0.0000, Train-L2-0.0253, Test-L2-0.0531
# Epoch-363, Time-1.3857, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0529
# Epoch-364, Time-1.2302, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0529
# Epoch-365, Time-1.2486, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0528
# Epoch-366, Time-1.1932, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0530
# Epoch-367, Time-1.1962, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0530
# Epoch-368, Time-1.3100, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0527
# Epoch-369, Time-1.2968, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0528
# Epoch-370, Time-1.2909, Train-MSE-0.0000, Train-L2-0.0250, Test-L2-0.0526
# Epoch-371, Time-1.2948, Train-MSE-0.0000, Train-L2-0.0250, Test-L2-0.0529
# Epoch-372, Time-1.2978, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0526
# Epoch-373, Time-1.3469, Train-MSE-0.0000, Train-L2-0.0250, Test-L2-0.0526
# Epoch-374, Time-1.2557, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.0527
# Epoch-375, Time-1.1924, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.0524
# Epoch-376, Time-1.2096, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.0527
# Epoch-377, Time-1.2340, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.0523
# Epoch-378, Time-1.2622, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-0.0525
# Epoch-379, Time-1.2405, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-0.0526
# Epoch-380, Time-1.2419, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.0523
# Epoch-381, Time-1.2238, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-0.0525
# Epoch-382, Time-1.1871, Train-MSE-0.0000, Train-L2-0.0246, Test-L2-0.0521
# Epoch-383, Time-1.2320, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.0521
# Epoch-384, Time-1.2791, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.0524
# Epoch-385, Time-1.3264, Train-MSE-0.0000, Train-L2-0.0245, Test-L2-0.0520
# Epoch-386, Time-1.2995, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.0523
# Epoch-387, Time-1.2465, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.0520
# Epoch-388, Time-1.2624, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.0519
# Epoch-389, Time-1.3608, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0522
# Epoch-390, Time-1.2585, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0518
# Epoch-391, Time-1.2749, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0521
# Epoch-392, Time-1.2656, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.0520
# Epoch-393, Time-1.2561, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.0518
# Epoch-394, Time-1.2235, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0519
# Epoch-395, Time-1.3063, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0518
# Epoch-396, Time-1.3093, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0518
# Epoch-397, Time-1.3271, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0518
# Epoch-398, Time-1.2975, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0520
# Epoch-399, Time-1.3140, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.0518
# Epoch-400, Time-1.2990, Train-MSE-0.0000, Train-L2-0.0241, Test-L2-0.0518
# Epoch-401, Time-1.2098, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.0514
# Epoch-402, Time-1.2560, Train-MSE-0.0000, Train-L2-0.0233, Test-L2-0.0513
# Epoch-403, Time-1.2113, Train-MSE-0.0000, Train-L2-0.0231, Test-L2-0.0513
# Epoch-404, Time-1.2663, Train-MSE-0.0000, Train-L2-0.0230, Test-L2-0.0512
# Epoch-405, Time-1.2796, Train-MSE-0.0000, Train-L2-0.0229, Test-L2-0.0512
# Epoch-406, Time-1.2434, Train-MSE-0.0000, Train-L2-0.0228, Test-L2-0.0511
# Epoch-407, Time-1.2639, Train-MSE-0.0000, Train-L2-0.0228, Test-L2-0.0510
# Epoch-408, Time-1.3285, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.0510
# Epoch-409, Time-1.3230, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.0509
# Epoch-410, Time-1.3089, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.0510
# Epoch-411, Time-1.2979, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.0509
# Epoch-412, Time-1.2711, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.0509
# Epoch-413, Time-1.3559, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.0508
# Epoch-414, Time-1.2886, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.0508
# Epoch-415, Time-1.2718, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.0509
# Epoch-416, Time-1.2748, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.0507
# Epoch-417, Time-1.2442, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.0508
# Epoch-418, Time-1.2461, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.0506
# Epoch-419, Time-1.2513, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.0507
# Epoch-420, Time-1.3279, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.0507
# Epoch-421, Time-1.3019, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.0505
# Epoch-422, Time-1.2999, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.0506
# Epoch-423, Time-1.3289, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.0505
# Epoch-424, Time-1.2769, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.0505
# Epoch-425, Time-1.3055, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.0505
# Epoch-426, Time-1.2639, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.0504
# Epoch-427, Time-1.2115, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.0504
# Epoch-428, Time-1.2208, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.0504
# Epoch-429, Time-1.2655, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.0503
# Epoch-430, Time-1.2482, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0504
# Epoch-431, Time-1.2193, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0502
# Epoch-432, Time-1.3239, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0502
# Epoch-433, Time-1.2375, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0503
# Epoch-434, Time-1.2014, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0502
# Epoch-435, Time-1.3080, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0503
# Epoch-436, Time-1.3899, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0502
# Epoch-437, Time-1.3202, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0502
# Epoch-438, Time-1.3384, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0502
# Epoch-439, Time-1.2459, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0502
# Epoch-440, Time-1.2578, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0501
# Epoch-441, Time-1.2026, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0503
# Epoch-442, Time-1.2032, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0500
# Epoch-443, Time-1.2145, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0503
# Epoch-444, Time-1.2458, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0500
# Epoch-445, Time-1.1813, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0501
# Epoch-446, Time-1.1930, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0500
# Epoch-447, Time-1.1916, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0501
# Epoch-448, Time-1.2705, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0500
# Epoch-449, Time-1.2433, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0502
# Epoch-450, Time-1.1562, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0499
# Epoch-451, Time-1.1927, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.0498
# Epoch-452, Time-1.2097, Train-MSE-0.0000, Train-L2-0.0214, Test-L2-0.0498
# Epoch-453, Time-1.3171, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.0496
# Epoch-454, Time-1.2571, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.0498
# Epoch-455, Time-1.2252, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.0496
# Epoch-456, Time-1.2302, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.0497
# Epoch-457, Time-1.2747, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.0496
# Epoch-458, Time-1.2880, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.0496
# Epoch-459, Time-1.2693, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0496
# Epoch-460, Time-1.2664, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0495
# Epoch-461, Time-1.2100, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0496
# Epoch-462, Time-1.2173, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0494
# Epoch-463, Time-1.2213, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0494
# Epoch-464, Time-1.2688, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.0495
# Epoch-465, Time-1.3123, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.0494
# Epoch-466, Time-1.2018, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.0495
# Epoch-467, Time-1.2297, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.0493
# Epoch-468, Time-1.1972, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.0493
# Epoch-469, Time-1.2127, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.0493
# Epoch-470, Time-1.2293, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.0492
# Epoch-471, Time-1.2394, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.0494
# Epoch-472, Time-1.3855, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.0492
# Epoch-473, Time-1.2653, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.0492
# Epoch-474, Time-1.2162, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.0492
# Epoch-475, Time-1.3163, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.0491
# Epoch-476, Time-1.2638, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.0493
# Epoch-477, Time-1.2722, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.0490
# Epoch-478, Time-1.2360, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0491
# Epoch-479, Time-1.3295, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0491
# Epoch-480, Time-1.2436, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0490
# Epoch-481, Time-1.2233, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0492
# Epoch-482, Time-1.2588, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0489
# Epoch-483, Time-1.2331, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0490
# Epoch-484, Time-1.2220, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0490
# Epoch-485, Time-1.3484, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0488
# Epoch-486, Time-1.2817, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.0490
# Epoch-487, Time-1.2526, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.0488
# Epoch-488, Time-1.2608, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.0488
# Epoch-489, Time-1.2703, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0489
# Epoch-490, Time-1.2269, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0487
# Epoch-491, Time-1.2397, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0489
# Epoch-492, Time-1.2617, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0488
# Epoch-493, Time-1.3462, Train-MSE-0.0000, Train-L2-0.0201, Test-L2-0.0487
# Epoch-494, Time-1.3332, Train-MSE-0.0000, Train-L2-0.0201, Test-L2-0.0488
# Epoch-495, Time-1.2954, Train-MSE-0.0000, Train-L2-0.0201, Test-L2-0.0487
# Epoch-496, Time-1.3403, Train-MSE-0.0000, Train-L2-0.0201, Test-L2-0.0487
# Epoch-497, Time-1.3019, Train-MSE-0.0000, Train-L2-0.0200, Test-L2-0.0487
# Epoch-498, Time-1.2532, Train-MSE-0.0000, Train-L2-0.0200, Test-L2-0.0486
# Epoch-499, Time-1.2359, Train-MSE-0.0000, Train-L2-0.0200, Test-L2-0.0487

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_Darcy2D_30')

# %%
# Prediction:
pred_mf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x, y = x.to(device), y.to(device)
        
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_mf.append(out.cpu())
        index += 1

pred_mf = torch.cat(( pred_mf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
# Add the residual operator to LF-dataset 
input_mf = x_normalizer_mf.decode( x_test_mf.cpu() ) 

real_mf = y_test_mf + input_mf[..., 1]
output_mf = pred_mf + input_mf[..., 1]

# %%
print(real_mf.shape, output_mf.shape)

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()
mse_LF = F.mse_loss(real_mf, x_test_mf[..., 1])
mse_residual = F.mse_loss(y_test_mf, pred_mf)

print('MSE-Predicted solution-{:0.4f}, MSE-LF Data-{:0.4f}, MSE-Residual-{:0.4f}'
      .format(mse_pred, mse_LF, mse_residual))

# %%
fig1, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig1.subplots_adjust(hspace=0.35, wspace=0.2)

fig1.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(real_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(real_mf[sample, :, :] - output_mf[sample, :, :]),
                                    cmap='jet', origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %% [markdown]
# # High Fidelity

# %%
class WaveConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv2d, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet       
        dummy_data = torch.randn( 1,1,*size )        
        dwt_ = DWT(J=self.level, mode='symmetric', wave=self.wavelet)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights3 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights4 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet
        dwt = DWT(J=self.level, mode='symmetric', wave=self.wavelet).to(x.device)
        x_ft, x_coeff = dwt(x)

        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft, self.weights1)
        # Multiply the final detailed wavelet coefficients
        x_coeff[-1][:,:,0,:,:] = self.mul2d(x_coeff[-1][:,:,0,:,:].clone(), self.weights2)
        x_coeff[-1][:,:,1,:,:] = self.mul2d(x_coeff[-1][:,:,1,:,:].clone(), self.weights3)
        x_coeff[-1][:,:,2,:,:] = self.mul2d(x_coeff[-1][:,:,2,:,:].clone(), self.weights4)
        
        # Return to physical space        
        idwt = IDWT(mode='symmetric', wave=self.wavelet).to(x.device)
        x = idwt((out_ft, x_coeff))
        return x

# %%
class WNO2d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """
        
        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %%
ntrain = ntrain
ntest = ntest
n_total = ntrain + ntest
batch_size = batch_size
learning_rate = 0.001

wavelet = 'db6'  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 3

epochs = 250
step_size = 50
gamma = 0.75

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# Create the input and output (residual) dataset
x_hf = torch.tensor( x_or_h, dtype=torch.float ) 
y_hf = torch.tensor( y_or_h, dtype=torch.float ) 
    
generator_hf = torch.Generator().manual_seed(453)
dataset_hf = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_hf, y_hf),
                                    [ntrain, ntest], generator=generator)
train_data_hf, test_data_hf = dataset_hf[0], dataset_hf[1]

# Split the training and testing datasets
x_train_hf, y_train_hf = train_data_hf[:][0], train_data_hf[:][1]
x_test_hf, y_test_hf = test_data_hf[:][0], test_data_hf[:][1]

x_normalizer_hf = UnitGaussianNormalizer(x_train_hf)
x_train_hf = x_normalizer_hf.encode(x_train_hf)
x_test_hf = x_normalizer_hf.encode(x_test_hf)

y_normalizer_hf = UnitGaussianNormalizer(y_train_hf)
y_train_hf = y_normalizer_hf.encode(y_train_hf)

# Define the dataloaders
train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                             batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, y_test_hf),
                                            batch_size=batch_size, shuffle=False)

# %%
model = WNO2d(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model))

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer_hf.to(device)
for ep in range(epochs):
    model.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model(x).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        y = y_normalizer_hf.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.to(device), y.to(device)

            out = model(x).reshape(x.shape[0], s, s)
            out = y_normalizer_hf.decode(out)

            test_l2 += myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1)).item()

    train_mse /= len(train_loader_hf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-224, Time-0.7813, Train-MSE-0.0003, Train-L2-0.0242, Test-L2-0.1834
# Epoch-225, Time-0.7433, Train-MSE-0.0004, Train-L2-0.0254, Test-L2-0.1804
# Epoch-226, Time-0.7992, Train-MSE-0.0004, Train-L2-0.0250, Test-L2-0.1795
# Epoch-227, Time-0.8164, Train-MSE-0.0004, Train-L2-0.0257, Test-L2-0.1795
# Epoch-228, Time-0.7583, Train-MSE-0.0003, Train-L2-0.0243, Test-L2-0.1804
# Epoch-229, Time-0.7847, Train-MSE-0.0003, Train-L2-0.0229, Test-L2-0.1806
# Epoch-230, Time-0.7787, Train-MSE-0.0003, Train-L2-0.0239, Test-L2-0.1804
# Epoch-231, Time-0.7874, Train-MSE-0.0003, Train-L2-0.0240, Test-L2-0.1802
# Epoch-232, Time-0.7899, Train-MSE-0.0004, Train-L2-0.0276, Test-L2-0.1826
# Epoch-233, Time-0.7474, Train-MSE-0.0004, Train-L2-0.0278, Test-L2-0.1817
# Epoch-234, Time-0.7505, Train-MSE-0.0004, Train-L2-0.0258, Test-L2-0.1810
# Epoch-235, Time-0.8012, Train-MSE-0.0004, Train-L2-0.0260, Test-L2-0.1832
# Epoch-236, Time-0.8357, Train-MSE-0.0003, Train-L2-0.0238, Test-L2-0.1805
# Epoch-237, Time-0.7737, Train-MSE-0.0003, Train-L2-0.0249, Test-L2-0.1811
# Epoch-238, Time-0.7714, Train-MSE-0.0003, Train-L2-0.0252, Test-L2-0.1793
# Epoch-239, Time-0.8369, Train-MSE-0.0004, Train-L2-0.0265, Test-L2-0.1804
# Epoch-240, Time-0.7934, Train-MSE-0.0004, Train-L2-0.0270, Test-L2-0.1801
# Epoch-241, Time-0.8184, Train-MSE-0.0004, Train-L2-0.0262, Test-L2-0.1825
# Epoch-242, Time-0.8087, Train-MSE-0.0003, Train-L2-0.0249, Test-L2-0.1796
# Epoch-243, Time-0.8229, Train-MSE-0.0003, Train-L2-0.0226, Test-L2-0.1785
# Epoch-244, Time-0.8363, Train-MSE-0.0004, Train-L2-0.0266, Test-L2-0.1798
# Epoch-245, Time-0.8049, Train-MSE-0.0004, Train-L2-0.0282, Test-L2-0.1806
# Epoch-246, Time-0.8069, Train-MSE-0.0004, Train-L2-0.0270, Test-L2-0.1817
# Epoch-247, Time-0.7903, Train-MSE-0.0004, Train-L2-0.0254, Test-L2-0.1794
# Epoch-248, Time-0.7798, Train-MSE-0.0003, Train-L2-0.0230, Test-L2-0.1771
# Epoch-249, Time-0.7871, Train-MSE-0.0003, Train-L2-0.0235, Test-L2-0.1793

# %%
# Save the HF-WNO model

torch.save(model, 'model/HF_WNO_Darcy2D_30')

# %%
# Predict on HF data using HF-WNO
pred_hf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x = x_normalizer_mf.decode(x)
        x = x_normalizer_hf.encode(x)
        
        x, y = x.to(device), y.to(device)

        out = model(x[..., 0:1]).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_hf.append(out.cpu())
        index += 1

pred_hf = torch.cat(( pred_hf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
mse_pred_hf = F.mse_loss(pred_hf, y_test_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
fig2, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig2.subplots_adjust(hspace=0.35, wspace=0.2)

fig2.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(y_test_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(pred_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(y_test_hf[sample, :, :] - pred_hf[sample, :, :]),
                                    cmap='jet',origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %%
fig4, axs = plt.subplots(nrows=2, ncols=5, figsize=(10, 4), facecolor='w', edgecolor='k')
fig4.subplots_adjust(hspace=0.35, wspace=0.2)

fig4.suptitle(f'Predictions Error', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(pred_hf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        index += 1

# %% [markdown]
# # Plotting

# %%
s = 1
xmax = s
ymax = s-8/51
from matplotlib.patches import Rectangle
plt.rcParams["font.family"] = "Serif"
plt.rcParams['font.size'] = 10

figure1 = plt.figure(constrained_layout=False, figsize = (14, 10))
plt.subplots_adjust(hspace=0.25, wspace=0.3)
index = 0
value = 0

plt.subplot(3,4, index+1)
plt.imshow(output_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('MFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
      
      #####        
plt.subplot(3,4, index+2)
plt.imshow(pred_hf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('HFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
        ###
plt.subplot(3,4, index+3)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(input_mf[value,:,:,1], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('LFM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        #####
plt.subplot(3,4, index+4)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(real_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Ground Truth');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        
        ###
plt.subplot(3,4, index+5)
plt.imshow(np.abs(output_mf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))

        ###
plt.subplot(3,4, index+6)
plt.imshow(np.abs(pred_hf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))


        ###
plt.subplot(3,4, index+7)
plt.imshow(np.abs(input_mf[value,:,:,1]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))
