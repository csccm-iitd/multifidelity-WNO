# %% [markdown]
# # It trains MFWNO on MF Darcy data (2D time-independent problem)
# ### HF data size = 50

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
torch.cuda.empty_cache()
import matplotlib.pyplot as plt
from utils import *

from timeit import default_timer
from pytorch_wavelets import DWT, IDWT # (or import DWT, IDWT)
from pytorch_wavelets import DTCWTForward, DTCWTInverse

# %%
torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# # WNO

# %%
class WaveConv2dCwt(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet1, wavelet2):
        super(WaveConv2dCwt, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        # !! It is computationally expensive than the discrete "WaveConv2d" !!
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet_level1 = wavelet1
        self.wavelet_level2 = wavelet2        
        dummy_data = torch.randn( 1,1,*size ) 
        dwt_ = DTCWTForward(J=self.level, biort=self.wavelet_level1,
                            qshift=self.wavelet_level2)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        self.modes21 = mode_coef[-1].shape[-3]
        self.modes22 = mode_coef[-1].shape[-2]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights0 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights15r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights15c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """        
        # Compute dual tree continuous Wavelet coefficients 
        cwt = DTCWTForward(J=self.level, biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x_ft, x_coeff = cwt(x)
        
        out_ft = torch.zeros_like(x_ft, device= x.device)
        out_coeff = [torch.zeros_like(coeffs, device= x.device) for coeffs in x_coeff]
        
        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights0)
        # Multiply the final detailed wavelet coefficients        
        out_coeff[-1][:,:,0,:,:,0] = self.mul2d(x_coeff[-1][:,:,0,:,:,0].clone(), self.weights15r)
        out_coeff[-1][:,:,0,:,:,1] = self.mul2d(x_coeff[-1][:,:,0,:,:,1].clone(), self.weights15c)
        out_coeff[-1][:,:,1,:,:,0] = self.mul2d(x_coeff[-1][:,:,1,:,:,0].clone(), self.weights45r)
        out_coeff[-1][:,:,1,:,:,1] = self.mul2d(x_coeff[-1][:,:,1,:,:,1].clone(), self.weights45c)
        out_coeff[-1][:,:,2,:,:,0] = self.mul2d(x_coeff[-1][:,:,2,:,:,0].clone(), self.weights75r)
        out_coeff[-1][:,:,2,:,:,1] = self.mul2d(x_coeff[-1][:,:,2,:,:,1].clone(), self.weights75c)
        out_coeff[-1][:,:,3,:,:,0] = self.mul2d(x_coeff[-1][:,:,3,:,:,0].clone(), self.weights105r)
        out_coeff[-1][:,:,3,:,:,1] = self.mul2d(x_coeff[-1][:,:,3,:,:,1].clone(), self.weights105c)
        out_coeff[-1][:,:,4,:,:,0] = self.mul2d(x_coeff[-1][:,:,4,:,:,0].clone(), self.weights135r)
        out_coeff[-1][:,:,4,:,:,1] = self.mul2d(x_coeff[-1][:,:,4,:,:,1].clone(), self.weights135c)
        out_coeff[-1][:,:,5,:,:,0] = self.mul2d(x_coeff[-1][:,:,5,:,:,0].clone(), self.weights165r)
        out_coeff[-1][:,:,5,:,:,1] = self.mul2d(x_coeff[-1][:,:,5,:,:,1].clone(), self.weights165c)
        
        # Return to physical space        
        icwt = DTCWTInverse(biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x = icwt((out_ft, out_coeff))
        return x

# %%
class WNO2d_mf(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d_mf, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet1 = wavelet[0]
        self.wavelet2 = wavelet[1]
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv1 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv2 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv3 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %% [markdown]
# # Training and Data

# %%
ntrain = 50
ntest = 40
epochs = 500
last_m = 600
batch_size = 5

n_total = ntrain + ntest
learning_rate = 0.001

step_size = 50
gamma = 0.75

wavelet = ['near_sym_a', 'qshift_a']  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 4

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# %%
""" Read data """
PATH = 'data/Darcy_Triangular_FNO_multifid_hmax018_hmin016.mat'
reader = MatReader(PATH)

x_train = np.array(reader.read_field('boundCoeff')[:,::r,::r][:,:s,:s])
y_train = np.array(reader.read_field('sol')[:,::r,::r][:,:s,:s])
y_train_l = np.array(reader.read_field('lressol')[:,::r,::r][:,:s,:s])
x_or_h = x_train[last_m-n_total:last_m].reshape((n_total,s,s,1))
y_or_h = y_train[last_m-n_total:last_m]
y_or_l = y_train_l[last_m-n_total:last_m].reshape((n_total,s,s,1))

# %%
y_or_l.shape

# %%
x_mf = np.concatenate((x_or_h,y_or_l),axis=-1)
y_mf = y_or_h - y_or_l.reshape((n_total,s,s))

x_mf = torch.tensor( x_mf, dtype=torch.float ) 
y_mf = torch.tensor( y_mf, dtype=torch.float ) 
    
generator = torch.Generator().manual_seed(453)
dataset = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_mf, y_mf),
                                    [ntrain, ntest], generator=generator)
train_dataset_mf, test_dataset_mf = dataset[0], dataset[1]

# %%
# Split the training and testing datasets

x_train_mf, y_train_mf = train_dataset_mf[:][0], train_dataset_mf[:][1]
x_test_mf, y_test_mf = test_dataset_mf[:][0], test_dataset_mf[:][1]

# %%
x_test_mf.shape

# %%
x_normalizer_mf = UnitGaussianNormalizer(x_train_mf)
x_train_mf = x_normalizer_mf.encode(x_train_mf)
x_test_mf = x_normalizer_mf.encode(x_test_mf)

y_normalizer = UnitGaussianNormalizer(y_train_mf)
y_train_mf = y_normalizer.encode(y_train_mf)

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                             batch_size=batch_size, shuffle=False)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %% [markdown]
# # MF Model

# %%
# %%
""" The MD-WNO model definition """
model_mf = WNO2d_mf(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer.to(device)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        y = y_normalizer.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.to(device), y.to(device)

            out = model_mf(x).reshape(x.shape[0], s, s)
            out = y_normalizer.decode(out)

            test_l2 += myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()

    train_mse /= len(train_loader_mf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-224, Time-1.6398, Train-MSE-0.0000, Train-L2-0.0320, Test-L2-0.0607
# Epoch-225, Time-1.6236, Train-MSE-0.0000, Train-L2-0.0354, Test-L2-0.0679
# Epoch-226, Time-1.6801, Train-MSE-0.0000, Train-L2-0.0405, Test-L2-0.0732
# Epoch-227, Time-1.6974, Train-MSE-0.0000, Train-L2-0.0600, Test-L2-0.0478
# Epoch-228, Time-1.7322, Train-MSE-0.0000, Train-L2-0.0620, Test-L2-0.0759
# Epoch-229, Time-1.6885, Train-MSE-0.0000, Train-L2-0.0521, Test-L2-0.0620
# Epoch-230, Time-1.5783, Train-MSE-0.0000, Train-L2-0.0396, Test-L2-0.0491
# Epoch-231, Time-1.6878, Train-MSE-0.0000, Train-L2-0.0330, Test-L2-0.0414
# Epoch-232, Time-1.6643, Train-MSE-0.0000, Train-L2-0.0284, Test-L2-0.0449
# Epoch-233, Time-1.6355, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0434
# Epoch-234, Time-1.6732, Train-MSE-0.0000, Train-L2-0.0271, Test-L2-0.0490
# Epoch-235, Time-1.6817, Train-MSE-0.0000, Train-L2-0.0296, Test-L2-0.0518
# Epoch-236, Time-1.6906, Train-MSE-0.0000, Train-L2-0.0310, Test-L2-0.0530
# Epoch-237, Time-1.6285, Train-MSE-0.0000, Train-L2-0.0328, Test-L2-0.0590
# Epoch-238, Time-1.6954, Train-MSE-0.0000, Train-L2-0.0353, Test-L2-0.0665
# Epoch-239, Time-1.6554, Train-MSE-0.0000, Train-L2-0.0467, Test-L2-0.0532
# Epoch-240, Time-1.6321, Train-MSE-0.0000, Train-L2-0.0577, Test-L2-0.0665
# Epoch-241, Time-1.6579, Train-MSE-0.0000, Train-L2-0.0539, Test-L2-0.0664
# Epoch-242, Time-1.6393, Train-MSE-0.0000, Train-L2-0.0435, Test-L2-0.0535
# Epoch-243, Time-1.6409, Train-MSE-0.0000, Train-L2-0.0356, Test-L2-0.0448
# Epoch-244, Time-1.6800, Train-MSE-0.0000, Train-L2-0.0291, Test-L2-0.0400
# Epoch-245, Time-1.6773, Train-MSE-0.0000, Train-L2-0.0257, Test-L2-0.0408
# Epoch-246, Time-1.6259, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.0411
# Epoch-247, Time-1.6165, Train-MSE-0.0000, Train-L2-0.0255, Test-L2-0.0451
# Epoch-248, Time-1.5907, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.0451
# Epoch-249, Time-1.5872, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0451
# Epoch-250, Time-1.6095, Train-MSE-0.0000, Train-L2-0.0276, Test-L2-0.0497
# Epoch-251, Time-1.6536, Train-MSE-0.0000, Train-L2-0.0330, Test-L2-0.0483
# Epoch-252, Time-1.6540, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-0.0437
# Epoch-253, Time-1.6556, Train-MSE-0.0000, Train-L2-0.0396, Test-L2-0.0528
# Epoch-254, Time-1.6355, Train-MSE-0.0000, Train-L2-0.0345, Test-L2-0.0477
# Epoch-255, Time-1.6331, Train-MSE-0.0000, Train-L2-0.0305, Test-L2-0.0424
# Epoch-256, Time-1.6928, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0392
# Epoch-257, Time-1.6631, Train-MSE-0.0000, Train-L2-0.0240, Test-L2-0.0375
# Epoch-258, Time-1.6682, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.0374
# Epoch-259, Time-1.7663, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.0383
# Epoch-260, Time-1.6375, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.0397
# Epoch-261, Time-1.6904, Train-MSE-0.0000, Train-L2-0.0232, Test-L2-0.0418
# Epoch-262, Time-1.6481, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0437
# Epoch-263, Time-1.6997, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0461
# Epoch-264, Time-1.6295, Train-MSE-0.0000, Train-L2-0.0276, Test-L2-0.0482
# Epoch-265, Time-1.7155, Train-MSE-0.0000, Train-L2-0.0332, Test-L2-0.0422
# Epoch-266, Time-1.6751, Train-MSE-0.0000, Train-L2-0.0374, Test-L2-0.0449
# Epoch-267, Time-1.6733, Train-MSE-0.0000, Train-L2-0.0377, Test-L2-0.0525
# Epoch-268, Time-1.6127, Train-MSE-0.0000, Train-L2-0.0339, Test-L2-0.0481
# Epoch-269, Time-1.7291, Train-MSE-0.0000, Train-L2-0.0320, Test-L2-0.0420
# Epoch-270, Time-1.6073, Train-MSE-0.0000, Train-L2-0.0280, Test-L2-0.0392
# Epoch-271, Time-1.6096, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.0377
# Epoch-272, Time-1.7132, Train-MSE-0.0000, Train-L2-0.0234, Test-L2-0.0367
# Epoch-273, Time-1.6000, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.0368
# Epoch-274, Time-1.6169, Train-MSE-0.0000, Train-L2-0.0217, Test-L2-0.0371
# Epoch-275, Time-1.6056, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0385
# Epoch-276, Time-1.5998, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.0403
# Epoch-277, Time-1.7285, Train-MSE-0.0000, Train-L2-0.0231, Test-L2-0.0426
# Epoch-278, Time-1.6172, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.0456
# Epoch-279, Time-1.6966, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.0466
# Epoch-280, Time-1.6586, Train-MSE-0.0000, Train-L2-0.0299, Test-L2-0.0451
# Epoch-281, Time-1.6388, Train-MSE-0.0000, Train-L2-0.0350, Test-L2-0.0394
# Epoch-282, Time-1.6295, Train-MSE-0.0000, Train-L2-0.0357, Test-L2-0.0473
# Epoch-283, Time-1.6698, Train-MSE-0.0000, Train-L2-0.0351, Test-L2-0.0499
# Epoch-284, Time-1.7205, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.0465
# Epoch-285, Time-1.7127, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.0413
# Epoch-286, Time-1.6587, Train-MSE-0.0000, Train-L2-0.0279, Test-L2-0.0386
# Epoch-287, Time-1.7280, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.0371
# Epoch-288, Time-1.6482, Train-MSE-0.0000, Train-L2-0.0232, Test-L2-0.0363
# Epoch-289, Time-1.6822, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0362
# Epoch-290, Time-1.6238, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.0366
# Epoch-291, Time-1.6169, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.0376
# Epoch-292, Time-1.6376, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.0394
# Epoch-293, Time-1.6299, Train-MSE-0.0000, Train-L2-0.0229, Test-L2-0.0422
# Epoch-294, Time-1.6256, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0452
# Epoch-295, Time-1.6865, Train-MSE-0.0000, Train-L2-0.0262, Test-L2-0.0467
# Epoch-296, Time-1.6165, Train-MSE-0.0000, Train-L2-0.0295, Test-L2-0.0456
# Epoch-297, Time-1.5849, Train-MSE-0.0000, Train-L2-0.0345, Test-L2-0.0397
# Epoch-298, Time-1.6103, Train-MSE-0.0000, Train-L2-0.0355, Test-L2-0.0456
# Epoch-299, Time-1.6203, Train-MSE-0.0000, Train-L2-0.0351, Test-L2-0.0494
# Epoch-300, Time-1.6016, Train-MSE-0.0000, Train-L2-0.0316, Test-L2-0.0400
# Epoch-301, Time-1.6090, Train-MSE-0.0000, Train-L2-0.0294, Test-L2-0.0382
# Epoch-302, Time-1.6376, Train-MSE-0.0000, Train-L2-0.0240, Test-L2-0.0391
# Epoch-303, Time-1.5925, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.0388
# Epoch-304, Time-1.6583, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.0401
# Epoch-305, Time-1.6297, Train-MSE-0.0000, Train-L2-0.0259, Test-L2-0.0364
# Epoch-306, Time-1.6437, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0373
# Epoch-307, Time-1.6680, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.0407
# Epoch-308, Time-1.6650, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.0392
# Epoch-309, Time-1.6431, Train-MSE-0.0000, Train-L2-0.0239, Test-L2-0.0375
# Epoch-310, Time-1.6387, Train-MSE-0.0000, Train-L2-0.0233, Test-L2-0.0357
# Epoch-311, Time-1.6497, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.0348
# Epoch-312, Time-1.6303, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0346
# Epoch-313, Time-1.6578, Train-MSE-0.0000, Train-L2-0.0197, Test-L2-0.0348
# Epoch-314, Time-1.6347, Train-MSE-0.0000, Train-L2-0.0195, Test-L2-0.0360
# Epoch-315, Time-1.6560, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0383
# Epoch-316, Time-1.7144, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0399
# Epoch-317, Time-1.7169, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.0378
# Epoch-318, Time-1.6883, Train-MSE-0.0000, Train-L2-0.0264, Test-L2-0.0355
# Epoch-319, Time-1.7002, Train-MSE-0.0000, Train-L2-0.0261, Test-L2-0.0386
# Epoch-320, Time-1.6548, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.0393
# Epoch-321, Time-1.7410, Train-MSE-0.0000, Train-L2-0.0234, Test-L2-0.0383
# Epoch-322, Time-1.6694, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-0.0368
# Epoch-323, Time-1.6586, Train-MSE-0.0000, Train-L2-0.0230, Test-L2-0.0353
# Epoch-324, Time-1.6284, Train-MSE-0.0000, Train-L2-0.0217, Test-L2-0.0347
# Epoch-325, Time-1.6348, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.0345
# Epoch-326, Time-1.6468, Train-MSE-0.0000, Train-L2-0.0197, Test-L2-0.0346
# Epoch-327, Time-1.7250, Train-MSE-0.0000, Train-L2-0.0193, Test-L2-0.0355
# Epoch-328, Time-1.7072, Train-MSE-0.0000, Train-L2-0.0199, Test-L2-0.0377
# Epoch-329, Time-1.6542, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.0402
# Epoch-330, Time-1.6299, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.0398
# Epoch-331, Time-1.6730, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0358
# Epoch-332, Time-1.6382, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0385
# Epoch-333, Time-1.6139, Train-MSE-0.0000, Train-L2-0.0259, Test-L2-0.0391
# Epoch-334, Time-1.6282, Train-MSE-0.0000, Train-L2-0.0233, Test-L2-0.0375
# Epoch-335, Time-1.6268, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.0371
# Epoch-336, Time-1.6774, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.0362
# Epoch-337, Time-1.6612, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.0350
# Epoch-338, Time-1.7427, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.0342
# Epoch-339, Time-1.6872, Train-MSE-0.0000, Train-L2-0.0197, Test-L2-0.0339
# Epoch-340, Time-1.6907, Train-MSE-0.0000, Train-L2-0.0190, Test-L2-0.0339
# Epoch-341, Time-1.6965, Train-MSE-0.0000, Train-L2-0.0188, Test-L2-0.0348
# Epoch-342, Time-1.6956, Train-MSE-0.0000, Train-L2-0.0194, Test-L2-0.0365
# Epoch-343, Time-1.7058, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0391
# Epoch-344, Time-1.6839, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.0408
# Epoch-345, Time-1.7371, Train-MSE-0.0000, Train-L2-0.0250, Test-L2-0.0385
# Epoch-346, Time-1.6808, Train-MSE-0.0000, Train-L2-0.0279, Test-L2-0.0365
# Epoch-347, Time-1.6862, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.0395
# Epoch-348, Time-1.6109, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.0385
# Epoch-349, Time-1.6826, Train-MSE-0.0000, Train-L2-0.0229, Test-L2-0.0373
# Epoch-350, Time-1.6237, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.0347
# Epoch-351, Time-1.5947, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.0349
# Epoch-352, Time-1.5751, Train-MSE-0.0000, Train-L2-0.0200, Test-L2-0.0356
# Epoch-353, Time-1.5793, Train-MSE-0.0000, Train-L2-0.0194, Test-L2-0.0359
# Epoch-354, Time-1.6460, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.0351
# Epoch-355, Time-1.6122, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.0335
# Epoch-356, Time-1.6200, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0343
# Epoch-357, Time-1.5795, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.0344
# Epoch-358, Time-1.5724, Train-MSE-0.0000, Train-L2-0.0192, Test-L2-0.0340
# Epoch-359, Time-1.5791, Train-MSE-0.0000, Train-L2-0.0192, Test-L2-0.0335
# Epoch-360, Time-1.5760, Train-MSE-0.0000, Train-L2-0.0190, Test-L2-0.0328
# Epoch-361, Time-1.5785, Train-MSE-0.0000, Train-L2-0.0184, Test-L2-0.0327
# Epoch-362, Time-1.5819, Train-MSE-0.0000, Train-L2-0.0178, Test-L2-0.0330
# Epoch-363, Time-1.6504, Train-MSE-0.0000, Train-L2-0.0176, Test-L2-0.0337
# Epoch-364, Time-1.6391, Train-MSE-0.0000, Train-L2-0.0180, Test-L2-0.0350
# Epoch-365, Time-1.7065, Train-MSE-0.0000, Train-L2-0.0192, Test-L2-0.0351
# Epoch-366, Time-1.6881, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.0335
# Epoch-367, Time-1.7460, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.0331
# Epoch-368, Time-1.7036, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.0339
# Epoch-369, Time-1.6990, Train-MSE-0.0000, Train-L2-0.0194, Test-L2-0.0339
# Epoch-370, Time-1.6391, Train-MSE-0.0000, Train-L2-0.0188, Test-L2-0.0337
# Epoch-371, Time-1.5758, Train-MSE-0.0000, Train-L2-0.0191, Test-L2-0.0333
# Epoch-372, Time-1.6128, Train-MSE-0.0000, Train-L2-0.0192, Test-L2-0.0327
# Epoch-373, Time-1.6349, Train-MSE-0.0000, Train-L2-0.0186, Test-L2-0.0324
# Epoch-374, Time-1.5979, Train-MSE-0.0000, Train-L2-0.0179, Test-L2-0.0326
# Epoch-375, Time-1.6095, Train-MSE-0.0000, Train-L2-0.0174, Test-L2-0.0330
# Epoch-376, Time-1.7125, Train-MSE-0.0000, Train-L2-0.0175, Test-L2-0.0342
# Epoch-377, Time-1.6771, Train-MSE-0.0000, Train-L2-0.0185, Test-L2-0.0356
# Epoch-378, Time-1.6955, Train-MSE-0.0000, Train-L2-0.0200, Test-L2-0.0348
# Epoch-379, Time-1.7554, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.0329
# Epoch-380, Time-1.6486, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.0337
# Epoch-381, Time-1.5805, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.0342
# Epoch-382, Time-1.6441, Train-MSE-0.0000, Train-L2-0.0190, Test-L2-0.0337
# Epoch-383, Time-1.6372, Train-MSE-0.0000, Train-L2-0.0190, Test-L2-0.0335
# Epoch-384, Time-1.6567, Train-MSE-0.0000, Train-L2-0.0195, Test-L2-0.0329
# Epoch-385, Time-1.6386, Train-MSE-0.0000, Train-L2-0.0191, Test-L2-0.0325
# Epoch-386, Time-1.6392, Train-MSE-0.0000, Train-L2-0.0183, Test-L2-0.0325
# Epoch-387, Time-1.6584, Train-MSE-0.0000, Train-L2-0.0176, Test-L2-0.0327
# Epoch-388, Time-1.6675, Train-MSE-0.0000, Train-L2-0.0173, Test-L2-0.0334
# Epoch-389, Time-1.5975, Train-MSE-0.0000, Train-L2-0.0178, Test-L2-0.0350
# Epoch-390, Time-1.6979, Train-MSE-0.0000, Train-L2-0.0192, Test-L2-0.0358
# Epoch-391, Time-1.7263, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.0339
# Epoch-392, Time-1.6457, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.0336
# Epoch-393, Time-1.6457, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.0343
# Epoch-394, Time-1.7290, Train-MSE-0.0000, Train-L2-0.0197, Test-L2-0.0337
# Epoch-395, Time-1.6399, Train-MSE-0.0000, Train-L2-0.0187, Test-L2-0.0334
# Epoch-396, Time-1.7135, Train-MSE-0.0000, Train-L2-0.0191, Test-L2-0.0333
# Epoch-397, Time-1.7025, Train-MSE-0.0000, Train-L2-0.0193, Test-L2-0.0329
# Epoch-398, Time-1.6764, Train-MSE-0.0000, Train-L2-0.0188, Test-L2-0.0324
# Epoch-399, Time-1.7080, Train-MSE-0.0000, Train-L2-0.0180, Test-L2-0.0324
# Epoch-400, Time-1.6606, Train-MSE-0.0000, Train-L2-0.0172, Test-L2-0.0332
# Epoch-401, Time-1.6584, Train-MSE-0.0000, Train-L2-0.0179, Test-L2-0.0336
# Epoch-402, Time-1.5997, Train-MSE-0.0000, Train-L2-0.0190, Test-L2-0.0322
# Epoch-403, Time-1.6186, Train-MSE-0.0000, Train-L2-0.0184, Test-L2-0.0319
# Epoch-404, Time-1.6704, Train-MSE-0.0000, Train-L2-0.0175, Test-L2-0.0317
# Epoch-405, Time-1.6037, Train-MSE-0.0000, Train-L2-0.0167, Test-L2-0.0316
# Epoch-406, Time-1.6481, Train-MSE-0.0000, Train-L2-0.0165, Test-L2-0.0315
# Epoch-407, Time-1.5965, Train-MSE-0.0000, Train-L2-0.0164, Test-L2-0.0314
# Epoch-408, Time-1.6400, Train-MSE-0.0000, Train-L2-0.0162, Test-L2-0.0314
# Epoch-409, Time-1.6410, Train-MSE-0.0000, Train-L2-0.0161, Test-L2-0.0317
# Epoch-410, Time-1.6668, Train-MSE-0.0000, Train-L2-0.0162, Test-L2-0.0321
# Epoch-411, Time-1.7325, Train-MSE-0.0000, Train-L2-0.0166, Test-L2-0.0321
# Epoch-412, Time-1.6401, Train-MSE-0.0000, Train-L2-0.0170, Test-L2-0.0317
# Epoch-413, Time-1.6197, Train-MSE-0.0000, Train-L2-0.0170, Test-L2-0.0313
# Epoch-414, Time-1.6746, Train-MSE-0.0000, Train-L2-0.0168, Test-L2-0.0314
# Epoch-415, Time-1.7007, Train-MSE-0.0000, Train-L2-0.0165, Test-L2-0.0314
# Epoch-416, Time-1.6457, Train-MSE-0.0000, Train-L2-0.0163, Test-L2-0.0313
# Epoch-417, Time-1.5998, Train-MSE-0.0000, Train-L2-0.0163, Test-L2-0.0312
# Epoch-418, Time-1.6261, Train-MSE-0.0000, Train-L2-0.0163, Test-L2-0.0311
# Epoch-419, Time-1.6896, Train-MSE-0.0000, Train-L2-0.0163, Test-L2-0.0310
# Epoch-420, Time-1.6845, Train-MSE-0.0000, Train-L2-0.0161, Test-L2-0.0310
# Epoch-421, Time-1.6825, Train-MSE-0.0000, Train-L2-0.0158, Test-L2-0.0312
# Epoch-422, Time-1.7381, Train-MSE-0.0000, Train-L2-0.0158, Test-L2-0.0316
# Epoch-423, Time-1.7490, Train-MSE-0.0000, Train-L2-0.0160, Test-L2-0.0321
# Epoch-424, Time-1.6839, Train-MSE-0.0000, Train-L2-0.0165, Test-L2-0.0322
# Epoch-425, Time-1.6788, Train-MSE-0.0000, Train-L2-0.0170, Test-L2-0.0317
# Epoch-426, Time-1.6905, Train-MSE-0.0000, Train-L2-0.0172, Test-L2-0.0312
# Epoch-427, Time-1.7269, Train-MSE-0.0000, Train-L2-0.0170, Test-L2-0.0312
# Epoch-428, Time-1.6553, Train-MSE-0.0000, Train-L2-0.0167, Test-L2-0.0314
# Epoch-429, Time-1.7083, Train-MSE-0.0000, Train-L2-0.0164, Test-L2-0.0314
# Epoch-430, Time-1.6201, Train-MSE-0.0000, Train-L2-0.0164, Test-L2-0.0314
# Epoch-431, Time-1.6870, Train-MSE-0.0000, Train-L2-0.0168, Test-L2-0.0313
# Epoch-432, Time-1.6399, Train-MSE-0.0000, Train-L2-0.0169, Test-L2-0.0309
# Epoch-433, Time-1.6480, Train-MSE-0.0000, Train-L2-0.0166, Test-L2-0.0309
# Epoch-434, Time-1.7112, Train-MSE-0.0000, Train-L2-0.0161, Test-L2-0.0310
# Epoch-435, Time-1.6749, Train-MSE-0.0000, Train-L2-0.0158, Test-L2-0.0314
# Epoch-436, Time-1.7932, Train-MSE-0.0000, Train-L2-0.0159, Test-L2-0.0321
# Epoch-437, Time-1.6440, Train-MSE-0.0000, Train-L2-0.0166, Test-L2-0.0327
# Epoch-438, Time-1.6539, Train-MSE-0.0000, Train-L2-0.0175, Test-L2-0.0320
# Epoch-439, Time-1.6607, Train-MSE-0.0000, Train-L2-0.0180, Test-L2-0.0312
# Epoch-440, Time-1.7316, Train-MSE-0.0000, Train-L2-0.0177, Test-L2-0.0314
# Epoch-441, Time-1.6816, Train-MSE-0.0000, Train-L2-0.0172, Test-L2-0.0316
# Epoch-442, Time-1.6825, Train-MSE-0.0000, Train-L2-0.0166, Test-L2-0.0315
# Epoch-443, Time-1.7075, Train-MSE-0.0000, Train-L2-0.0167, Test-L2-0.0314
# Epoch-444, Time-1.7046, Train-MSE-0.0000, Train-L2-0.0172, Test-L2-0.0311
# Epoch-445, Time-1.6597, Train-MSE-0.0000, Train-L2-0.0172, Test-L2-0.0309
# Epoch-446, Time-1.6409, Train-MSE-0.0000, Train-L2-0.0167, Test-L2-0.0311
# Epoch-447, Time-1.6516, Train-MSE-0.0000, Train-L2-0.0161, Test-L2-0.0313
# Epoch-448, Time-1.6260, Train-MSE-0.0000, Train-L2-0.0158, Test-L2-0.0318
# Epoch-449, Time-1.6659, Train-MSE-0.0000, Train-L2-0.0162, Test-L2-0.0326
# Epoch-450, Time-1.6173, Train-MSE-0.0000, Train-L2-0.0173, Test-L2-0.0308
# Epoch-451, Time-1.7319, Train-MSE-0.0000, Train-L2-0.0171, Test-L2-0.0309
# Epoch-452, Time-1.7186, Train-MSE-0.0000, Train-L2-0.0163, Test-L2-0.0308
# Epoch-453, Time-1.7247, Train-MSE-0.0000, Train-L2-0.0157, Test-L2-0.0303
# Epoch-454, Time-1.6141, Train-MSE-0.0000, Train-L2-0.0155, Test-L2-0.0303
# Epoch-455, Time-1.6401, Train-MSE-0.0000, Train-L2-0.0152, Test-L2-0.0305
# Epoch-456, Time-1.6514, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0308
# Epoch-457, Time-1.6589, Train-MSE-0.0000, Train-L2-0.0154, Test-L2-0.0308
# Epoch-458, Time-1.6409, Train-MSE-0.0000, Train-L2-0.0157, Test-L2-0.0304
# Epoch-459, Time-1.5903, Train-MSE-0.0000, Train-L2-0.0156, Test-L2-0.0302
# Epoch-460, Time-1.6780, Train-MSE-0.0000, Train-L2-0.0153, Test-L2-0.0302
# Epoch-461, Time-1.6465, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0301
# Epoch-462, Time-1.6707, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0301
# Epoch-463, Time-1.7380, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0300
# Epoch-464, Time-1.6531, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0301
# Epoch-465, Time-1.6823, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0302
# Epoch-466, Time-1.6720, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0304
# Epoch-467, Time-1.7113, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0304
# Epoch-468, Time-1.7247, Train-MSE-0.0000, Train-L2-0.0152, Test-L2-0.0302
# Epoch-469, Time-1.6624, Train-MSE-0.0000, Train-L2-0.0152, Test-L2-0.0300
# Epoch-470, Time-1.7180, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0300
# Epoch-471, Time-1.6221, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0300
# Epoch-472, Time-1.6294, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0299
# Epoch-473, Time-1.6323, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0299
# Epoch-474, Time-1.6809, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0298
# Epoch-475, Time-1.6101, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0298
# Epoch-476, Time-1.7176, Train-MSE-0.0000, Train-L2-0.0147, Test-L2-0.0298
# Epoch-477, Time-1.6669, Train-MSE-0.0000, Train-L2-0.0146, Test-L2-0.0300
# Epoch-478, Time-1.6193, Train-MSE-0.0000, Train-L2-0.0146, Test-L2-0.0302
# Epoch-479, Time-1.7003, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0304
# Epoch-480, Time-1.6166, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0302
# Epoch-481, Time-1.6746, Train-MSE-0.0000, Train-L2-0.0152, Test-L2-0.0300
# Epoch-482, Time-1.6621, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0298
# Epoch-483, Time-1.6782, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0298
# Epoch-484, Time-1.6189, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0298
# Epoch-485, Time-1.6181, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0298
# Epoch-486, Time-1.6381, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0298
# Epoch-487, Time-1.6876, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0297
# Epoch-488, Time-1.6415, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0296
# Epoch-489, Time-1.6236, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-0.0296
# Epoch-490, Time-1.6711, Train-MSE-0.0000, Train-L2-0.0146, Test-L2-0.0298
# Epoch-491, Time-1.6216, Train-MSE-0.0000, Train-L2-0.0145, Test-L2-0.0301
# Epoch-492, Time-1.6366, Train-MSE-0.0000, Train-L2-0.0147, Test-L2-0.0305
# Epoch-493, Time-1.6961, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0305
# Epoch-494, Time-1.5948, Train-MSE-0.0000, Train-L2-0.0155, Test-L2-0.0301
# Epoch-495, Time-1.6005, Train-MSE-0.0000, Train-L2-0.0156, Test-L2-0.0298
# Epoch-496, Time-1.6538, Train-MSE-0.0000, Train-L2-0.0154, Test-L2-0.0298
# Epoch-497, Time-1.6365, Train-MSE-0.0000, Train-L2-0.0151, Test-L2-0.0299
# Epoch-498, Time-1.6089, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-0.0299
# Epoch-499, Time-1.6389, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-0.0299

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_Darcy2D_50')

# %%
# Prediction:
pred_mf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x, y = x.to(device), y.to(device)
        
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_mf.append(out.cpu())
        index += 1

pred_mf = torch.cat(( pred_mf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
# Add the residual operator to LF-dataset 
input_mf = x_normalizer_mf.decode( x_test_mf.cpu() ) 

real_mf = y_test_mf + input_mf[..., 1]
output_mf = pred_mf + input_mf[..., 1]

# %%
print(real_mf.shape, output_mf.shape)

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()
mse_LF = F.mse_loss(real_mf, x_test_mf[..., 1])
mse_residual = F.mse_loss(y_test_mf, pred_mf)

print('MSE-Predicted solution-{:0.4f}, MSE-LF Data-{:0.4f}, MSE-Residual-{:0.4f}'
      .format(mse_pred, mse_LF, mse_residual))

# %%
fig1, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig1.subplots_adjust(hspace=0.35, wspace=0.2)

fig1.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(real_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(real_mf[sample, :, :] - output_mf[sample, :, :]),
                                    cmap='jet', origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %% [markdown]
# # High Fidelity

# %%
class WaveConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv2d, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet       
        dummy_data = torch.randn( 1,1,*size )        
        dwt_ = DWT(J=self.level, mode='symmetric', wave=self.wavelet)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights3 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights4 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet
        dwt = DWT(J=self.level, mode='symmetric', wave=self.wavelet).to(x.device)
        x_ft, x_coeff = dwt(x)

        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft, self.weights1)
        # Multiply the final detailed wavelet coefficients
        x_coeff[-1][:,:,0,:,:] = self.mul2d(x_coeff[-1][:,:,0,:,:].clone(), self.weights2)
        x_coeff[-1][:,:,1,:,:] = self.mul2d(x_coeff[-1][:,:,1,:,:].clone(), self.weights3)
        x_coeff[-1][:,:,2,:,:] = self.mul2d(x_coeff[-1][:,:,2,:,:].clone(), self.weights4)
        
        # Return to physical space        
        idwt = IDWT(mode='symmetric', wave=self.wavelet).to(x.device)
        x = idwt((out_ft, x_coeff))
        return x

# %%
class WNO2d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """
        
        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %%
ntrain = ntrain
ntest = ntest
n_total = ntrain + ntest
batch_size = batch_size
learning_rate = 0.001

wavelet = 'db6'  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 3

epochs = 250
step_size = 50
gamma = 0.75

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# Create the input and output (residual) dataset
x_hf = torch.tensor( x_or_h, dtype=torch.float ) 
y_hf = torch.tensor( y_or_h, dtype=torch.float ) 
    
generator_hf = torch.Generator().manual_seed(453)
dataset_hf = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_hf, y_hf),
                                    [ntrain, ntest], generator=generator)
train_data_hf, test_data_hf = dataset_hf[0], dataset_hf[1]

# Split the training and testing datasets
x_train_hf, y_train_hf = train_data_hf[:][0], train_data_hf[:][1]
x_test_hf, y_test_hf = test_data_hf[:][0], test_data_hf[:][1]

x_normalizer_hf = UnitGaussianNormalizer(x_train_hf)
x_train_hf = x_normalizer_hf.encode(x_train_hf)
x_test_hf = x_normalizer_hf.encode(x_test_hf)

y_normalizer_hf = UnitGaussianNormalizer(y_train_hf)
y_train_hf = y_normalizer_hf.encode(y_train_hf)

# Define the dataloaders
train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                             batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, y_test_hf),
                                            batch_size=batch_size, shuffle=False)

# %%
model = WNO2d(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model))

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer_hf.to(device)
for ep in range(epochs):
    model.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model(x).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        y = y_normalizer_hf.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.to(device), y.to(device)

            out = model(x).reshape(x.shape[0], s, s)
            out = y_normalizer_hf.decode(out)

            test_l2 += myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1)).item()

    train_mse /= len(train_loader_hf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-224, Time-0.9935, Train-MSE-0.0002, Train-L2-0.0198, Test-L2-0.0398
# Epoch-225, Time-1.1162, Train-MSE-0.0002, Train-L2-0.0194, Test-L2-0.0372
# Epoch-226, Time-1.1081, Train-MSE-0.0002, Train-L2-0.0204, Test-L2-0.0447
# Epoch-227, Time-1.0474, Train-MSE-0.0002, Train-L2-0.0229, Test-L2-0.0456
# Epoch-228, Time-1.0088, Train-MSE-0.0004, Train-L2-0.0269, Test-L2-0.0431
# Epoch-229, Time-0.9930, Train-MSE-0.0003, Train-L2-0.0236, Test-L2-0.0409
# Epoch-230, Time-1.0344, Train-MSE-0.0003, Train-L2-0.0218, Test-L2-0.0409
# Epoch-231, Time-1.0388, Train-MSE-0.0003, Train-L2-0.0224, Test-L2-0.0409
# Epoch-232, Time-1.0427, Train-MSE-0.0002, Train-L2-0.0212, Test-L2-0.0398
# Epoch-233, Time-1.0601, Train-MSE-0.0002, Train-L2-0.0212, Test-L2-0.0401
# Epoch-234, Time-1.0078, Train-MSE-0.0003, Train-L2-0.0216, Test-L2-0.0404
# Epoch-235, Time-1.0522, Train-MSE-0.0002, Train-L2-0.0215, Test-L2-0.0393
# Epoch-236, Time-1.1379, Train-MSE-0.0002, Train-L2-0.0215, Test-L2-0.0409
# Epoch-237, Time-1.0357, Train-MSE-0.0003, Train-L2-0.0258, Test-L2-0.0434
# Epoch-238, Time-1.0141, Train-MSE-0.0003, Train-L2-0.0255, Test-L2-0.0457
# Epoch-239, Time-1.0214, Train-MSE-0.0003, Train-L2-0.0237, Test-L2-0.0405
# Epoch-240, Time-1.0739, Train-MSE-0.0003, Train-L2-0.0236, Test-L2-0.0421
# Epoch-241, Time-1.0359, Train-MSE-0.0003, Train-L2-0.0229, Test-L2-0.0450
# Epoch-242, Time-1.0333, Train-MSE-0.0003, Train-L2-0.0253, Test-L2-0.0428
# Epoch-243, Time-1.0483, Train-MSE-0.0003, Train-L2-0.0226, Test-L2-0.0399
# Epoch-244, Time-1.0599, Train-MSE-0.0002, Train-L2-0.0191, Test-L2-0.0379
# Epoch-245, Time-1.0570, Train-MSE-0.0003, Train-L2-0.0241, Test-L2-0.0389
# Epoch-246, Time-1.0790, Train-MSE-0.0002, Train-L2-0.0211, Test-L2-0.0428
# Epoch-247, Time-1.0183, Train-MSE-0.0002, Train-L2-0.0222, Test-L2-0.0385
# Epoch-248, Time-1.0302, Train-MSE-0.0003, Train-L2-0.0229, Test-L2-0.0401
# Epoch-249, Time-1.0537, Train-MSE-0.0002, Train-L2-0.0215, Test-L2-0.0409

# %%
# Save the HF-WNO model

torch.save(model, 'model/HF_WNO_Darcy2D_50')

# %%
# Predict on HF data using HF-WNO
pred_hf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x = x_normalizer_mf.decode(x)
        x = x_normalizer_hf.encode(x)
        
        x, y = x.to(device), y.to(device)

        out = model(x[..., 0:1]).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_hf.append(out.cpu())
        index += 1

pred_hf = torch.cat(( pred_hf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
mse_pred_hf = F.mse_loss(pred_hf, y_test_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
fig2, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig2.subplots_adjust(hspace=0.35, wspace=0.2)

fig2.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(y_test_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(pred_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(y_test_hf[sample, :, :] - pred_hf[sample, :, :]),
                                    cmap='jet',origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %%
fig4, axs = plt.subplots(nrows=2, ncols=5, figsize=(10, 4), facecolor='w', edgecolor='k')
fig4.subplots_adjust(hspace=0.35, wspace=0.2)

fig4.suptitle(f'Predictions Error', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(pred_hf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        index += 1

# %% [markdown]
# # Plotting

# %%
s = 1
xmax = s
ymax = s-8/51
from matplotlib.patches import Rectangle
plt.rcParams["font.family"] = "Serif"
plt.rcParams['font.size'] = 10

figure1 = plt.figure(constrained_layout=False, figsize = (14, 10))
plt.subplots_adjust(hspace=0.25, wspace=0.3)
index = 0
value = 0

plt.subplot(3,4, index+1)
plt.imshow(output_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('MFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
      
      #####        
plt.subplot(3,4, index+2)
plt.imshow(pred_hf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('HFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
        ###
plt.subplot(3,4, index+3)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(input_mf[value,:,:,1], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('LFM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        #####
plt.subplot(3,4, index+4)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(real_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Ground Truth');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        
        ###
plt.subplot(3,4, index+5)
plt.imshow(np.abs(output_mf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))

        ###
plt.subplot(3,4, index+6)
plt.imshow(np.abs(pred_hf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))


        ###
plt.subplot(3,4, index+7)
plt.imshow(np.abs(input_mf[value,:,:,1]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))
