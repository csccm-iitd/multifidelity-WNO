# %% [markdown]
# # It trains MFWNO on MF Darcy data (2D time-independent problem)
# ### HF data size = 20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
torch.cuda.empty_cache()
import matplotlib.pyplot as plt
from utils import *

from timeit import default_timer
from pytorch_wavelets import DWT, IDWT # (or import DWT, IDWT)
from pytorch_wavelets import DTCWTForward, DTCWTInverse

# %%
torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# # WNO

# %%
class WaveConv2dCwt(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet1, wavelet2):
        super(WaveConv2dCwt, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        # !! It is computationally expensive than the discrete "WaveConv2d" !!
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet_level1 = wavelet1
        self.wavelet_level2 = wavelet2        
        dummy_data = torch.randn( 1,1,*size ) 
        dwt_ = DTCWTForward(J=self.level, biort=self.wavelet_level1,
                            qshift=self.wavelet_level2)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        self.modes21 = mode_coef[-1].shape[-3]
        self.modes22 = mode_coef[-1].shape[-2]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights0 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights15r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights15c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights45c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights75c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights105c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights135c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165r = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))
        self.weights165c = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes21, self.modes22))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """        
        # Compute dual tree continuous Wavelet coefficients 
        cwt = DTCWTForward(J=self.level, biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x_ft, x_coeff = cwt(x)
        
        out_ft = torch.zeros_like(x_ft, device= x.device)
        out_coeff = [torch.zeros_like(coeffs, device= x.device) for coeffs in x_coeff]
        
        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft[:, :, :self.modes1, :self.modes2], self.weights0)
        # Multiply the final detailed wavelet coefficients        
        out_coeff[-1][:,:,0,:,:,0] = self.mul2d(x_coeff[-1][:,:,0,:,:,0].clone(), self.weights15r)
        out_coeff[-1][:,:,0,:,:,1] = self.mul2d(x_coeff[-1][:,:,0,:,:,1].clone(), self.weights15c)
        out_coeff[-1][:,:,1,:,:,0] = self.mul2d(x_coeff[-1][:,:,1,:,:,0].clone(), self.weights45r)
        out_coeff[-1][:,:,1,:,:,1] = self.mul2d(x_coeff[-1][:,:,1,:,:,1].clone(), self.weights45c)
        out_coeff[-1][:,:,2,:,:,0] = self.mul2d(x_coeff[-1][:,:,2,:,:,0].clone(), self.weights75r)
        out_coeff[-1][:,:,2,:,:,1] = self.mul2d(x_coeff[-1][:,:,2,:,:,1].clone(), self.weights75c)
        out_coeff[-1][:,:,3,:,:,0] = self.mul2d(x_coeff[-1][:,:,3,:,:,0].clone(), self.weights105r)
        out_coeff[-1][:,:,3,:,:,1] = self.mul2d(x_coeff[-1][:,:,3,:,:,1].clone(), self.weights105c)
        out_coeff[-1][:,:,4,:,:,0] = self.mul2d(x_coeff[-1][:,:,4,:,:,0].clone(), self.weights135r)
        out_coeff[-1][:,:,4,:,:,1] = self.mul2d(x_coeff[-1][:,:,4,:,:,1].clone(), self.weights135c)
        out_coeff[-1][:,:,5,:,:,0] = self.mul2d(x_coeff[-1][:,:,5,:,:,0].clone(), self.weights165r)
        out_coeff[-1][:,:,5,:,:,1] = self.mul2d(x_coeff[-1][:,:,5,:,:,1].clone(), self.weights165c)
        
        # Return to physical space        
        icwt = DTCWTInverse(biort=self.wavelet_level1, qshift=self.wavelet_level2).to(x.device)
        x = icwt((out_ft, out_coeff))
        return x

# %%
class WNO2d_mf(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d_mf, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet1 = wavelet[0]
        self.wavelet2 = wavelet[1]
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv1 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv2 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.conv3 = WaveConv2dCwt(self.width, self.width, self.level, self.size, self.wavelet1, self.wavelet2)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %% [markdown]
# # Training and Data

# %%
ntrain = 20
ntest = 40
epochs = 500
last_m = 600
batch_size = 5

n_total = ntrain + ntest
learning_rate = 0.001

step_size = 50
gamma = 0.75

wavelet = ['near_sym_a', 'qshift_a']  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 4

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# %%
""" Read data """
PATH = 'data/Darcy_Triangular_FNO_multifid_hmax018_hmin016.mat'
reader = MatReader(PATH)

x_train = np.array(reader.read_field('boundCoeff')[:,::r,::r][:,:s,:s])
y_train = np.array(reader.read_field('sol')[:,::r,::r][:,:s,:s])
y_train_l = np.array(reader.read_field('lressol')[:,::r,::r][:,:s,:s])
x_or_h = x_train[last_m-n_total:last_m].reshape((n_total,s,s,1))
y_or_h = y_train[last_m-n_total:last_m]
y_or_l = y_train_l[last_m-n_total:last_m].reshape((n_total,s,s,1))

# %%
y_or_l.shape

# %%
x_mf = np.concatenate((x_or_h,y_or_l),axis=-1)
y_mf = y_or_h - y_or_l.reshape((n_total,s,s))

x_mf = torch.tensor( x_mf, dtype=torch.float ) 
y_mf = torch.tensor( y_mf, dtype=torch.float ) 
    
generator = torch.Generator().manual_seed(453)
dataset = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_mf, y_mf),
                                    [ntrain, ntest], generator=generator)
train_dataset_mf, test_dataset_mf = dataset[0], dataset[1]

# %%
# Split the training and testing datasets

x_train_mf, y_train_mf = train_dataset_mf[:][0], train_dataset_mf[:][1]
x_test_mf, y_test_mf = test_dataset_mf[:][0], test_dataset_mf[:][1]

# %%
x_test_mf.shape

# %%
x_normalizer_mf = UnitGaussianNormalizer(x_train_mf)
x_train_mf = x_normalizer_mf.encode(x_train_mf)
x_test_mf = x_normalizer_mf.encode(x_test_mf)

y_normalizer = UnitGaussianNormalizer(y_train_mf)
y_train_mf = y_normalizer.encode(y_train_mf)

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                             batch_size=batch_size, shuffle=False)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %% [markdown]
# # MF Model

# %%
# %%
""" The MD-WNO model definition """
model_mf = WNO2d_mf(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer.to(device)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        y = y_normalizer.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.to(device), y.to(device)

            out = model_mf(x).reshape(x.shape[0], s, s)
            out = y_normalizer.decode(out)

            test_l2 += myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()

    train_mse /= len(train_loader_mf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-113, Time-1.0185, Train-MSE-0.0000, Train-L2-0.0644, Test-L2-0.1384
# Epoch-114, Time-1.0669, Train-MSE-0.0000, Train-L2-0.0637, Test-L2-0.1390
# Epoch-115, Time-0.9974, Train-MSE-0.0000, Train-L2-0.0630, Test-L2-0.1418
# Epoch-116, Time-1.0217, Train-MSE-0.0000, Train-L2-0.0647, Test-L2-0.1402
# Epoch-117, Time-1.0760, Train-MSE-0.0000, Train-L2-0.0654, Test-L2-0.1435
# Epoch-118, Time-1.0094, Train-MSE-0.0000, Train-L2-0.0673, Test-L2-0.1378
# Epoch-119, Time-0.9586, Train-MSE-0.0000, Train-L2-0.0654, Test-L2-0.1396
# Epoch-120, Time-0.9423, Train-MSE-0.0000, Train-L2-0.0642, Test-L2-0.1372
# Epoch-121, Time-1.0482, Train-MSE-0.0000, Train-L2-0.0634, Test-L2-0.1381
# Epoch-122, Time-1.0524, Train-MSE-0.0000, Train-L2-0.0620, Test-L2-0.1413
# Epoch-123, Time-0.9351, Train-MSE-0.0000, Train-L2-0.0637, Test-L2-0.1392
# Epoch-124, Time-1.0182, Train-MSE-0.0000, Train-L2-0.0641, Test-L2-0.1428
# Epoch-125, Time-0.9724, Train-MSE-0.0000, Train-L2-0.0658, Test-L2-0.1368
# Epoch-126, Time-0.9925, Train-MSE-0.0000, Train-L2-0.0637, Test-L2-0.1390
# Epoch-127, Time-1.0228, Train-MSE-0.0000, Train-L2-0.0623, Test-L2-0.1368
# Epoch-128, Time-0.9721, Train-MSE-0.0000, Train-L2-0.0620, Test-L2-0.1387
# Epoch-129, Time-0.9682, Train-MSE-0.0000, Train-L2-0.0616, Test-L2-0.1421
# Epoch-130, Time-1.0465, Train-MSE-0.0000, Train-L2-0.0646, Test-L2-0.1383
# Epoch-131, Time-1.0183, Train-MSE-0.0000, Train-L2-0.0637, Test-L2-0.1417
# Epoch-132, Time-0.9219, Train-MSE-0.0000, Train-L2-0.0647, Test-L2-0.1358
# Epoch-133, Time-0.9931, Train-MSE-0.0000, Train-L2-0.0630, Test-L2-0.1385
# Epoch-134, Time-1.1133, Train-MSE-0.0000, Train-L2-0.0614, Test-L2-0.1368
# Epoch-135, Time-1.0752, Train-MSE-0.0000, Train-L2-0.0613, Test-L2-0.1386
# Epoch-136, Time-0.9685, Train-MSE-0.0000, Train-L2-0.0610, Test-L2-0.1427
# Epoch-137, Time-0.9778, Train-MSE-0.0000, Train-L2-0.0643, Test-L2-0.1381
# Epoch-138, Time-1.0045, Train-MSE-0.0000, Train-L2-0.0630, Test-L2-0.1424
# Epoch-139, Time-1.0290, Train-MSE-0.0000, Train-L2-0.0639, Test-L2-0.1356
# Epoch-140, Time-0.9635, Train-MSE-0.0000, Train-L2-0.0621, Test-L2-0.1389
# Epoch-141, Time-0.9900, Train-MSE-0.0000, Train-L2-0.0606, Test-L2-0.1359
# Epoch-142, Time-1.0192, Train-MSE-0.0000, Train-L2-0.0603, Test-L2-0.1381
# Epoch-143, Time-1.1024, Train-MSE-0.0000, Train-L2-0.0591, Test-L2-0.1412
# Epoch-144, Time-0.9766, Train-MSE-0.0000, Train-L2-0.0623, Test-L2-0.1384
# Epoch-145, Time-1.0257, Train-MSE-0.0000, Train-L2-0.0617, Test-L2-0.1424
# Epoch-146, Time-1.1794, Train-MSE-0.0000, Train-L2-0.0636, Test-L2-0.1361
# Epoch-147, Time-1.0094, Train-MSE-0.0000, Train-L2-0.0607, Test-L2-0.1388
# Epoch-148, Time-1.0613, Train-MSE-0.0000, Train-L2-0.0599, Test-L2-0.1359
# Epoch-149, Time-1.0303, Train-MSE-0.0000, Train-L2-0.0596, Test-L2-0.1369
# Epoch-150, Time-1.0558, Train-MSE-0.0000, Train-L2-0.0564, Test-L2-0.1374
# Epoch-151, Time-1.0385, Train-MSE-0.0000, Train-L2-0.0547, Test-L2-0.1337
# Epoch-152, Time-1.0190, Train-MSE-0.0000, Train-L2-0.0524, Test-L2-0.1367
# Epoch-153, Time-0.9562, Train-MSE-0.0000, Train-L2-0.0525, Test-L2-0.1342
# Epoch-154, Time-1.0349, Train-MSE-0.0000, Train-L2-0.0517, Test-L2-0.1365
# Epoch-155, Time-1.0400, Train-MSE-0.0000, Train-L2-0.0521, Test-L2-0.1342
# Epoch-156, Time-0.9722, Train-MSE-0.0000, Train-L2-0.0511, Test-L2-0.1354
# Epoch-157, Time-0.9498, Train-MSE-0.0000, Train-L2-0.0513, Test-L2-0.1330
# Epoch-158, Time-0.9550, Train-MSE-0.0000, Train-L2-0.0503, Test-L2-0.1338
# Epoch-159, Time-1.0514, Train-MSE-0.0000, Train-L2-0.0499, Test-L2-0.1320
# Epoch-160, Time-1.0832, Train-MSE-0.0000, Train-L2-0.0491, Test-L2-0.1322
# Epoch-161, Time-1.1384, Train-MSE-0.0000, Train-L2-0.0484, Test-L2-0.1323
# Epoch-162, Time-0.9374, Train-MSE-0.0000, Train-L2-0.0481, Test-L2-0.1320
# Epoch-163, Time-0.9688, Train-MSE-0.0000, Train-L2-0.0482, Test-L2-0.1339
# Epoch-164, Time-1.1104, Train-MSE-0.0000, Train-L2-0.0494, Test-L2-0.1321
# Epoch-165, Time-1.0591, Train-MSE-0.0000, Train-L2-0.0491, Test-L2-0.1335
# Epoch-166, Time-1.0185, Train-MSE-0.0000, Train-L2-0.0493, Test-L2-0.1311
# Epoch-167, Time-0.9950, Train-MSE-0.0000, Train-L2-0.0485, Test-L2-0.1320
# Epoch-168, Time-1.0012, Train-MSE-0.0000, Train-L2-0.0481, Test-L2-0.1318
# Epoch-169, Time-0.9513, Train-MSE-0.0000, Train-L2-0.0479, Test-L2-0.1318
# Epoch-170, Time-1.0316, Train-MSE-0.0000, Train-L2-0.0482, Test-L2-0.1344
# Epoch-171, Time-1.0302, Train-MSE-0.0000, Train-L2-0.0498, Test-L2-0.1316
# Epoch-172, Time-1.0156, Train-MSE-0.0000, Train-L2-0.0494, Test-L2-0.1340
# Epoch-173, Time-1.0070, Train-MSE-0.0000, Train-L2-0.0497, Test-L2-0.1304
# Epoch-174, Time-0.9858, Train-MSE-0.0000, Train-L2-0.0487, Test-L2-0.1322
# Epoch-175, Time-1.0187, Train-MSE-0.0000, Train-L2-0.0481, Test-L2-0.1309
# Epoch-176, Time-1.0304, Train-MSE-0.0000, Train-L2-0.0478, Test-L2-0.1316
# Epoch-177, Time-1.1904, Train-MSE-0.0000, Train-L2-0.0479, Test-L2-0.1339
# Epoch-178, Time-1.3220, Train-MSE-0.0000, Train-L2-0.0499, Test-L2-0.1317
# Epoch-179, Time-1.2731, Train-MSE-0.0000, Train-L2-0.0499, Test-L2-0.1344
# Epoch-180, Time-1.2013, Train-MSE-0.0000, Train-L2-0.0505, Test-L2-0.1305
# Epoch-181, Time-1.2148, Train-MSE-0.0000, Train-L2-0.0487, Test-L2-0.1325
# Epoch-182, Time-1.1857, Train-MSE-0.0000, Train-L2-0.0479, Test-L2-0.1303
# Epoch-183, Time-1.2013, Train-MSE-0.0000, Train-L2-0.0471, Test-L2-0.1312
# Epoch-184, Time-1.2421, Train-MSE-0.0000, Train-L2-0.0467, Test-L2-0.1328
# Epoch-185, Time-1.1883, Train-MSE-0.0000, Train-L2-0.0484, Test-L2-0.1316
# Epoch-186, Time-1.1307, Train-MSE-0.0000, Train-L2-0.0491, Test-L2-0.1342
# Epoch-187, Time-1.1393, Train-MSE-0.0000, Train-L2-0.0504, Test-L2-0.1301
# Epoch-188, Time-1.0114, Train-MSE-0.0000, Train-L2-0.0485, Test-L2-0.1322
# Epoch-189, Time-1.1395, Train-MSE-0.0000, Train-L2-0.0475, Test-L2-0.1297
# Epoch-190, Time-1.2069, Train-MSE-0.0000, Train-L2-0.0467, Test-L2-0.1314
# Epoch-191, Time-1.1138, Train-MSE-0.0000, Train-L2-0.0462, Test-L2-0.1325
# Epoch-192, Time-1.1892, Train-MSE-0.0000, Train-L2-0.0480, Test-L2-0.1317
# Epoch-193, Time-1.2370, Train-MSE-0.0000, Train-L2-0.0486, Test-L2-0.1344
# Epoch-194, Time-1.2468, Train-MSE-0.0000, Train-L2-0.0501, Test-L2-0.1301
# Epoch-195, Time-1.2305, Train-MSE-0.0000, Train-L2-0.0481, Test-L2-0.1326
# Epoch-196, Time-1.1802, Train-MSE-0.0000, Train-L2-0.0473, Test-L2-0.1293
# Epoch-197, Time-1.2284, Train-MSE-0.0000, Train-L2-0.0465, Test-L2-0.1310
# Epoch-198, Time-1.1201, Train-MSE-0.0000, Train-L2-0.0455, Test-L2-0.1308
# Epoch-199, Time-1.0419, Train-MSE-0.0000, Train-L2-0.0459, Test-L2-0.1316
# Epoch-200, Time-0.9995, Train-MSE-0.0000, Train-L2-0.0454, Test-L2-0.1323
# Epoch-201, Time-1.1057, Train-MSE-0.0000, Train-L2-0.0442, Test-L2-0.1288
# Epoch-202, Time-1.1004, Train-MSE-0.0000, Train-L2-0.0415, Test-L2-0.1312
# Epoch-203, Time-1.1510, Train-MSE-0.0000, Train-L2-0.0412, Test-L2-0.1290
# Epoch-204, Time-1.1273, Train-MSE-0.0000, Train-L2-0.0407, Test-L2-0.1304
# Epoch-205, Time-1.0832, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-0.1290
# Epoch-206, Time-1.1433, Train-MSE-0.0000, Train-L2-0.0402, Test-L2-0.1294
# Epoch-207, Time-1.1293, Train-MSE-0.0000, Train-L2-0.0400, Test-L2-0.1282
# Epoch-208, Time-1.0388, Train-MSE-0.0000, Train-L2-0.0393, Test-L2-0.1287
# Epoch-209, Time-1.0882, Train-MSE-0.0000, Train-L2-0.0389, Test-L2-0.1277
# Epoch-210, Time-1.0701, Train-MSE-0.0000, Train-L2-0.0384, Test-L2-0.1279
# Epoch-211, Time-1.0750, Train-MSE-0.0000, Train-L2-0.0381, Test-L2-0.1279
# Epoch-212, Time-1.1525, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-0.1276
# Epoch-213, Time-1.1182, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-0.1285
# Epoch-214, Time-1.0368, Train-MSE-0.0000, Train-L2-0.0384, Test-L2-0.1274
# Epoch-215, Time-1.0533, Train-MSE-0.0000, Train-L2-0.0384, Test-L2-0.1284
# Epoch-216, Time-1.1244, Train-MSE-0.0000, Train-L2-0.0384, Test-L2-0.1269
# Epoch-217, Time-1.0878, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-0.1276
# Epoch-218, Time-1.0773, Train-MSE-0.0000, Train-L2-0.0376, Test-L2-0.1270
# Epoch-219, Time-1.1260, Train-MSE-0.0000, Train-L2-0.0374, Test-L2-0.1275
# Epoch-220, Time-1.1662, Train-MSE-0.0000, Train-L2-0.0376, Test-L2-0.1282
# Epoch-221, Time-1.1340, Train-MSE-0.0000, Train-L2-0.0385, Test-L2-0.1272
# Epoch-222, Time-1.0847, Train-MSE-0.0000, Train-L2-0.0387, Test-L2-0.1282
# Epoch-223, Time-1.1261, Train-MSE-0.0000, Train-L2-0.0388, Test-L2-0.1263
# Epoch-224, Time-1.2013, Train-MSE-0.0000, Train-L2-0.0382, Test-L2-0.1277
# Epoch-225, Time-1.0531, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-0.1265
# Epoch-226, Time-1.1489, Train-MSE-0.0000, Train-L2-0.0380, Test-L2-0.1276
# Epoch-227, Time-1.1581, Train-MSE-0.0000, Train-L2-0.0385, Test-L2-0.1278
# Epoch-228, Time-1.1069, Train-MSE-0.0000, Train-L2-0.0396, Test-L2-0.1268
# Epoch-229, Time-1.0607, Train-MSE-0.0000, Train-L2-0.0395, Test-L2-0.1280
# Epoch-230, Time-1.1081, Train-MSE-0.0000, Train-L2-0.0393, Test-L2-0.1261
# Epoch-231, Time-1.0104, Train-MSE-0.0000, Train-L2-0.0387, Test-L2-0.1275
# Epoch-232, Time-1.1618, Train-MSE-0.0000, Train-L2-0.0382, Test-L2-0.1266
# Epoch-233, Time-1.0810, Train-MSE-0.0000, Train-L2-0.0382, Test-L2-0.1272
# Epoch-234, Time-1.0731, Train-MSE-0.0000, Train-L2-0.0382, Test-L2-0.1283
# Epoch-235, Time-1.1085, Train-MSE-0.0000, Train-L2-0.0391, Test-L2-0.1265
# Epoch-236, Time-0.9915, Train-MSE-0.0000, Train-L2-0.0389, Test-L2-0.1285
# Epoch-237, Time-0.9748, Train-MSE-0.0000, Train-L2-0.0390, Test-L2-0.1255
# Epoch-238, Time-1.0036, Train-MSE-0.0000, Train-L2-0.0383, Test-L2-0.1276
# Epoch-239, Time-1.0372, Train-MSE-0.0000, Train-L2-0.0377, Test-L2-0.1257
# Epoch-240, Time-1.0831, Train-MSE-0.0000, Train-L2-0.0376, Test-L2-0.1276
# Epoch-241, Time-1.0331, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-0.1278
# Epoch-242, Time-0.9685, Train-MSE-0.0000, Train-L2-0.0395, Test-L2-0.1270
# Epoch-243, Time-1.1196, Train-MSE-0.0000, Train-L2-0.0393, Test-L2-0.1282
# Epoch-244, Time-1.0207, Train-MSE-0.0000, Train-L2-0.0394, Test-L2-0.1258
# Epoch-245, Time-0.9545, Train-MSE-0.0000, Train-L2-0.0383, Test-L2-0.1272
# Epoch-246, Time-1.0751, Train-MSE-0.0000, Train-L2-0.0376, Test-L2-0.1256
# Epoch-247, Time-1.1181, Train-MSE-0.0000, Train-L2-0.0370, Test-L2-0.1269
# Epoch-248, Time-1.1066, Train-MSE-0.0000, Train-L2-0.0369, Test-L2-0.1274
# Epoch-249, Time-1.0685, Train-MSE-0.0000, Train-L2-0.0383, Test-L2-0.1271
# Epoch-250, Time-1.0528, Train-MSE-0.0000, Train-L2-0.0377, Test-L2-0.1279
# Epoch-251, Time-1.0550, Train-MSE-0.0000, Train-L2-0.0357, Test-L2-0.1253
# Epoch-252, Time-1.0674, Train-MSE-0.0000, Train-L2-0.0340, Test-L2-0.1268
# Epoch-253, Time-1.0643, Train-MSE-0.0000, Train-L2-0.0338, Test-L2-0.1254
# Epoch-254, Time-1.1006, Train-MSE-0.0000, Train-L2-0.0335, Test-L2-0.1260
# Epoch-255, Time-1.2023, Train-MSE-0.0000, Train-L2-0.0335, Test-L2-0.1253
# Epoch-256, Time-1.1725, Train-MSE-0.0000, Train-L2-0.0330, Test-L2-0.1256
# Epoch-257, Time-1.1395, Train-MSE-0.0000, Train-L2-0.0327, Test-L2-0.1249
# Epoch-258, Time-1.0410, Train-MSE-0.0000, Train-L2-0.0322, Test-L2-0.1252
# Epoch-259, Time-1.0245, Train-MSE-0.0000, Train-L2-0.0320, Test-L2-0.1248
# Epoch-260, Time-0.9293, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.1248
# Epoch-261, Time-0.9401, Train-MSE-0.0000, Train-L2-0.0316, Test-L2-0.1249
# Epoch-262, Time-0.9944, Train-MSE-0.0000, Train-L2-0.0316, Test-L2-0.1246
# Epoch-263, Time-1.1268, Train-MSE-0.0000, Train-L2-0.0315, Test-L2-0.1250
# Epoch-264, Time-0.9768, Train-MSE-0.0000, Train-L2-0.0316, Test-L2-0.1244
# Epoch-265, Time-1.0639, Train-MSE-0.0000, Train-L2-0.0315, Test-L2-0.1249
# Epoch-266, Time-1.0771, Train-MSE-0.0000, Train-L2-0.0315, Test-L2-0.1243
# Epoch-267, Time-1.1830, Train-MSE-0.0000, Train-L2-0.0313, Test-L2-0.1246
# Epoch-268, Time-1.1581, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1244
# Epoch-269, Time-1.1486, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-0.1243
# Epoch-270, Time-1.1505, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-0.1247
# Epoch-271, Time-1.1828, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1240
# Epoch-272, Time-1.1096, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1247
# Epoch-273, Time-1.1335, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1237
# Epoch-274, Time-1.1289, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-0.1244
# Epoch-275, Time-1.1009, Train-MSE-0.0000, Train-L2-0.0310, Test-L2-0.1239
# Epoch-276, Time-1.2032, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-0.1244
# Epoch-277, Time-1.0634, Train-MSE-0.0000, Train-L2-0.0314, Test-L2-0.1244
# Epoch-278, Time-1.1446, Train-MSE-0.0000, Train-L2-0.0319, Test-L2-0.1240
# Epoch-279, Time-1.1474, Train-MSE-0.0000, Train-L2-0.0319, Test-L2-0.1244
# Epoch-280, Time-1.1556, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.1237
# Epoch-281, Time-0.9947, Train-MSE-0.0000, Train-L2-0.0314, Test-L2-0.1241
# Epoch-282, Time-1.0425, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1240
# Epoch-283, Time-0.9283, Train-MSE-0.0000, Train-L2-0.0314, Test-L2-0.1241
# Epoch-284, Time-0.9458, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.1247
# Epoch-285, Time-0.9134, Train-MSE-0.0000, Train-L2-0.0322, Test-L2-0.1235
# Epoch-286, Time-0.9676, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.1246
# Epoch-287, Time-0.9763, Train-MSE-0.0000, Train-L2-0.0314, Test-L2-0.1233
# Epoch-288, Time-1.0005, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-0.1245
# Epoch-289, Time-1.0513, Train-MSE-0.0000, Train-L2-0.0313, Test-L2-0.1240
# Epoch-290, Time-1.1106, Train-MSE-0.0000, Train-L2-0.0322, Test-L2-0.1242
# Epoch-291, Time-1.0756, Train-MSE-0.0000, Train-L2-0.0325, Test-L2-0.1245
# Epoch-292, Time-1.0567, Train-MSE-0.0000, Train-L2-0.0324, Test-L2-0.1234
# Epoch-293, Time-0.9432, Train-MSE-0.0000, Train-L2-0.0317, Test-L2-0.1243
# Epoch-294, Time-0.9591, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1235
# Epoch-295, Time-1.0073, Train-MSE-0.0000, Train-L2-0.0312, Test-L2-0.1242
# Epoch-296, Time-0.9215, Train-MSE-0.0000, Train-L2-0.0315, Test-L2-0.1244
# Epoch-297, Time-0.9260, Train-MSE-0.0000, Train-L2-0.0323, Test-L2-0.1236
# Epoch-298, Time-0.9403, Train-MSE-0.0000, Train-L2-0.0321, Test-L2-0.1246
# Epoch-299, Time-1.0329, Train-MSE-0.0000, Train-L2-0.0318, Test-L2-0.1229
# Epoch-300, Time-0.9423, Train-MSE-0.0000, Train-L2-0.0306, Test-L2-0.1242
# Epoch-301, Time-1.0253, Train-MSE-0.0000, Train-L2-0.0295, Test-L2-0.1231
# Epoch-302, Time-0.9343, Train-MSE-0.0000, Train-L2-0.0289, Test-L2-0.1229
# Epoch-303, Time-0.9916, Train-MSE-0.0000, Train-L2-0.0287, Test-L2-0.1237
# Epoch-304, Time-0.9986, Train-MSE-0.0000, Train-L2-0.0286, Test-L2-0.1226
# Epoch-305, Time-0.9323, Train-MSE-0.0000, Train-L2-0.0284, Test-L2-0.1236
# Epoch-306, Time-1.0247, Train-MSE-0.0000, Train-L2-0.0284, Test-L2-0.1228
# Epoch-307, Time-0.9648, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.1233
# Epoch-308, Time-0.9996, Train-MSE-0.0000, Train-L2-0.0283, Test-L2-0.1228
# Epoch-309, Time-0.9131, Train-MSE-0.0000, Train-L2-0.0281, Test-L2-0.1232
# Epoch-310, Time-1.0007, Train-MSE-0.0000, Train-L2-0.0281, Test-L2-0.1226
# Epoch-311, Time-0.9603, Train-MSE-0.0000, Train-L2-0.0279, Test-L2-0.1231
# Epoch-312, Time-1.0359, Train-MSE-0.0000, Train-L2-0.0278, Test-L2-0.1226
# Epoch-313, Time-0.9655, Train-MSE-0.0000, Train-L2-0.0276, Test-L2-0.1229
# Epoch-314, Time-0.9298, Train-MSE-0.0000, Train-L2-0.0276, Test-L2-0.1225
# Epoch-315, Time-0.9186, Train-MSE-0.0000, Train-L2-0.0274, Test-L2-0.1227
# Epoch-316, Time-1.0249, Train-MSE-0.0000, Train-L2-0.0273, Test-L2-0.1225
# Epoch-317, Time-0.9986, Train-MSE-0.0000, Train-L2-0.0272, Test-L2-0.1225
# Epoch-318, Time-0.9244, Train-MSE-0.0000, Train-L2-0.0271, Test-L2-0.1226
# Epoch-319, Time-0.9586, Train-MSE-0.0000, Train-L2-0.0271, Test-L2-0.1224
# Epoch-320, Time-1.0013, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.1226
# Epoch-321, Time-1.0022, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.1223
# Epoch-322, Time-0.9586, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.1224
# Epoch-323, Time-0.9721, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.1223
# Epoch-324, Time-0.9641, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1223
# Epoch-325, Time-1.0147, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1224
# Epoch-326, Time-0.9704, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1221
# Epoch-327, Time-1.0011, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1225
# Epoch-328, Time-0.9225, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1219
# Epoch-329, Time-1.0639, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1224
# Epoch-330, Time-1.0785, Train-MSE-0.0000, Train-L2-0.0266, Test-L2-0.1219
# Epoch-331, Time-1.0759, Train-MSE-0.0000, Train-L2-0.0265, Test-L2-0.1222
# Epoch-332, Time-1.1362, Train-MSE-0.0000, Train-L2-0.0265, Test-L2-0.1220
# Epoch-333, Time-1.1628, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1220
# Epoch-334, Time-1.1811, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1222
# Epoch-335, Time-1.2830, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1218
# Epoch-336, Time-1.0939, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1221
# Epoch-337, Time-1.1654, Train-MSE-0.0000, Train-L2-0.0266, Test-L2-0.1219
# Epoch-338, Time-1.0807, Train-MSE-0.0000, Train-L2-0.0266, Test-L2-0.1220
# Epoch-339, Time-0.9107, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1222
# Epoch-340, Time-1.0658, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.1217
# Epoch-341, Time-1.0560, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.1223
# Epoch-342, Time-1.1809, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1215
# Epoch-343, Time-1.2319, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1224
# Epoch-344, Time-1.0059, Train-MSE-0.0000, Train-L2-0.0268, Test-L2-0.1218
# Epoch-345, Time-1.0270, Train-MSE-0.0000, Train-L2-0.0272, Test-L2-0.1222
# Epoch-346, Time-1.1838, Train-MSE-0.0000, Train-L2-0.0274, Test-L2-0.1219
# Epoch-347, Time-1.1058, Train-MSE-0.0000, Train-L2-0.0275, Test-L2-0.1217
# Epoch-348, Time-1.0967, Train-MSE-0.0000, Train-L2-0.0271, Test-L2-0.1220
# Epoch-349, Time-0.9441, Train-MSE-0.0000, Train-L2-0.0269, Test-L2-0.1218
# Epoch-350, Time-0.9482, Train-MSE-0.0000, Train-L2-0.0267, Test-L2-0.1219
# Epoch-351, Time-0.9564, Train-MSE-0.0000, Train-L2-0.0262, Test-L2-0.1220
# Epoch-352, Time-1.0541, Train-MSE-0.0000, Train-L2-0.0258, Test-L2-0.1213
# Epoch-353, Time-0.9610, Train-MSE-0.0000, Train-L2-0.0255, Test-L2-0.1219
# Epoch-354, Time-0.9444, Train-MSE-0.0000, Train-L2-0.0255, Test-L2-0.1214
# Epoch-355, Time-1.0363, Train-MSE-0.0000, Train-L2-0.0254, Test-L2-0.1217
# Epoch-356, Time-1.0388, Train-MSE-0.0000, Train-L2-0.0254, Test-L2-0.1214
# Epoch-357, Time-0.9577, Train-MSE-0.0000, Train-L2-0.0252, Test-L2-0.1217
# Epoch-358, Time-0.9174, Train-MSE-0.0000, Train-L2-0.0251, Test-L2-0.1213
# Epoch-359, Time-0.9248, Train-MSE-0.0000, Train-L2-0.0250, Test-L2-0.1216
# Epoch-360, Time-1.1627, Train-MSE-0.0000, Train-L2-0.0249, Test-L2-0.1212
# Epoch-361, Time-1.1203, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.1215
# Epoch-362, Time-0.9240, Train-MSE-0.0000, Train-L2-0.0248, Test-L2-0.1212
# Epoch-363, Time-1.0178, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-0.1214
# Epoch-364, Time-1.3078, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-0.1212
# Epoch-365, Time-1.0690, Train-MSE-0.0000, Train-L2-0.0246, Test-L2-0.1212
# Epoch-366, Time-1.0435, Train-MSE-0.0000, Train-L2-0.0245, Test-L2-0.1212
# Epoch-367, Time-1.0834, Train-MSE-0.0000, Train-L2-0.0245, Test-L2-0.1211
# Epoch-368, Time-1.1126, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.1212
# Epoch-369, Time-1.0797, Train-MSE-0.0000, Train-L2-0.0244, Test-L2-0.1210
# Epoch-370, Time-1.0284, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.1212
# Epoch-371, Time-1.0291, Train-MSE-0.0000, Train-L2-0.0243, Test-L2-0.1210
# Epoch-372, Time-0.9819, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.1212
# Epoch-373, Time-1.0048, Train-MSE-0.0000, Train-L2-0.0242, Test-L2-0.1210
# Epoch-374, Time-1.0010, Train-MSE-0.0000, Train-L2-0.0241, Test-L2-0.1210
# Epoch-375, Time-1.0139, Train-MSE-0.0000, Train-L2-0.0241, Test-L2-0.1210
# Epoch-376, Time-1.2923, Train-MSE-0.0000, Train-L2-0.0241, Test-L2-0.1209
# Epoch-377, Time-1.1178, Train-MSE-0.0000, Train-L2-0.0240, Test-L2-0.1210
# Epoch-378, Time-1.1999, Train-MSE-0.0000, Train-L2-0.0240, Test-L2-0.1208
# Epoch-379, Time-1.2872, Train-MSE-0.0000, Train-L2-0.0240, Test-L2-0.1210
# Epoch-380, Time-0.9737, Train-MSE-0.0000, Train-L2-0.0239, Test-L2-0.1207
# Epoch-381, Time-0.9496, Train-MSE-0.0000, Train-L2-0.0239, Test-L2-0.1210
# Epoch-382, Time-0.9191, Train-MSE-0.0000, Train-L2-0.0239, Test-L2-0.1207
# Epoch-383, Time-0.9996, Train-MSE-0.0000, Train-L2-0.0238, Test-L2-0.1209
# Epoch-384, Time-1.1268, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.1207
# Epoch-385, Time-0.9665, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.1208
# Epoch-386, Time-1.0067, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.1208
# Epoch-387, Time-0.9986, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.1207
# Epoch-388, Time-1.0961, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-0.1208
# Epoch-389, Time-0.9936, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-0.1206
# Epoch-390, Time-0.9501, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-0.1208
# Epoch-391, Time-1.0855, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1205
# Epoch-392, Time-1.1100, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1208
# Epoch-393, Time-1.0914, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1205
# Epoch-394, Time-1.0802, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1207
# Epoch-395, Time-1.0299, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1205
# Epoch-396, Time-1.0330, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1206
# Epoch-397, Time-0.9989, Train-MSE-0.0000, Train-L2-0.0235, Test-L2-0.1205
# Epoch-398, Time-0.9492, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-0.1207
# Epoch-399, Time-0.9876, Train-MSE-0.0000, Train-L2-0.0238, Test-L2-0.1204
# Epoch-400, Time-1.1073, Train-MSE-0.0000, Train-L2-0.0237, Test-L2-0.1208
# Epoch-401, Time-0.9829, Train-MSE-0.0000, Train-L2-0.0234, Test-L2-0.1203
# Epoch-402, Time-1.0199, Train-MSE-0.0000, Train-L2-0.0231, Test-L2-0.1206
# Epoch-403, Time-1.0321, Train-MSE-0.0000, Train-L2-0.0231, Test-L2-0.1204
# Epoch-404, Time-1.0466, Train-MSE-0.0000, Train-L2-0.0230, Test-L2-0.1204
# Epoch-405, Time-1.0126, Train-MSE-0.0000, Train-L2-0.0230, Test-L2-0.1204
# Epoch-406, Time-0.9901, Train-MSE-0.0000, Train-L2-0.0229, Test-L2-0.1204
# Epoch-407, Time-0.9793, Train-MSE-0.0000, Train-L2-0.0228, Test-L2-0.1203
# Epoch-408, Time-0.9549, Train-MSE-0.0000, Train-L2-0.0228, Test-L2-0.1204
# Epoch-409, Time-1.0449, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.1203
# Epoch-410, Time-0.9762, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.1204
# Epoch-411, Time-0.9640, Train-MSE-0.0000, Train-L2-0.0227, Test-L2-0.1203
# Epoch-412, Time-1.0303, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.1203
# Epoch-413, Time-1.1261, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.1202
# Epoch-414, Time-1.0184, Train-MSE-0.0000, Train-L2-0.0226, Test-L2-0.1203
# Epoch-415, Time-1.0396, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.1202
# Epoch-416, Time-1.0305, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.1202
# Epoch-417, Time-1.1392, Train-MSE-0.0000, Train-L2-0.0225, Test-L2-0.1202
# Epoch-418, Time-1.1807, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.1202
# Epoch-419, Time-1.0699, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.1202
# Epoch-420, Time-1.0840, Train-MSE-0.0000, Train-L2-0.0224, Test-L2-0.1202
# Epoch-421, Time-1.0813, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.1201
# Epoch-422, Time-1.0523, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.1201
# Epoch-423, Time-0.9563, Train-MSE-0.0000, Train-L2-0.0223, Test-L2-0.1201
# Epoch-424, Time-0.9735, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.1201
# Epoch-425, Time-1.1042, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.1201
# Epoch-426, Time-1.0103, Train-MSE-0.0000, Train-L2-0.0222, Test-L2-0.1201
# Epoch-427, Time-0.8884, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.1200
# Epoch-428, Time-1.2962, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.1201
# Epoch-429, Time-1.0199, Train-MSE-0.0000, Train-L2-0.0221, Test-L2-0.1200
# Epoch-430, Time-1.0080, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.1200
# Epoch-431, Time-0.9648, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.1200
# Epoch-432, Time-1.0255, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.1200
# Epoch-433, Time-1.0531, Train-MSE-0.0000, Train-L2-0.0220, Test-L2-0.1199
# Epoch-434, Time-1.0334, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.1200
# Epoch-435, Time-0.9535, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.1199
# Epoch-436, Time-1.0607, Train-MSE-0.0000, Train-L2-0.0219, Test-L2-0.1199
# Epoch-437, Time-1.0905, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.1199
# Epoch-438, Time-1.0427, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.1199
# Epoch-439, Time-1.0491, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.1199
# Epoch-440, Time-0.9946, Train-MSE-0.0000, Train-L2-0.0217, Test-L2-0.1199
# Epoch-441, Time-1.0762, Train-MSE-0.0000, Train-L2-0.0217, Test-L2-0.1199
# Epoch-442, Time-0.9725, Train-MSE-0.0000, Train-L2-0.0217, Test-L2-0.1198
# Epoch-443, Time-0.9321, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.1198
# Epoch-444, Time-0.9314, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.1198
# Epoch-445, Time-0.9862, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.1198
# Epoch-446, Time-0.9578, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-0.1198
# Epoch-447, Time-0.9956, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.1198
# Epoch-448, Time-0.9541, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.1197
# Epoch-449, Time-1.0658, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.1197
# Epoch-450, Time-1.0007, Train-MSE-0.0000, Train-L2-0.0214, Test-L2-0.1197
# Epoch-451, Time-1.0071, Train-MSE-0.0000, Train-L2-0.0214, Test-L2-0.1197
# Epoch-452, Time-0.9979, Train-MSE-0.0000, Train-L2-0.0214, Test-L2-0.1197
# Epoch-453, Time-0.9343, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.1197
# Epoch-454, Time-1.0388, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.1197
# Epoch-455, Time-0.9716, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.1197
# Epoch-456, Time-0.9567, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.1197
# Epoch-457, Time-0.9217, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.1196
# Epoch-458, Time-1.0295, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.1196
# Epoch-459, Time-0.9361, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.1196
# Epoch-460, Time-0.9368, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.1196
# Epoch-461, Time-1.0485, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.1196
# Epoch-462, Time-1.1306, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.1196
# Epoch-463, Time-1.0421, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.1196
# Epoch-464, Time-1.0447, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.1196
# Epoch-465, Time-1.0989, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.1196
# Epoch-466, Time-1.1846, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.1195
# Epoch-467, Time-0.9276, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.1195
# Epoch-468, Time-0.9072, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.1195
# Epoch-469, Time-0.9270, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.1195
# Epoch-470, Time-0.9562, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.1195
# Epoch-471, Time-0.9660, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.1195
# Epoch-472, Time-0.9208, Train-MSE-0.0000, Train-L2-0.0209, Test-L2-0.1195
# Epoch-473, Time-0.9455, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.1195
# Epoch-474, Time-0.9483, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.1195
# Epoch-475, Time-1.0877, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.1195
# Epoch-476, Time-0.9202, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.1194
# Epoch-477, Time-0.9645, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.1194
# Epoch-478, Time-0.9404, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.1194
# Epoch-479, Time-0.9787, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.1194
# Epoch-480, Time-1.1032, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-0.1194
# Epoch-481, Time-1.0373, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.1194
# Epoch-482, Time-1.0849, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.1194
# Epoch-483, Time-1.1162, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.1194
# Epoch-484, Time-1.1032, Train-MSE-0.0000, Train-L2-0.0206, Test-L2-0.1194
# Epoch-485, Time-1.0764, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.1193
# Epoch-486, Time-1.0177, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.1193
# Epoch-487, Time-0.9678, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.1193
# Epoch-488, Time-0.9234, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.1193
# Epoch-489, Time-0.9027, Train-MSE-0.0000, Train-L2-0.0205, Test-L2-0.1193
# Epoch-490, Time-0.9238, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.1193
# Epoch-491, Time-0.9742, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.1193
# Epoch-492, Time-1.0446, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.1193
# Epoch-493, Time-0.9863, Train-MSE-0.0000, Train-L2-0.0204, Test-L2-0.1193
# Epoch-494, Time-0.9456, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.1193
# Epoch-495, Time-0.9724, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.1193
# Epoch-496, Time-1.0131, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.1192
# Epoch-497, Time-0.9293, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.1192
# Epoch-498, Time-0.9152, Train-MSE-0.0000, Train-L2-0.0203, Test-L2-0.1192
# Epoch-499, Time-0.9963, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.1192

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_Darcy2D_20')

# %%
# Prediction:
pred_mf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x, y = x.to(device), y.to(device)
        
        out = model_mf(x).reshape(x.shape[0], s, s)
        out = y_normalizer.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_mf.append(out.cpu())
        index += 1

pred_mf = torch.cat(( pred_mf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
# Add the residual operator to LF-dataset 
input_mf = x_normalizer_mf.decode( x_test_mf.cpu() ) 

real_mf = y_test_mf + input_mf[..., 1]
output_mf = pred_mf + input_mf[..., 1]

# %%
print(real_mf.shape, output_mf.shape)

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()
mse_LF = F.mse_loss(real_mf, x_test_mf[..., 1])
mse_residual = F.mse_loss(y_test_mf, pred_mf)

print('MSE-Predicted solution-{:0.4f}, MSE-LF Data-{:0.4f}, MSE-Residual-{:0.4f}'
      .format(mse_pred, mse_LF, mse_residual))

# %%
fig1, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig1.subplots_adjust(hspace=0.35, wspace=0.2)

fig1.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(real_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample, :, :], cmap='nipy_spectral', origin='lower' )
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(real_mf[sample, :, :] - output_mf[sample, :, :]),
                                    cmap='jet', origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %% [markdown]
# # High Fidelity

# %%
class WaveConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv2d, self).__init__()

        """
        2D Wavelet layer. It does DWT, linear transform, and Inverse dWT. 
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet       
        dummy_data = torch.randn( 1,1,*size )        
        dwt_ = DWT(J=self.level, mode='symmetric', wave=self.wavelet)
        mode_data, mode_coef = dwt_(dummy_data)
        self.modes1 = mode_data.shape[-2]
        self.modes2 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels * out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights3 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))
        self.weights4 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1, self.modes2))

    # Convolution
    def mul2d(self, input, weights):
        # (batch, in_channel, x,y ), (in_channel, out_channel, x,y) -> (batch, out_channel, x,y)
        return torch.einsum("bixy,ioxy->boxy", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x * y]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x * y]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet
        dwt = DWT(J=self.level, mode='symmetric', wave=self.wavelet).to(x.device)
        x_ft, x_coeff = dwt(x)

        # Multiply the final approximate Wavelet modes
        out_ft = self.mul2d(x_ft, self.weights1)
        # Multiply the final detailed wavelet coefficients
        x_coeff[-1][:,:,0,:,:] = self.mul2d(x_coeff[-1][:,:,0,:,:].clone(), self.weights2)
        x_coeff[-1][:,:,1,:,:] = self.mul2d(x_coeff[-1][:,:,1,:,:].clone(), self.weights3)
        x_coeff[-1][:,:,2,:,:] = self.mul2d(x_coeff[-1][:,:,2,:,:].clone(), self.weights4)
        
        # Return to physical space        
        idwt = IDWT(mode='symmetric', wave=self.wavelet).to(x.device)
        x = idwt((out_ft, x_coeff))
        return x

# %%
class WNO2d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO2d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the coefficient function and locations (a(x, y), x, y)
        input shape: (batchsize, x=s, y=s, c=3)
        output: the solution 
        output shape: (batchsize, x=s, y=s, c=1)
        """
        
        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 1
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 3: (a(x, y), x, y)

        self.conv0 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv2d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv2d(self.width, self.width, 1)
        self.w1 = nn.Conv2d(self.width, self.width, 1)
        self.w2 = nn.Conv2d(self.width, self.width, 1)
        self.w3 = nn.Conv2d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)

        x = self.fc0(x)
        x = x.permute(0, 3, 1, 2)
        x = F.pad(x, [0,self.padding, 0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        x = x[..., :-self.padding, :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 3, 1)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)
        return x
    
    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x, size_y = shape[0], shape[1], shape[2]
        gridx = torch.tensor(np.linspace(0, self.grid_range[0], size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1, 1).repeat([batchsize, 1, size_y, 1])
        gridy = torch.tensor(np.linspace(0, self.grid_range[1], size_y), dtype=torch.float)
        gridy = gridy.reshape(1, 1, size_y, 1).repeat([batchsize, size_x, 1, 1])
        return torch.cat((gridx, gridy), dim=-1).to(device)

# %%
ntrain = ntrain
ntest = ntest
n_total = ntrain + ntest
batch_size = batch_size
learning_rate = 0.001

wavelet = 'db6'  # wavelet basis function
level = 2        # lavel of wavelet decomposition
width = 64       # uplifting dimension
grid_range = [1, 1]
in_channel = 3

epochs = 250
step_size = 50
gamma = 0.75

r = 2
h = int(((101 - 1)/r) + 1)
s = h

# %%
# Create the input and output (residual) dataset
x_hf = torch.tensor( x_or_h, dtype=torch.float ) 
y_hf = torch.tensor( y_or_h, dtype=torch.float ) 
    
generator_hf = torch.Generator().manual_seed(453)
dataset_hf = torch.utils.data.random_split(torch.utils.data.TensorDataset(x_hf, y_hf),
                                    [ntrain, ntest], generator=generator)
train_data_hf, test_data_hf = dataset_hf[0], dataset_hf[1]

# Split the training and testing datasets
x_train_hf, y_train_hf = train_data_hf[:][0], train_data_hf[:][1]
x_test_hf, y_test_hf = test_data_hf[:][0], test_data_hf[:][1]

x_normalizer_hf = UnitGaussianNormalizer(x_train_hf)
x_train_hf = x_normalizer_hf.encode(x_train_hf)
x_test_hf = x_normalizer_hf.encode(x_test_hf)

y_normalizer_hf = UnitGaussianNormalizer(y_train_hf)
y_train_hf = y_normalizer_hf.encode(y_train_hf)

# Define the dataloaders
train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                             batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, y_test_hf),
                                            batch_size=batch_size, shuffle=False)

# %%
model = WNO2d(width=width, level=level, size=[s,s], wavelet=wavelet,
              in_channel=in_channel, grid_range=grid_range).to(device)
print(count_params(model))

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-6)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
y_normalizer_hf.to(device)
for ep in range(epochs):
    model.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()
        out = model(x).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        y = y_normalizer_hf.decode(y)
        
        mse = F.mse_loss(out.view(x.shape[0], -1), y.view(x.shape[0], -1), reduction='mean')
        loss = myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1))
        loss.backward()
        optimizer.step()
        
        train_mse += mse.item()
        train_l2 += loss.item()
    
    scheduler.step()
    model.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.to(device), y.to(device)

            out = model(x).reshape(x.shape[0], s, s)
            out = y_normalizer_hf.decode(out)

            test_l2 += myloss(out.view(x.shape[0],-1), y.view(x.shape[0],-1)).item()

    train_mse /= len(train_loader_hf)
    train_l2/= ntrain
    test_l2 /= ntest
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-113, Time-0.7404, Train-MSE-0.0036, Train-L2-0.0879, Test-L2-0.2990
# Epoch-114, Time-0.6728, Train-MSE-0.0030, Train-L2-0.0819, Test-L2-0.3121
# Epoch-115, Time-0.6540, Train-MSE-0.0033, Train-L2-0.0889, Test-L2-0.2980
# Epoch-116, Time-0.6021, Train-MSE-0.0030, Train-L2-0.0814, Test-L2-0.3062
# Epoch-117, Time-0.6277, Train-MSE-0.0029, Train-L2-0.0854, Test-L2-0.3025
# Epoch-118, Time-0.6134, Train-MSE-0.0035, Train-L2-0.0853, Test-L2-0.3036
# Epoch-119, Time-0.6241, Train-MSE-0.0024, Train-L2-0.0759, Test-L2-0.3034
# Epoch-120, Time-0.6162, Train-MSE-0.0025, Train-L2-0.0767, Test-L2-0.2976
# Epoch-121, Time-0.6809, Train-MSE-0.0020, Train-L2-0.0706, Test-L2-0.2922
# Epoch-122, Time-0.7502, Train-MSE-0.0019, Train-L2-0.0645, Test-L2-0.3039
# Epoch-123, Time-0.6989, Train-MSE-0.0019, Train-L2-0.0640, Test-L2-0.2913
# Epoch-124, Time-0.6091, Train-MSE-0.0022, Train-L2-0.0642, Test-L2-0.2968
# Epoch-125, Time-0.6033, Train-MSE-0.0016, Train-L2-0.0590, Test-L2-0.2950
# Epoch-126, Time-0.6226, Train-MSE-0.0014, Train-L2-0.0558, Test-L2-0.2930
# Epoch-127, Time-0.5994, Train-MSE-0.0014, Train-L2-0.0549, Test-L2-0.2931
# Epoch-128, Time-0.6058, Train-MSE-0.0015, Train-L2-0.0573, Test-L2-0.2931
# Epoch-129, Time-0.6587, Train-MSE-0.0015, Train-L2-0.0573, Test-L2-0.2890
# Epoch-130, Time-0.6421, Train-MSE-0.0015, Train-L2-0.0568, Test-L2-0.2951
# Epoch-131, Time-0.5953, Train-MSE-0.0015, Train-L2-0.0572, Test-L2-0.2953
# Epoch-132, Time-0.6515, Train-MSE-0.0014, Train-L2-0.0550, Test-L2-0.2884
# Epoch-133, Time-0.6778, Train-MSE-0.0015, Train-L2-0.0561, Test-L2-0.2926
# Epoch-134, Time-0.5974, Train-MSE-0.0013, Train-L2-0.0523, Test-L2-0.2893
# Epoch-135, Time-0.6298, Train-MSE-0.0013, Train-L2-0.0553, Test-L2-0.2947
# Epoch-136, Time-0.6659, Train-MSE-0.0014, Train-L2-0.0572, Test-L2-0.2933
# Epoch-137, Time-0.6842, Train-MSE-0.0013, Train-L2-0.0551, Test-L2-0.2879
# Epoch-138, Time-0.6279, Train-MSE-0.0012, Train-L2-0.0532, Test-L2-0.2915
# Epoch-139, Time-0.6379, Train-MSE-0.0012, Train-L2-0.0512, Test-L2-0.2939
# Epoch-140, Time-0.6291, Train-MSE-0.0012, Train-L2-0.0515, Test-L2-0.2931
# Epoch-141, Time-0.5859, Train-MSE-0.0028, Train-L2-0.0658, Test-L2-0.2879
# Epoch-142, Time-0.5869, Train-MSE-0.0018, Train-L2-0.0584, Test-L2-0.2928
# Epoch-143, Time-0.5962, Train-MSE-0.0013, Train-L2-0.0550, Test-L2-0.2913
# Epoch-144, Time-0.5899, Train-MSE-0.0016, Train-L2-0.0580, Test-L2-0.2898
# Epoch-145, Time-0.5890, Train-MSE-0.0011, Train-L2-0.0511, Test-L2-0.2855
# Epoch-146, Time-0.6616, Train-MSE-0.0010, Train-L2-0.0478, Test-L2-0.2867
# Epoch-147, Time-0.5948, Train-MSE-0.0011, Train-L2-0.0493, Test-L2-0.2882
# Epoch-148, Time-0.6727, Train-MSE-0.0009, Train-L2-0.0454, Test-L2-0.2936
# Epoch-149, Time-0.6447, Train-MSE-0.0016, Train-L2-0.0531, Test-L2-0.2923
# Epoch-150, Time-0.5851, Train-MSE-0.0011, Train-L2-0.0488, Test-L2-0.2883
# Epoch-151, Time-0.6239, Train-MSE-0.0011, Train-L2-0.0476, Test-L2-0.2856
# Epoch-152, Time-0.6165, Train-MSE-0.0009, Train-L2-0.0435, Test-L2-0.2866
# Epoch-153, Time-0.6327, Train-MSE-0.0008, Train-L2-0.0419, Test-L2-0.2882
# Epoch-154, Time-0.6291, Train-MSE-0.0008, Train-L2-0.0414, Test-L2-0.2843
# Epoch-155, Time-0.5896, Train-MSE-0.0007, Train-L2-0.0388, Test-L2-0.2865
# Epoch-156, Time-0.5980, Train-MSE-0.0007, Train-L2-0.0393, Test-L2-0.2868
# Epoch-157, Time-0.5891, Train-MSE-0.0008, Train-L2-0.0400, Test-L2-0.2828
# Epoch-158, Time-0.6225, Train-MSE-0.0007, Train-L2-0.0375, Test-L2-0.2843
# Epoch-159, Time-0.6653, Train-MSE-0.0006, Train-L2-0.0360, Test-L2-0.2867
# Epoch-160, Time-0.7050, Train-MSE-0.0006, Train-L2-0.0365, Test-L2-0.2817
# Epoch-161, Time-0.5925, Train-MSE-0.0006, Train-L2-0.0365, Test-L2-0.2824
# Epoch-162, Time-0.6078, Train-MSE-0.0006, Train-L2-0.0360, Test-L2-0.2843
# Epoch-163, Time-0.5988, Train-MSE-0.0006, Train-L2-0.0360, Test-L2-0.2810
# Epoch-164, Time-0.6085, Train-MSE-0.0006, Train-L2-0.0378, Test-L2-0.2819
# Epoch-165, Time-0.6147, Train-MSE-0.0006, Train-L2-0.0381, Test-L2-0.2811
# Epoch-166, Time-0.6436, Train-MSE-0.0007, Train-L2-0.0397, Test-L2-0.2811
# Epoch-167, Time-0.6236, Train-MSE-0.0006, Train-L2-0.0376, Test-L2-0.2786
# Epoch-168, Time-0.5992, Train-MSE-0.0006, Train-L2-0.0364, Test-L2-0.2806
# Epoch-169, Time-0.6029, Train-MSE-0.0006, Train-L2-0.0377, Test-L2-0.2794
# Epoch-170, Time-0.6103, Train-MSE-0.0007, Train-L2-0.0371, Test-L2-0.2794
# Epoch-171, Time-0.5898, Train-MSE-0.0006, Train-L2-0.0383, Test-L2-0.2786
# Epoch-172, Time-0.6028, Train-MSE-0.0007, Train-L2-0.0379, Test-L2-0.2823
# Epoch-173, Time-0.6516, Train-MSE-0.0007, Train-L2-0.0413, Test-L2-0.2787
# Epoch-174, Time-0.6585, Train-MSE-0.0006, Train-L2-0.0356, Test-L2-0.2782
# Epoch-175, Time-0.6300, Train-MSE-0.0007, Train-L2-0.0378, Test-L2-0.2802
# Epoch-176, Time-0.6047, Train-MSE-0.0006, Train-L2-0.0389, Test-L2-0.2787
# Epoch-177, Time-0.6463, Train-MSE-0.0006, Train-L2-0.0386, Test-L2-0.2792
# Epoch-178, Time-0.5872, Train-MSE-0.0008, Train-L2-0.0452, Test-L2-0.2796
# Epoch-179, Time-0.6927, Train-MSE-0.0008, Train-L2-0.0430, Test-L2-0.2787
# Epoch-180, Time-0.6362, Train-MSE-0.0007, Train-L2-0.0397, Test-L2-0.2808
# Epoch-181, Time-0.5936, Train-MSE-0.0007, Train-L2-0.0384, Test-L2-0.2808
# Epoch-182, Time-0.6386, Train-MSE-0.0008, Train-L2-0.0458, Test-L2-0.2825
# Epoch-183, Time-0.6055, Train-MSE-0.0010, Train-L2-0.0495, Test-L2-0.2806
# Epoch-184, Time-0.6166, Train-MSE-0.0007, Train-L2-0.0415, Test-L2-0.2805
# Epoch-185, Time-0.5913, Train-MSE-0.0009, Train-L2-0.0466, Test-L2-0.2843
# Epoch-186, Time-0.6260, Train-MSE-0.0009, Train-L2-0.0459, Test-L2-0.2804
# Epoch-187, Time-0.6174, Train-MSE-0.0008, Train-L2-0.0468, Test-L2-0.2803
# Epoch-188, Time-0.5911, Train-MSE-0.0011, Train-L2-0.0493, Test-L2-0.2788
# Epoch-189, Time-0.5869, Train-MSE-0.0009, Train-L2-0.0455, Test-L2-0.2853
# Epoch-190, Time-0.6295, Train-MSE-0.0007, Train-L2-0.0431, Test-L2-0.2792
# Epoch-191, Time-0.5883, Train-MSE-0.0011, Train-L2-0.0513, Test-L2-0.2835
# Epoch-192, Time-0.5989, Train-MSE-0.0010, Train-L2-0.0497, Test-L2-0.2774
# Epoch-193, Time-0.6837, Train-MSE-0.0010, Train-L2-0.0509, Test-L2-0.2821
# Epoch-194, Time-0.6333, Train-MSE-0.0008, Train-L2-0.0432, Test-L2-0.2772
# Epoch-195, Time-0.5879, Train-MSE-0.0006, Train-L2-0.0384, Test-L2-0.2804
# Epoch-196, Time-0.6282, Train-MSE-0.0006, Train-L2-0.0368, Test-L2-0.2795
# Epoch-197, Time-0.5959, Train-MSE-0.0006, Train-L2-0.0370, Test-L2-0.2787
# Epoch-198, Time-0.5945, Train-MSE-0.0006, Train-L2-0.0384, Test-L2-0.2779
# Epoch-199, Time-0.5949, Train-MSE-0.0005, Train-L2-0.0342, Test-L2-0.2773
# Epoch-200, Time-0.6333, Train-MSE-0.0004, Train-L2-0.0306, Test-L2-0.2753
# Epoch-201, Time-0.6261, Train-MSE-0.0004, Train-L2-0.0294, Test-L2-0.2778
# Epoch-202, Time-0.5764, Train-MSE-0.0004, Train-L2-0.0316, Test-L2-0.2742
# Epoch-203, Time-0.5853, Train-MSE-0.0005, Train-L2-0.0321, Test-L2-0.2798
# Epoch-204, Time-0.5991, Train-MSE-0.0004, Train-L2-0.0313, Test-L2-0.2755
# Epoch-205, Time-0.6003, Train-MSE-0.0005, Train-L2-0.0323, Test-L2-0.2765
# Epoch-206, Time-0.6025, Train-MSE-0.0004, Train-L2-0.0295, Test-L2-0.2746
# Epoch-207, Time-0.6753, Train-MSE-0.0003, Train-L2-0.0273, Test-L2-0.2766
# Epoch-208, Time-0.6394, Train-MSE-0.0003, Train-L2-0.0267, Test-L2-0.2761
# Epoch-209, Time-0.6169, Train-MSE-0.0003, Train-L2-0.0257, Test-L2-0.2752
# Epoch-210, Time-0.6273, Train-MSE-0.0004, Train-L2-0.0278, Test-L2-0.2764
# Epoch-211, Time-0.6147, Train-MSE-0.0003, Train-L2-0.0270, Test-L2-0.2757
# Epoch-212, Time-0.5849, Train-MSE-0.0004, Train-L2-0.0291, Test-L2-0.2748
# Epoch-213, Time-0.6635, Train-MSE-0.0004, Train-L2-0.0293, Test-L2-0.2792
# Epoch-214, Time-0.6510, Train-MSE-0.0004, Train-L2-0.0300, Test-L2-0.2735
# Epoch-215, Time-0.6843, Train-MSE-0.0004, Train-L2-0.0283, Test-L2-0.2772
# Epoch-216, Time-0.6451, Train-MSE-0.0004, Train-L2-0.0300, Test-L2-0.2748
# Epoch-217, Time-0.6045, Train-MSE-0.0005, Train-L2-0.0301, Test-L2-0.2760
# Epoch-218, Time-0.6884, Train-MSE-0.0003, Train-L2-0.0272, Test-L2-0.2782
# Epoch-219, Time-0.5939, Train-MSE-0.0003, Train-L2-0.0276, Test-L2-0.2739
# Epoch-220, Time-0.6557, Train-MSE-0.0003, Train-L2-0.0265, Test-L2-0.2750
# Epoch-221, Time-0.6203, Train-MSE-0.0003, Train-L2-0.0243, Test-L2-0.2749
# Epoch-222, Time-0.5919, Train-MSE-0.0003, Train-L2-0.0241, Test-L2-0.2735
# Epoch-223, Time-0.6271, Train-MSE-0.0003, Train-L2-0.0272, Test-L2-0.2765
# Epoch-224, Time-0.6994, Train-MSE-0.0003, Train-L2-0.0282, Test-L2-0.2764
# Epoch-225, Time-0.7081, Train-MSE-0.0003, Train-L2-0.0288, Test-L2-0.2736
# Epoch-226, Time-0.7253, Train-MSE-0.0004, Train-L2-0.0318, Test-L2-0.2784
# Epoch-227, Time-0.7416, Train-MSE-0.0005, Train-L2-0.0340, Test-L2-0.2724
# Epoch-228, Time-0.6904, Train-MSE-0.0007, Train-L2-0.0374, Test-L2-0.2786
# Epoch-229, Time-0.6369, Train-MSE-0.0004, Train-L2-0.0344, Test-L2-0.2741
# Epoch-230, Time-0.6350, Train-MSE-0.0003, Train-L2-0.0288, Test-L2-0.2748
# Epoch-231, Time-0.6849, Train-MSE-0.0004, Train-L2-0.0295, Test-L2-0.2718
# Epoch-232, Time-0.6508, Train-MSE-0.0004, Train-L2-0.0296, Test-L2-0.2746
# Epoch-233, Time-0.6874, Train-MSE-0.0004, Train-L2-0.0310, Test-L2-0.2719
# Epoch-234, Time-0.6515, Train-MSE-0.0004, Train-L2-0.0304, Test-L2-0.2760
# Epoch-235, Time-0.6398, Train-MSE-0.0005, Train-L2-0.0325, Test-L2-0.2703
# Epoch-236, Time-0.5918, Train-MSE-0.0005, Train-L2-0.0347, Test-L2-0.2752
# Epoch-237, Time-0.6000, Train-MSE-0.0006, Train-L2-0.0358, Test-L2-0.2729
# Epoch-238, Time-0.6576, Train-MSE-0.0004, Train-L2-0.0300, Test-L2-0.2751
# Epoch-239, Time-0.7524, Train-MSE-0.0003, Train-L2-0.0275, Test-L2-0.2772
# Epoch-240, Time-0.7210, Train-MSE-0.0003, Train-L2-0.0285, Test-L2-0.2710
# Epoch-241, Time-0.6788, Train-MSE-0.0004, Train-L2-0.0289, Test-L2-0.2765
# Epoch-242, Time-0.7038, Train-MSE-0.0004, Train-L2-0.0315, Test-L2-0.2734
# Epoch-243, Time-0.7069, Train-MSE-0.0003, Train-L2-0.0296, Test-L2-0.2756
# Epoch-244, Time-0.6482, Train-MSE-0.0003, Train-L2-0.0270, Test-L2-0.2718
# Epoch-245, Time-0.6649, Train-MSE-0.0003, Train-L2-0.0273, Test-L2-0.2749
# Epoch-246, Time-0.7045, Train-MSE-0.0003, Train-L2-0.0282, Test-L2-0.2745
# Epoch-247, Time-0.6968, Train-MSE-0.0004, Train-L2-0.0303, Test-L2-0.2740
# Epoch-248, Time-0.6851, Train-MSE-0.0005, Train-L2-0.0326, Test-L2-0.2734
# Epoch-249, Time-0.5920, Train-MSE-0.0004, Train-L2-0.0307, Test-L2-0.2719

# %%
# Save the HF-WNO model

torch.save(model, 'model/HF_WNO_Darcy2D_20')

# %%
# Predict on HF data using HF-WNO
pred_hf = [] 
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        x = x_normalizer_mf.decode(x)
        x = x_normalizer_hf.encode(x)
        
        x, y = x.to(device), y.to(device)

        out = model(x[..., 0:1]).reshape(x.shape[0], s, s)
        out = y_normalizer_hf.decode(out)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        test_l2 /= x.shape[0]
        print('Batch-{}, Test-L2-{:0.4f}'.format(index, test_l2))
        
        pred_hf.append(out.cpu())
        index += 1

pred_hf = torch.cat(( pred_hf ), dim=0 )

print('Mean mse_hf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
mse_pred_hf = F.mse_loss(pred_hf, y_test_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
fig2, axs = plt.subplots(nrows=3, ncols=5, figsize=(16, 6), facecolor='w', edgecolor='k')
fig2.subplots_adjust(hspace=0.35, wspace=0.2)

fig2.suptitle(f'Predictions MFWNO AC2d Size', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(y_test_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(pred_hf[sample, :, :], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        im = axs[2, index].imshow(torch.abs(y_test_hf[sample, :, :] - pred_hf[sample, :, :]),
                                    cmap='jet',origin='lower')
        plt.colorbar(im, ax=axs[2, index])
        index += 1

# %%
fig4, axs = plt.subplots(nrows=2, ncols=5, figsize=(10, 4), facecolor='w', edgecolor='k')
fig4.subplots_adjust(hspace=0.35, wspace=0.2)

fig4.suptitle(f'Predictions Error', fontsize=16)
index = 0 
for sample in range(ntest):
    if sample % 9 == 0:
        im = axs[0, index].imshow(pred_hf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[0, index])
        im = axs[1, index].imshow(output_mf[sample] - y_hf[sample], cmap='nipy_spectral',origin='lower')
        plt.colorbar(im, ax=axs[1, index])
        index += 1

# %% [markdown]
# # Plotting

# %%
s = 1
xmax = s
ymax = s-8/51
from matplotlib.patches import Rectangle
plt.rcParams["font.family"] = "Serif"
plt.rcParams['font.size'] = 10

figure1 = plt.figure(constrained_layout=False, figsize = (14, 10))
plt.subplots_adjust(hspace=0.25, wspace=0.3)
index = 0
value = 0

plt.subplot(3,4, index+1)
plt.imshow(output_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('MFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
      
      #####        
plt.subplot(3,4, index+2)
plt.imshow(pred_hf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('HFSM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.4, facecolor='white'))
        ###
plt.subplot(3,4, index+3)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(input_mf[value,:,:,1], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('LFM');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        #####
plt.subplot(3,4, index+4)
# plt.imshow(pred.cpu().detach().numpy()[value,:,:], origin='lower', extent = [0, s, 0, s], interpolation='Gaussian', cmap='nipy_spectral')
plt.imshow(real_mf[value,:,:], origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Ground Truth');
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax]); plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.5,0),0.01,0.41, facecolor='white'))
        
        ###
plt.subplot(3,4, index+5)
plt.imshow(np.abs(output_mf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))

        ###
plt.subplot(3,4, index+6)
plt.imshow(np.abs(pred_hf[value,:,:]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))


        ###
plt.subplot(3,4, index+7)
plt.imshow(np.abs(input_mf[value,:,:,1]-real_mf[value,:,:]), \
   origin='lower', extent = [0, 1, 0, 1], interpolation='Gaussian', cmap='nipy_spectral')
plt.title('Error');
plt.colorbar(orientation="horizontal", fraction=0.04, pad=0.2)
        
xf = np.array([0., xmax/2]); yf = xf*(ymax/(xmax/2)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([xmax/2, xmax]); yf = (xf-xmax)*(ymax/((xmax/2)-xmax)); plt.fill_between(xf, yf, ymax, color = [1, 1, 1])
xf = np.array([0, xmax])
plt.fill_between(xf, ymax, s, color = [1, 1, 1])        
plt.gca().add_patch(Rectangle((0.49,0),0.01,0.41, facecolor='white'))
