# %% [markdown]
# # It trains MFWNO on the MF 1D Poisson's data (time-independent problem).
# ### HF data size = 20

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from utils import *
import matplotlib.pyplot as plt

from timeit import default_timer
from pytorch_wavelets import DWT1D, IDWT1D

# %%
torch.manual_seed(10)
np.random.seed(10)

# %% [markdown]
# # WNO

# %%
class WaveConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv1d, self).__init__()

        """
        1D Wavelet layer. It does Wavelet Transform, linear transform, and
        Inverse Wavelet Transform.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet 
        self.dwt_ = DWT1D(wave=self.wavelet, J=self.level, mode='zero')
        dummy_data = torch.randn( 1,1,size ) 
        mode_data, _ = self.dwt_(dummy_data)
        self.modes1 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))

    # Convolution
    def mul1d(self, input, weights):
        # (batch, in_channel, x ), (in_channel, out_channel, x) -> (batch, out_channel, x)
        return torch.einsum("bix,iox->box", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet     
        dwt = DWT1D(wave=self.wavelet, J=self.level, mode='zero').to(x.device)
        x_ft, x_coeff = dwt(x)
        
        # Multiply the final low pass wavelet coefficients
        out_ft = self.mul1d(x_ft, self.weights1)
        # Multiply the final high pass wavelet coefficients
        x_coeff[-1] = self.mul1d(x_coeff[-1].clone(), self.weights2)
        
        # Reconstruct the signal
        idwt = IDWT1D(wave=self.wavelet, mode='zero').to(x.device)
        x = idwt((out_ft, x_coeff)) 
        return x

# %%
class WNO1d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        if self.padding != 0:
            x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)
        
        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        if self.padding != 0:
            x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class WNO1d_linear(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d_linear, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2

        x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class MFWNO(nn.Module):
  def __init__(self, width, level, size, wavelet, in_channel, grid_range):
    super(MFWNO, self).__init__()
    
    self.width = width
    self.level = level 
    self.size = size
    self.wavelet = wavelet 
    self.in_channel = in_channel 
    self.grid_range = grid_range
    
    self.conv1 = WNO1d_linear(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.conv2 = WNO1d(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.fc0 = nn.Linear(1,12)
    self.fc1 = nn.Linear(12,1)

  def forward(self, x):
    x = self.conv1(x) + self.conv2(x)
    x = self.fc0(x)
    x = F.gelu(x)
    x = self.fc1(x)
    return x

# %% [markdown]
# # Multifidelity

# %%
ntrain = 20
ntest = 40
n_total = ntrain + ntest
last_m = 400
s = 100

batch_size = 5
learning_rate = 0.001

w_decay = 1e-4
epochs = 500
step_size = 50   # weight-decay step size
gamma = 0.5      # weight-decay rate

wavelet = 'db6'  # wavelet basis function
level = 3        # lavel of wavelet decomposition
width = 64       # uplifting dimension
layers = 4       # no of wavelet layers

h = 100           # total grid size divided by the subsampling rate
grid_range = 1
in_channel = 3   # (a(x), x) for this case

# %%
PATH = 'data/possion_10pt_100pt__lscale_01.npz'
data = np.load(PATH)

x_data_h = data['f_stoch'][last_m-n_total:last_m]
y_data_l = data['y_low_100'][last_m-n_total:last_m]
y_data_h = data['yhi'][last_m-n_total:last_m]
x_coords = data['xhi'].reshape((s,))

# %%
 data['f_stoch'].shape

# %%
# read data

x_mf = np.stack((x_data_h, y_data_l), axis=-1)
y_mf = y_data_h - y_data_l

x_train_mf, y_train_mf = x_mf[:ntrain, ...], y_mf[:ntrain, ...]
x_test_mf, y_test_mf = x_mf[-ntest:, ...], y_mf[-ntest:, ...]

x_train_mf = torch.tensor( x_train_mf, dtype=torch.float )
y_train_mf = torch.tensor( y_train_mf, dtype=torch.float ) 
x_test_mf = torch.tensor( x_test_mf, dtype=torch.float ) 
y_test_mf = torch.tensor( y_test_mf, dtype=torch.float ) 

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                              batch_size=batch_size, shuffle=True)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_mf.shape, y_mf.shape, x_train_mf.shape, y_train_mf.shape, x_test_mf.shape, y_test_mf.shape)

# %%
# model
model_mf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=3, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_mf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    test_mse = 0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.cuda(), y.cuda()

            out = model_mf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
            tmse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
            test_mse += tmse.item()

    train_mse /= len(train_loader_mf)
    train_l2 /= ntrain
    test_l2 /= ntest
    test_mse /= len(test_loader_mf)
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}, Test-MSE-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2, test_mse))
# Out:
# Epoch-92, Time-0.2539, Train-MSE-0.0000, Train-L2-0.1235, Test-L2-0.9298, Test-MSE-0.0014
# Epoch-93, Time-0.2429, Train-MSE-0.0000, Train-L2-0.1272, Test-L2-0.9710, Test-MSE-0.0014
# Epoch-94, Time-0.2514, Train-MSE-0.0000, Train-L2-0.0910, Test-L2-0.9379, Test-MSE-0.0014
# Epoch-95, Time-0.2462, Train-MSE-0.0000, Train-L2-0.0902, Test-L2-0.9602, Test-MSE-0.0014
# Epoch-96, Time-0.2387, Train-MSE-0.0000, Train-L2-0.0814, Test-L2-0.9540, Test-MSE-0.0014
# Epoch-97, Time-0.2479, Train-MSE-0.0000, Train-L2-0.0735, Test-L2-0.9482, Test-MSE-0.0014
# Epoch-98, Time-0.2423, Train-MSE-0.0000, Train-L2-0.0681, Test-L2-0.9591, Test-MSE-0.0014
# Epoch-99, Time-0.2559, Train-MSE-0.0000, Train-L2-0.0757, Test-L2-0.9554, Test-MSE-0.0014
# Epoch-100, Time-0.2437, Train-MSE-0.0000, Train-L2-0.0643, Test-L2-0.9592, Test-MSE-0.0014
# Epoch-101, Time-0.2233, Train-MSE-0.0000, Train-L2-0.0565, Test-L2-0.9599, Test-MSE-0.0014
# Epoch-102, Time-0.2187, Train-MSE-0.0000, Train-L2-0.0559, Test-L2-0.9483, Test-MSE-0.0014
# Epoch-103, Time-0.2180, Train-MSE-0.0000, Train-L2-0.0479, Test-L2-0.9524, Test-MSE-0.0014
# Epoch-104, Time-0.2253, Train-MSE-0.0000, Train-L2-0.0499, Test-L2-0.9524, Test-MSE-0.0014
# Epoch-105, Time-0.1988, Train-MSE-0.0000, Train-L2-0.0456, Test-L2-0.9573, Test-MSE-0.0014
# Epoch-106, Time-0.1806, Train-MSE-0.0000, Train-L2-0.0488, Test-L2-0.9609, Test-MSE-0.0014
# Epoch-107, Time-0.2216, Train-MSE-0.0000, Train-L2-0.0457, Test-L2-0.9593, Test-MSE-0.0014
# Epoch-108, Time-0.2401, Train-MSE-0.0000, Train-L2-0.0495, Test-L2-0.9517, Test-MSE-0.0014
# Epoch-109, Time-0.2473, Train-MSE-0.0000, Train-L2-0.0453, Test-L2-0.9653, Test-MSE-0.0014
# Epoch-110, Time-0.2378, Train-MSE-0.0000, Train-L2-0.0389, Test-L2-0.9592, Test-MSE-0.0014
# Epoch-111, Time-0.2401, Train-MSE-0.0000, Train-L2-0.0423, Test-L2-0.9638, Test-MSE-0.0014
# Epoch-112, Time-0.2403, Train-MSE-0.0000, Train-L2-0.0409, Test-L2-0.9559, Test-MSE-0.0014
# Epoch-113, Time-0.2419, Train-MSE-0.0000, Train-L2-0.0438, Test-L2-0.9630, Test-MSE-0.0014
# Epoch-114, Time-0.2409, Train-MSE-0.0000, Train-L2-0.0457, Test-L2-0.9571, Test-MSE-0.0014
# Epoch-115, Time-0.2416, Train-MSE-0.0000, Train-L2-0.0547, Test-L2-0.9604, Test-MSE-0.0014
# Epoch-116, Time-0.2339, Train-MSE-0.0000, Train-L2-0.0561, Test-L2-0.9811, Test-MSE-0.0015
# Epoch-117, Time-0.2537, Train-MSE-0.0000, Train-L2-0.0586, Test-L2-0.9474, Test-MSE-0.0014
# Epoch-118, Time-0.2463, Train-MSE-0.0000, Train-L2-0.0709, Test-L2-0.9695, Test-MSE-0.0014
# Epoch-119, Time-0.2625, Train-MSE-0.0000, Train-L2-0.0518, Test-L2-0.9593, Test-MSE-0.0014
# Epoch-120, Time-0.2480, Train-MSE-0.0000, Train-L2-0.0556, Test-L2-0.9661, Test-MSE-0.0014
# Epoch-121, Time-0.2446, Train-MSE-0.0000, Train-L2-0.0533, Test-L2-0.9608, Test-MSE-0.0014
# Epoch-122, Time-0.2458, Train-MSE-0.0000, Train-L2-0.0524, Test-L2-0.9624, Test-MSE-0.0014
# Epoch-123, Time-0.2335, Train-MSE-0.0000, Train-L2-0.0538, Test-L2-0.9611, Test-MSE-0.0014
# Epoch-124, Time-0.2370, Train-MSE-0.0000, Train-L2-0.0497, Test-L2-0.9684, Test-MSE-0.0015
# Epoch-125, Time-0.2290, Train-MSE-0.0000, Train-L2-0.0517, Test-L2-0.9680, Test-MSE-0.0015
# Epoch-126, Time-0.2471, Train-MSE-0.0000, Train-L2-0.0473, Test-L2-0.9630, Test-MSE-0.0014
# Epoch-127, Time-0.2471, Train-MSE-0.0000, Train-L2-0.0419, Test-L2-0.9634, Test-MSE-0.0014
# Epoch-128, Time-0.2478, Train-MSE-0.0000, Train-L2-0.0461, Test-L2-0.9620, Test-MSE-0.0014
# Epoch-129, Time-0.2355, Train-MSE-0.0000, Train-L2-0.0359, Test-L2-0.9628, Test-MSE-0.0014
# Epoch-130, Time-0.2457, Train-MSE-0.0000, Train-L2-0.0390, Test-L2-0.9602, Test-MSE-0.0014
# Epoch-131, Time-0.2452, Train-MSE-0.0000, Train-L2-0.0363, Test-L2-0.9628, Test-MSE-0.0014
# Epoch-132, Time-0.2401, Train-MSE-0.0000, Train-L2-0.0359, Test-L2-0.9638, Test-MSE-0.0014
# Epoch-133, Time-0.2404, Train-MSE-0.0000, Train-L2-0.0466, Test-L2-0.9576, Test-MSE-0.0014
# Epoch-134, Time-0.2535, Train-MSE-0.0000, Train-L2-0.0396, Test-L2-0.9637, Test-MSE-0.0014
# Epoch-135, Time-0.2456, Train-MSE-0.0000, Train-L2-0.0403, Test-L2-0.9652, Test-MSE-0.0014
# Epoch-136, Time-0.2538, Train-MSE-0.0000, Train-L2-0.0401, Test-L2-0.9675, Test-MSE-0.0014
# Epoch-137, Time-0.2439, Train-MSE-0.0000, Train-L2-0.0497, Test-L2-0.9648, Test-MSE-0.0014
# Epoch-138, Time-0.2505, Train-MSE-0.0000, Train-L2-0.0402, Test-L2-0.9655, Test-MSE-0.0014
# Epoch-139, Time-0.2639, Train-MSE-0.0000, Train-L2-0.0463, Test-L2-0.9671, Test-MSE-0.0014
# Epoch-140, Time-0.2530, Train-MSE-0.0000, Train-L2-0.0431, Test-L2-0.9647, Test-MSE-0.0014
# Epoch-141, Time-0.2426, Train-MSE-0.0000, Train-L2-0.0439, Test-L2-0.9568, Test-MSE-0.0014
# Epoch-142, Time-0.2373, Train-MSE-0.0000, Train-L2-0.0491, Test-L2-0.9782, Test-MSE-0.0015
# Epoch-143, Time-0.2389, Train-MSE-0.0000, Train-L2-0.0583, Test-L2-0.9605, Test-MSE-0.0014
# Epoch-144, Time-0.2552, Train-MSE-0.0000, Train-L2-0.0577, Test-L2-0.9701, Test-MSE-0.0014
# Epoch-145, Time-0.2470, Train-MSE-0.0000, Train-L2-0.0620, Test-L2-0.9448, Test-MSE-0.0014
# Epoch-146, Time-0.2470, Train-MSE-0.0000, Train-L2-0.0609, Test-L2-0.9656, Test-MSE-0.0014
# Epoch-147, Time-0.2350, Train-MSE-0.0000, Train-L2-0.0562, Test-L2-0.9621, Test-MSE-0.0014
# Epoch-148, Time-0.2433, Train-MSE-0.0000, Train-L2-0.0652, Test-L2-0.9714, Test-MSE-0.0015
# Epoch-149, Time-0.2535, Train-MSE-0.0000, Train-L2-0.0569, Test-L2-0.9484, Test-MSE-0.0014
# Epoch-150, Time-0.2456, Train-MSE-0.0000, Train-L2-0.0560, Test-L2-0.9648, Test-MSE-0.0014
# Epoch-151, Time-0.2470, Train-MSE-0.0000, Train-L2-0.0575, Test-L2-0.9667, Test-MSE-0.0014
# Epoch-152, Time-0.2613, Train-MSE-0.0000, Train-L2-0.0419, Test-L2-0.9570, Test-MSE-0.0014
# Epoch-153, Time-0.2612, Train-MSE-0.0000, Train-L2-0.0335, Test-L2-0.9704, Test-MSE-0.0015
# Epoch-154, Time-0.2536, Train-MSE-0.0000, Train-L2-0.0307, Test-L2-0.9644, Test-MSE-0.0014
# Epoch-155, Time-0.2504, Train-MSE-0.0000, Train-L2-0.0348, Test-L2-0.9684, Test-MSE-0.0014
# Epoch-156, Time-0.2485, Train-MSE-0.0000, Train-L2-0.0357, Test-L2-0.9555, Test-MSE-0.0014
# Epoch-157, Time-0.2448, Train-MSE-0.0000, Train-L2-0.0413, Test-L2-0.9603, Test-MSE-0.0014
# Epoch-158, Time-0.2517, Train-MSE-0.0000, Train-L2-0.0356, Test-L2-0.9674, Test-MSE-0.0014
# Epoch-159, Time-0.2429, Train-MSE-0.0000, Train-L2-0.0272, Test-L2-0.9638, Test-MSE-0.0014
# Epoch-160, Time-0.2408, Train-MSE-0.0000, Train-L2-0.0274, Test-L2-0.9671, Test-MSE-0.0014
# Epoch-161, Time-0.2438, Train-MSE-0.0000, Train-L2-0.0308, Test-L2-0.9604, Test-MSE-0.0014
# Epoch-162, Time-0.2275, Train-MSE-0.0000, Train-L2-0.0287, Test-L2-0.9680, Test-MSE-0.0014
# Epoch-163, Time-0.2586, Train-MSE-0.0000, Train-L2-0.0270, Test-L2-0.9699, Test-MSE-0.0015
# Epoch-164, Time-0.2474, Train-MSE-0.0000, Train-L2-0.0254, Test-L2-0.9578, Test-MSE-0.0014
# Epoch-165, Time-0.2422, Train-MSE-0.0000, Train-L2-0.0234, Test-L2-0.9623, Test-MSE-0.0014
# Epoch-166, Time-0.2453, Train-MSE-0.0000, Train-L2-0.0212, Test-L2-0.9656, Test-MSE-0.0014
# Epoch-167, Time-0.2384, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.9657, Test-MSE-0.0014
# Epoch-168, Time-0.2535, Train-MSE-0.0000, Train-L2-0.0213, Test-L2-0.9651, Test-MSE-0.0014
# Epoch-169, Time-0.2496, Train-MSE-0.0000, Train-L2-0.0210, Test-L2-0.9619, Test-MSE-0.0014
# Epoch-170, Time-0.2561, Train-MSE-0.0000, Train-L2-0.0218, Test-L2-0.9647, Test-MSE-0.0014
# Epoch-171, Time-0.2426, Train-MSE-0.0000, Train-L2-0.0211, Test-L2-0.9623, Test-MSE-0.0014
# Epoch-172, Time-0.2394, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-0.9656, Test-MSE-0.0014
# Epoch-173, Time-0.2546, Train-MSE-0.0000, Train-L2-0.0202, Test-L2-0.9624, Test-MSE-0.0014
# Epoch-174, Time-0.2527, Train-MSE-0.0000, Train-L2-0.0215, Test-L2-0.9667, Test-MSE-0.0014
# Epoch
Train-MSE-0.0000, Train-L2-0.0087, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-472, Time-0.2342, Train-MSE-0.0000, Train-L2-0.0087, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-473, Time-0.2360, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-474, Time-0.2362, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-475, Time-0.2451, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-476, Time-0.2411, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-477, Time-0.2526, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-478, Time-0.2403, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-479, Time-0.2588, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-480, Time-0.2375, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-481, Time-0.2474, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-482, Time-0.2519, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-483, Time-0.2367, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-484, Time-0.2478, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-485, Time-0.2437, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-486, Time-0.2362, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-487, Time-0.2442, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-488, Time-0.2472, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-489, Time-0.2284, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-490, Time-0.2179, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-491, Time-0.2140, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-492, Time-0.2202, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-493, Time-0.2188, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-494, Time-0.2100, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-495, Time-0.2006, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-496, Time-0.1831, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-497, Time-0.2046, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-498, Time-0.2095, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014
# Epoch-499, Time-0.2166, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-0.9669, Test-MSE-0.0014

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_poisson1D_20')

# %%
# Prediction:
pred_mf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_mf(x).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_mf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_mf = torch.cat(( pred_mf ))
print('Mean mse_mf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
pred_mf.shape

# %%
inp_mf  = x_test_mf 
real_mf = y_test_mf + inp_mf[:,:,1]
output_mf  =  pred_mf + inp_mf[:,:,1]

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()

print('MSE-Predicted solution-{:0.6f}'.format(mse_pred))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_mf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_mf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
colormap = plt.cm.jet  
colors2 = [colormap(i) for i in np.linspace(0, 1, 5)]

fig1 = plt.figure(figsize = (10, 4), dpi=300)
fig1.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, inp_mf[i, :, 0], color=colors2[index], label='Forcing-{}'.format(i))
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %% [markdown]
# # High Fidelity

# %%
# read data
x_hf = torch.tensor( x_data_h, dtype=torch.float ).unsqueeze(-1)
y_hf = torch.tensor( y_data_h, dtype=torch.float ) 

x_train_hf, y_train_hf = x_hf[:ntrain, ...], y_hf[:ntrain, ...]
x_test_hf, y_test_hf = x_hf[-ntest:, ...], y_hf[-ntest:, ...]

train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                              batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, x_test_hf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_train_hf.shape, y_train_hf.shape, x_test_hf.shape, y_test_hf.shape)

# %%
# model
model_hf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=2, grid_range=grid_range).to(device)
print(count_params(model_hf))

optimizer = torch.optim.Adam(model_hf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_hf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_hf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_hf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.cuda(), y.cuda()

            out = model_hf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()

    train_mse /= len(train_loader_hf)
    train_l2 /= ntrain
    test_l2 /= ntest

    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-113, Time-0.2045, Train-MSE-0.0394, Train-L2-0.0988, Test-L2-1.5043
# Epoch-114, Time-0.2359, Train-MSE-0.0391, Train-L2-0.0936, Test-L2-1.5144
# Epoch-115, Time-0.2501, Train-MSE-0.0397, Train-L2-0.0950, Test-L2-1.5020
# Epoch-116, Time-0.2511, Train-MSE-0.0394, Train-L2-0.0983, Test-L2-1.5154
# Epoch-117, Time-0.2568, Train-MSE-0.0382, Train-L2-0.0943, Test-L2-1.5141
# Epoch-118, Time-0.2571, Train-MSE-0.0385, Train-L2-0.0902, Test-L2-1.4995
# Epoch-119, Time-0.2529, Train-MSE-0.0388, Train-L2-0.0969, Test-L2-1.5162
# Epoch-120, Time-0.2360, Train-MSE-0.0380, Train-L2-0.0888, Test-L2-1.5149
# Epoch-121, Time-0.2488, Train-MSE-0.0367, Train-L2-0.0896, Test-L2-1.5114
# Epoch-122, Time-0.2481, Train-MSE-0.0376, Train-L2-0.0869, Test-L2-1.5197
# Epoch-123, Time-0.2553, Train-MSE-0.0369, Train-L2-0.0842, Test-L2-1.5150
# Epoch-124, Time-0.2443, Train-MSE-0.0360, Train-L2-0.0868, Test-L2-1.5188
# Epoch-125, Time-0.2465, Train-MSE-0.0365, Train-L2-0.0821, Test-L2-1.5224
# Epoch-126, Time-0.2394, Train-MSE-0.0362, Train-L2-0.0833, Test-L2-1.5118
# Epoch-127, Time-0.2404, Train-MSE-0.0373, Train-L2-0.0884, Test-L2-1.5191
# Epoch-128, Time-0.2534, Train-MSE-0.0357, Train-L2-0.0816, Test-L2-1.5211
# Epoch-129, Time-0.2475, Train-MSE-0.0356, Train-L2-0.0831, Test-L2-1.5192
# Epoch-130, Time-0.2407, Train-MSE-0.0350, Train-L2-0.0816, Test-L2-1.5233
# Epoch-131, Time-0.2409, Train-MSE-0.0357, Train-L2-0.0855, Test-L2-1.5224
# Epoch-132, Time-0.2380, Train-MSE-0.0340, Train-L2-0.0821, Test-L2-1.5287
# Epoch-133, Time-0.2480, Train-MSE-0.0355, Train-L2-0.0916, Test-L2-1.5170
# Epoch-134, Time-0.2398, Train-MSE-0.0339, Train-L2-0.0982, Test-L2-1.5250
# Epoch-135, Time-0.2447, Train-MSE-0.0363, Train-L2-0.0999, Test-L2-1.5395
# Epoch-136, Time-0.2421, Train-MSE-0.0336, Train-L2-0.1081, Test-L2-1.5272
# Epoch-137, Time-0.2483, Train-MSE-0.0318, Train-L2-0.1029, Test-L2-1.5272
# Epoch-138, Time-0.2483, Train-MSE-0.0329, Train-L2-0.0868, Test-L2-1.5256
# Epoch-139, Time-0.2447, Train-MSE-0.0344, Train-L2-0.0865, Test-L2-1.5294
# Epoch-140, Time-0.2442, Train-MSE-0.0328, Train-L2-0.0835, Test-L2-1.5335
# Epoch-141, Time-0.2548, Train-MSE-0.0328, Train-L2-0.0869, Test-L2-1.5261
# Epoch-142, Time-0.2402, Train-MSE-0.0330, Train-L2-0.0840, Test-L2-1.5344
# Epoch-143, Time-0.2455, Train-MSE-0.0318, Train-L2-0.0844, Test-L2-1.5367
# Epoch-144, Time-0.2380, Train-MSE-0.0336, Train-L2-0.0820, Test-L2-1.5212
# Epoch-145, Time-0.2488, Train-MSE-0.0341, Train-L2-0.0864, Test-L2-1.5315
# Epoch-146, Time-0.2465, Train-MSE-0.0316, Train-L2-0.0948, Test-L2-1.5429
# Epoch-147, Time-0.2615, Train-MSE-0.0324, Train-L2-0.0846, Test-L2-1.5362
# Epoch-148, Time-0.2483, Train-MSE-0.0319, Train-L2-0.0896, Test-L2-1.5208
# Epoch-149, Time-0.2483, Train-MSE-0.0325, Train-L2-0.0877, Test-L2-1.5406
# Epoch-150, Time-0.2447, Train-MSE-0.0307, Train-L2-0.0775, Test-L2-1.5392
# Epoch-151, Time-0.2328, Train-MSE-0.0306, Train-L2-0.0740, Test-L2-1.5296
# Epoch-152, Time-0.2331, Train-MSE-0.0311, Train-L2-0.0710, Test-L2-1.5361
# Epoch-153, Time-0.2442, Train-MSE-0.0303, Train-L2-0.0705, Test-L2-1.5339
# Epoch-154, Time-0.2328, Train-MSE-0.0312, Train-L2-0.0706, Test-L2-1.5380
# Epoch-155, Time-0.2366, Train-MSE-0.0296, Train-L2-0.0695, Test-L2-1.5422
# Epoch-156, Time-0.2433, Train-MSE-0.0294, Train-L2-0.0750, Test-L2-1.5367
# Epoch-157, Time-0.2388, Train-MSE-0.0305, Train-L2-0.0706, Test-L2-1.5379
# Epoch-158, Time-0.2441, Train-MSE-0.0302, Train-L2-0.0665, Test-L2-1.5369
# Epoch-159, Time-0.2489, Train-MSE-0.0301, Train-L2-0.0664, Test-L2-1.5402
# Epoch-160, Time-0.2411, Train-MSE-0.0300, Train-L2-0.0666, Test-L2-1.5352
# Epoch-161, Time-0.2555, Train-MSE-0.0303, Train-L2-0.0663, Test-L2-1.5405
# Epoch-162, Time-0.2557, Train-MSE-0.0293, Train-L2-0.0719, Test-L2-1.5411
# Epoch-163, Time-0.2627, Train-MSE-0.0304, Train-L2-0.0703, Test-L2-1.5365
# Epoch-164, Time-0.2367, Train-MSE-0.0296, Train-L2-0.0702, Test-L2-1.5439
# Epoch-165, Time-0.2390, Train-MSE-0.0285, Train-L2-0.0695, Test-L2-1.5449
# Epoch-166, Time-0.2448, Train-MSE-0.0295, Train-L2-0.0716, Test-L2-1.5402
# Epoch-167, Time-0.2433, Train-MSE-0.0287, Train-L2-0.0676, Test-L2-1.5432
# Epoch-168, Time-0.2479, Train-MSE-0.0291, Train-L2-0.0668, Test-L2-1.5422
# Epoch-169, Time-0.2517, Train-MSE-0.0289, Train-L2-0.0657, Test-L2-1.5413
# Epoch-170, Time-0.2422, Train-MSE-0.0291, Train-L2-0.0651, Test-L2-1.5435
# Epoch-171, Time-0.2461, Train-MSE-0.0285, Train-L2-0.0654, Test-L2-1.5443
# Epoch-172, Time-0.2520, Train-MSE-0.0290, Train-L2-0.0669, Test-L2-1.5418
# Epoch-173, Time-0.2456, Train-MSE-0.0283, Train-L2-0.0673, Test-L2-1.5454
# Epoch-174, Time-0.2506, Train-MSE-0.0284, Train-L2-0.0662, Test-L2-1.5439
# Epoch-175, Time-0.2430, Train-MSE-0.0281, Train-L2-0.0706, Test-L2-1.5411
# Epoch-176, Time-0.2398, Train-MSE-0.0281, Train-L2-0.0744, Test-L2-1.5474
# Epoch-177, Time-0.2503, Train-MSE-0.0293, Train-L2-0.0752, Test-L2-1.5442
# Epoch-178, Time-0.2457, Train-MSE-0.0277, Train-L2-0.0738, Test-L2-1.5442
# Epoch-179, Time-0.2471, Train-MSE-0.0282, Train-L2-0.0721, Test-L2-1.5532
# Epoch-180, Time-0.2556, Train-MSE-0.0281, Train-L2-0.0768, Test-L2-1.5486
# Epoch-181, Time-0.2564, Train-MSE-0.0277, Train-L2-0.0733, Test-L2-1.5412
# Epoch-182, Time-0.2478, Train-MSE-0.0283, Train-L2-0.0696, Test-L2-1.5520
# Epoch-183, Time-0.2445, Train-MSE-0.0271, Train-L2-0.0681, Test-L2-1.5503
# Epoch-184, Time-0.2612, Train-MSE-0.0268, Train-L2-0.0719, Test-L2-1.5431
# Epoch-185, Time-0.2559, Train-MSE-0.0278, Train-L2-0.0662, Test-L2-1.5517
# Epoch-186, Time-0.2555, Train-MSE-0.0268, Train-L2-0.0640, Test-L2-1.5502
# Epoch-187, Time-0.2594, Train-MSE-0.0269, Train-L2-0.0638, Test-L2-1.5503
# Epoch-188, Time-0.2578, Train-MSE-0.0268, Train-L2-0.0624, Test-L2-1.5486
# Epoch-189, Time-0.2520, Train-MSE-0.0270, Train-L2-0.0626, Test-L2-1.5503
# Epoch-190, Time-0.2339, Train-MSE-0.0267, Train-L2-0.0624, Test-L2-1.5521
# Epoch-191, Time-0.2447, Train-MSE-0.0266, Train-L2-0.0625, Test-L2-1.5505
# Epoch-192, Time-0.2393, Train-MSE-0.0265, Train-L2-0.0633, Test-L2-1.5541
# Epoch-193, Time-0.2444, Train-MSE-0.0262, Train-L2-0.0627, Test-L2-1.5542
# Epoch-194, Time-0.2439, Train-MSE-0.0266, Train-L2-0.0668, Test-L2-1.5490
# Epoch-195, Time-0.2385, Train-MSE-0.0269, Train-L2-0.0667, Test-L2-1.5524
# Epoch-196, Time-0.2396, Train-MSE-0.0254, Train-L2-0.0680, Test-L2-1.5577
# Epoch-197, Time-0.2426, Train-MSE-0.0255, Train-L2-0.0675, Test-L2-1.5502
# Epoch-198, Time-0.2395, Train-MSE-0.0257, Train-L2-0.0613, Test-L2-1.5550
# Epoch-199, Time-0.2451, Train-MSE-0.0254, Train-L2-0.0655, Test-L2-1.5597
# Epoch-200, Time-0.2489, Train-MSE-0.0255, Train-L2-0.0609, Test-L2-1.5550
# Epoch-201, Time-0.2472, Train-MSE-0.0257, Train-L2-0.0600, Test-L2-1.5537
# Epoch-202, Time-0.2523, Train-MSE-0.0256, Train-L2-0.0584, Test-L2-1.5549
# Epoch-203, Time-0.2393, Train-MSE-0.0253, Train-L2-0.0585, Test-L2-1.5531
# Epoch-204, Time-0.2533, Train-MSE-0.0255, Train-L2-0.0574, Test-L2-1.5567
# Epoch-205, Time-0.2221, Train-MSE-0.0253, Train-L2-0.0581, Test-L2-1.5559
# Epoch-206, Time-0.2229, Train-MSE-0.0255, Train-L2-0.0584, Test-L2-1.5549
# Epoch-207, Time-0.2220, Train-MSE-0.0250, Train-L2-0.0574, Test-L2-1.5556
# Epoch-208, Time-0.2222, Train-MSE-0.0254, Train-L2-0.0575, Test-L2-1.5568
# Epoch-209, Time-0.2217, Train-MSE-0.0254, Train-L2-0.0574, Test-L2-1.5580
# Epoch-210, Time-0.2244, Train-MSE-0.0250, Train-L2-0.0580, Test-L2-1.5545
# Epoch-211, Time-0.1843, Train-MSE-0.0254, Train-L2-0.0571, Test-L2-1.5596
# Epoch-212, Time-0.2034, Train-MSE-0.0248, Train-L2-0.0584, Test-L2-1.5573
# Epoch-213, Time-0.2215, Train-MSE-0.0253, Train-L2-0.0573, Test-L2-1.5532
# Epoch-214, Time-0.2227, Train-MSE-0.0248, Train-L2-0.0559, Test-L2-1.5605
# Epoch-215, Time-0.2240, Train-MSE-0.0247, Train-L2-0.0568, Test-L2-1.5573
# Epoch-216, Time-0.2233, Train-MSE-0.0249, Train-L2-0.0561, Test-L2-1.5571
# Epoch-217, Time-0.2233, Train-MSE-0.0245, Train-L2-0.0567, Test-L2-1.5602
# Epoch-218, Time-0.2195, Train-MSE-0.0248, Train-L2-0.0556, Test-L2-1.5566
# Epoch-219, Time-0.1900, Train-MSE-0.0246, Train-L2-0.0547, Test-L2-1.5594
# Epoch-220, Time-0.2037, Train-MSE-0.0244, Train-L2-0.0543, Test-L2-1.5594
# Epoch-221, Time-0.2215, Train-MSE-0.0246, Train-L2-0.0545, Test-L2-1.5577
# Epoch-222, Time-0.2208, Train-MSE-0.0246, Train-L2-0.0543, Test-L2-1.5600
# Epoch-223, Time-0.2135, Train-MSE-0.0244, Train-L2-0.0543, Test-L2-1.5587
# Epoch-224, Time-0.2341, Train-MSE-0.0245, Train-L2-0.0540, Test-L2-1.5601
# Epoch-225, Time-0.2019, Train-MSE-0.0242, Train-L2-0.0547, Test-L2-1.5604
# Epoch-226, Time-0.2110, Train-MSE-0.0242, Train-L2-0.0540, Test-L2-1.5594
# Epoch-227, Time-0.2078, Train-MSE-0.0244, Train-L2-0.0546, Test-L2-1.5586
# Epoch-228, Time-0.2073, Train-MSE-0.0241, Train-L2-0.0552, Test-L2-1.5612
# Epoch-229, Time-0.2144, Train-MSE-0.0241, Train-L2-0.0555, Test-L2-1.5601
# Epoch-230, Time-0.2048, Train-MSE-0.0241, Train-L2-0.0541, Test-L2-1.5599
# Epoch-231, Time-0.2326, Train-MSE-0.0242, Train-L2-0.0553, Test-L2-1.5624
# Epoch-232, Time-0.2598, Train-MSE-0.0238, Train-L2-0.0543, Test-L2-1.5620
# Epoch-233, Time-0.2583, Train-MSE-0.0240, Train-L2-0.0549, Test-L2-1.5620
# Epoch-234, Time-0.2564, Train-MSE-0.0238, Train-L2-0.0545, Test-L2-1.5609
# Epoch-235, Time-0.2585, Train-MSE-0.0241, Train-L2-0.0537, Test-L2-1.5611
# Epoch-236, Time-0.2562, Train-MSE-0.0238, Train-L2-0.0545, Test-L2-1.5625
# Epoch-237, Time-0.2609, Train-MSE-0.0239, Train-L2-0.0538, Test-L2-1.5616
# Epoch-238, Time-0.2590, Train-MSE-0.0238, Train-L2-0.0533, Test-L2-1.5633
# Epoch-239, Time-0.2600, Train-MSE-0.0236, Train-L2-0.0551, Test-L2-1.5626
# Epoch-240, Time-0.2591, Train-MSE-0.0237, Train-L2-0.0550, Test-L2-1.5616
# Epoch-241, Time-0.2594, Train-MSE-0.0235, Train-L2-0.0552, Test-L2-1.5639
# Epoch-242, Time-0.2538, Train-MSE-0.0232, Train-L2-0.0544, Test-L2-1.5621
# Epoch-243, Time-0.2562, Train-MSE-0.0237, Train-L2-0.0540, Test-L2-1.5636
# Epoch-244, Time-0.2566, Train-MSE-0.0231, Train-L2-0.0569, Test-L2-1.5647
# Epoch-245, Time-0.2507, Train-MSE-0.0235, Train-L2-0.0554, Test-L2-1.5624
# Epoch-246, Time-0.2847, Train-MSE-0.0229, Train-L2-0.0544, Test-L2-1.5663
# Epoch-247, Time-0.2502, Train-MSE-0.0229, Train-L2-0.0539, Test-L2-1.5638
# Epoch-248, Time-0.2587, Train-MSE-0.0234, Train-L2-0.0564, Test-L2-1.5639
# Epoch-249, Time-0.2564, Train-MSE-0.0231, Train-L2-0.0541, Test-L2-1.5663
# Epoch-250, Time-0.2638, Train-MSE-0.0231, Train-L2-0.0535, Test-L2-1.5650
# Epoch-251, Time-0.2508, Train-MSE-0.0231, Train-L2-0.0525, Test-L2-1.5640
# Epoch-252, Time-0.2585, Train-MSE-0.0230, Train-L2-0.0515, Test-L2-1.5649
# Epoch-253, Time-0.2623, Train-MSE-0.0229, Train-L2-0.0513, Test-L2-1.5658
# Epoch-254, Time-0.2483, Train-MSE-0.0229, Train-L2-0.0515, Test-L2-1.5651
# Epoch-255, Time-0.2565, Train-MSE-0.0229, Train-L2-0.0514, Test-L2-1.5643
# Epoch-256, Time-0.2585, Train-MSE-0.0230, Train-L2-0.0509, Test-L2-1.5658
# Epoch-257, Time-0.2323, Train-MSE-0.0228, Train-L2-0.0507, Test-L2-1.5665
# Epoch-258, Time-0.2436, Train-MSE-0.0227, Train-L2-0.0509, Test-L2-1.5653
# Epoch-259, Time-0.2515, Train-MSE-0.0229, Train-L2-0.0510, Test-L2-1.5657
# Epoch-260, Time-0.2478, Train-MSE-0.0228, Train-L2-0.0508, Test-L2-1.5660
# Epoch-261, Time-0.2556, Train-MSE-0.0228, Train-L2-0.0505, Test-L2-1.5656
# Epoch-262, Time-0.2486, Train-MSE-0.0227, Train-L2-0.0502, Test-L2-1.5660
# Epoch-263, Time-0.2562, Train-MSE-0.0227, Train-L2-0.0501, Test-L2-1.5659
# Epoch-264, Time-0.2447, Train-MSE-0.0227, Train-L2-0.0503, Test-L2-1.5663
# Epoch-265, Time-0.2562, Train-MSE-0.0226, Train-L2-0.0503, Test-L2-1.5671
# Epoch-266, Time-0.2565, Train-MSE-0.0226, Train-L2-0.0502, Test-L2-1.5654
# Epoch-267, Time-0.2522, Train-MSE-0.0227, Train-L2-0.0500, Test-L2-1.5668
# Epoch-268, Time-0.2544, Train-MSE-0.0225, Train-L2-0.0502, Test-L2-1.5676
# Epoch-269, Time-0.2550, Train-MSE-0.0226, Train-L2-0.0502, Test-L2-1.5661
# Epoch-270, Time-0.2599, Train-MSE-0.0226, Train-L2-0.0503, Test-L2-1.5664
# Epoch-271, Time-0.2529, Train-MSE-0.0225, Train-L2-0.0501, Test-L2-1.5683
# Epoch-272, Time-0.2439, Train-MSE-0.0224, Train-L2-0.0498, Test-L2-1.5668
# Epoch-273, Time-0.2471, Train-MSE-0.0225, Train-L2-0.0496, Test-L2-1.5670
# Epoch-274, Time-0.2474, Train-MSE-0.0224, Train-L2-0.0495, Test-L2-1.5679
# Epoch-275, Time-0.2502, Train-MSE-0.0224, Train-L2-0.0498, Test-L2-1.5671
# Epoch-276, Time-0.2491, Train-MSE-0.0225, Train-L2-0.0498, Test-L2-1.5670
# Epoch-277, Time-0.2390, Train-MSE-0.0224, Train-L2-0.0495, Test-L2-1.5678
# Epoch-278, Time-0.2207, Train-MSE-0.0224, Train-L2-0.0495, Test-L2-1.5682
# Epoch-279, Time-0.2297, Train-MSE-0.0223, Train-L2-0.0495, Test-L2-1.5671
# Epoch-280, Time-0.2402, Train-MSE-0.0223, Train-L2-0.0495, Test-L2-1.5682
# Epoch-281, Time-0.2420, Train-MSE-0.0222, Train-L2-0.0495, Test-L2-1.5690
# Epoch-282, Time-0.2164, Train-MSE-0.0222, Train-L2-0.0492, Test-L2-1.5672
# Epoch-283, Time-0.2204, Train-MSE-0.0222, Train-L2-0.0491, Test-L2-1.5687
# Epoch-284, Time-0.2345, Train-MSE-0.0221, Train-L2-0.0494, Test-L2-1.5692
# Epoch-285, Time-0.2304, Train-MSE-0.0222, Train-L2-0.0492, Test-L2-1.5668
# Epoch-286, Time-0.2536, Train-MSE-0.0222, Train-L2-0.0490, Test-L2-1.5693
# Epoch-287, Time-0.2421, Train-MSE-0.0220, Train-L2-0.0492, Test-L2-1.5686
# Epoch-288, Time-0.2470, Train-MSE-0.0221, Train-L2-0.0488, Test-L2-1.5683
# Epoch-289, Time-0.2479, Train-MSE-0.0221, Train-L2-0.0488, Test-L2-1.5693
# Epoch-290, Time-0.2433, Train-MSE-0.0220, Train-L2-0.0492, Test-L2-1.5687
# Epoch-291, Time-0.2472, Train-MSE-0.0221, Train-L2-0.0497, Test-L2-1.5687
# Epoch-292, Time-0.2489, Train-MSE-0.0218, Train-L2-0.0496, Test-L2-1.5696
# Epoch-293, Time-0.2436, Train-MSE-0.0218, Train-L2-0.0486, Test-L2-1.5694
# Epoch-294, Time-0.2569, Train-MSE-0.0220, Train-L2-0.0493, Test-L2-1.5686
# Epoch-295, Time-0.2412, Train-MSE-0.0219, Train-L2-0.0499, Test-L2-1.5688
# Epoch-296, Time-0.2471, Train-MSE-0.0220, Train-L2-0.0497, Test-L2-1.5709
# Epoch-297, Time-0.2469, Train-MSE-0.0216, Train-L2-0.0491, Test-L2-1.5700
# Epoch-298, Time-0.2436, Train-MSE-0.0219, Train-L2-0.0488, Test-L2-1.5691
# Epoch-299, Time-0.2408, Train-MSE-0.0219, Train-L2-0.0502, Test-L2-1.5707
# Epoch-300, Time-0.2462, Train-MSE-0.0216, Train-L2-0.0492, Test-L2-1.5708
# Epoch-301, Time-0.2472, Train-MSE-0.0217, Train-L2-0.0485, Test-L2-1.5702
# Epoch-302, Time-0.2446, Train-MSE-0.0217, Train-L2-0.0484, Test-L2-1.5703
# Epoch-303, Time-0.2394, Train-MSE-0.0217, Train-L2-0.0481, Test-L2-1.5701
# Epoch-304, Time-0.2604, Train-MSE-0.0217, Train-L2-0.0481, Test-L2-1.5701
# Epoch-305, Time-0.2483, Train-MSE-0.0217, Train-L2-0.0479, Test-L2-1.5704
# Epoch-306, Time-0.2462, Train-MSE-0.0216, Train-L2-0.0479, Test-L2-1.5706
# Epoch-307, Time-0.2394, Train-MSE-0.0216, Train-L2-0.0479, Test-L2-1.5705
# Epoch-308, Time-0.2390, Train-MSE-0.0216, Train-L2-0.0478, Test-L2-1.5707
# Epoch-309, Time-0.2381, Train-MSE-0.0216, Train-L2-0.0477, Test-L2-1.5706
# Epoch-310, Time-0.2387, Train-MSE-0.0216, Train-L2-0.0477, Test-L2-1.5705
# Epoch-311, Time-0.2334, Train-MSE-0.0216, Train-L2-0.0477, Test-L2-1.5708
# Epoch-312, Time-0.2327, Train-MSE-0.0216, Train-L2-0.0476, Test-L2-1.5710
# Epoch-313, Time-0.2410, Train-MSE-0.0216, Train-L2-0.0476, Test-L2-1.5711
# Epoch-314, Time-0.2435, Train-MSE-0.0216, Train-L2-0.0476, Test-L2-1.5706
# Epoch-315, Time-0.2503, Train-MSE-0.0216, Train-L2-0.0475, Test-L2-1.5710
# Epoch-316, Time-0.2486, Train-MSE-0.0215, Train-L2-0.0476, Test-L2-1.5712
# Epoch-317, Time-0.2526, Train-MSE-0.0215, Train-L2-0.0475, Test-L2-1.5709
# Epoch-318, Time-0.2525, Train-MSE-0.0215, Train-L2-0.0476, Test-L2-1.5709
# Epoch-319, Time-0.2365, Train-MSE-0.0215, Train-L2-0.0476, Test-L2-1.5712
# Epoch-320, Time-0.2414, Train-MSE-0.0215, Train-L2-0.0475, Test-L2-1.5715
# Epoch-321, Time-0.2431, Train-MSE-0.0214, Train-L2-0.0475, Test-L2-1.5712
# Epoch-322, Time-0.2389, Train-MSE-0.0214, Train-L2-0.0473, Test-L2-1.5713
# Epoch-323, Time-0.2398, Train-MSE-0.0215, Train-L2-0.0474, Test-L2-1.5714
# Epoch-324, Time-0.2489, Train-MSE-0.0214, Train-L2-0.0472, Test-L2-1.5716
# Epoch-325, Time-0.2412, Train-MSE-0.0214, Train-L2-0.0473, Test-L2-1.5713
# Epoch-326, Time-0.2458, Train-MSE-0.0214, Train-L2-0.0472, Test-L2-1.5711
# Epoch-327, Time-0.2411, Train-MSE-0.0214, Train-L2-0.0472, Test-L2-1.5717
# Epoch-328, Time-0.2547, Train-MSE-0.0214, Train-L2-0.0471, Test-L2-1.5718
# Epoch-329, Time-0.2527, Train-MSE-0.0213, Train-L2-0.0471, Test-L2-1.5717
# Epoch-330, Time-0.2492, Train-MSE-0.0214, Train-L2-0.0471, Test-L2-1.5718
# Epoch-331, Time-0.2450, Train-MSE-0.0213, Train-L2-0.0470, Test-L2-1.5720
# Epoch-332, Time-0.2479, Train-MSE-0.0213, Train-L2-0.0470, Test-L2-1.5718
# Epoch-333, Time-0.2384, Train-MSE-0.0213, Train-L2-0.0470, Test-L2-1.5719
# Epoch-334, Time-0.2431, Train-MSE-0.0213, Train-L2-0.0470, Test-L2-1.5722
# Epoch-335, Time-0.2362, Train-MSE-0.0213, Train-L2-0.0469, Test-L2-1.5720
# Epoch-336, Time-0.2401, Train-MSE-0.0213, Train-L2-0.0469, Test-L2-1.5720
# Epoch-337, Time-0.2467, Train-MSE-0.0212, Train-L2-0.0469, Test-L2-1.5724
# Epoch-338, Time-0.2483, Train-MSE-0.0212, Train-L2-0.0468, Test-L2-1.5720
# Epoch-339, Time-0.2490, Train-MSE-0.0212, Train-L2-0.0468, Test-L2-1.5724
# Epoch-340, Time-0.2382, Train-MSE-0.0212, Train-L2-0.0468, Test-L2-1.5724
# Epoch-341, Time-0.2470, Train-MSE-0.0212, Train-L2-0.0467, Test-L2-1.5724
# Epoch-342, Time-0.2433, Train-MSE-0.0212, Train-L2-0.0467, Test-L2-1.5725
# Epoch-343, Time-0.2492, Train-MSE-0.0212, Train-L2-0.0467, Test-L2-1.5726
# Epoch-344, Time-0.2488, Train-MSE-0.0211, Train-L2-0.0467, Test-L2-1.5726
# Epoch-345, Time-0.2596, Train-MSE-0.0211, Train-L2-0.0466, Test-L2-1.5728
# Epoch-346, Time-0.2471, Train-MSE-0.0211, Train-L2-0.0466, Test-L2-1.5726
# Epoch-347, Time-0.2421, Train-MSE-0.0211, Train-L2-0.0466, Test-L2-1.5728
# Epoch-348, Time-0.2496, Train-MSE-0.0211, Train-L2-0.0467, Test-L2-1.5731
# Epoch-349, Time-0.2552, Train-MSE-0.0211, Train-L2-0.0465, Test-L2-1.5728
# Epoch-350, Time-0.2304, Train-MSE-0.0211, Train-L2-0.0465, Test-L2-1.5728
# Epoch-351, Time-0.2424, Train-MSE-0.0211, Train-L2-0.0465, Test-L2-1.5731
# Epoch-352, Time-0.2505, Train-MSE-0.0210, Train-L2-0.0464, Test-L2-1.5731
# Epoch-353, Time-0.2433, Train-MSE-0.0210, Train-L2-0.0464, Test-L2-1.5730
# Epoch-354, Time-0.2315, Train-MSE-0.0210, Train-L2-0.0464, Test-L2-1.5731
# Epoch-355, Time-0.2265, Train-MSE-0.0210, Train-L2-0.0463, Test-L2-1.5730
# Epoch-356, Time-0.2424, Train-MSE-0.0210, Train-L2-0.0464, Test-L2-1.5731
# Epoch-357, Time-0.2295, Train-MSE-0.0210, Train-L2-0.0463, Test-L2-1.5730
# Epoch-358, Time-0.2296, Train-MSE-0.0210, Train-L2-0.0463, Test-L2-1.5732
# Epoch-359, Time-0.2287, Train-MSE-0.0210, Train-L2-0.0463, Test-L2-1.5734
# Epoch-360, Time-0.2318, Train-MSE-0.0210, Train-L2-0.0463, Test-L2-1.5732
# Epoch-361, Time-0.2281, Train-MSE-0.0210, Train-L2-0.0462, Test-L2-1.5732
# Epoch-362, Time-0.2236, Train-MSE-0.0210, Train-L2-0.0462, Test-L2-1.5733
# Epoch-363, Time-0.2434, Train-MSE-0.0210, Train-L2-0.0462, Test-L2-1.5734
# Epoch-364, Time-0.2432, Train-MSE-0.0209, Train-L2-0.0462, Test-L2-1.5734
# Epoch-365, Time-0.2330, Train-MSE-0.0209, Train-L2-0.0462, Test-L2-1.5736
# Epoch-366, Time-0.2261, Train-MSE-0.0209, Train-L2-0.0462, Test-L2-1.5735
# Epoch-367, Time-0.2188, Train-MSE-0.0209, Train-L2-0.0462, Test-L2-1.5733
# Epoch-368, Time-0.2414, Train-MSE-0.0209, Train-L2-0.0462, Test-L2-1.5734
# Epoch-369, Time-0.2315, Train-MSE-0.0209, Train-L2-0.0461, Test-L2-1.5737
# Epoch-370, Time-0.2398, Train-MSE-0.0209, Train-L2-0.0461, Test-L2-1.5736
# Epoch-371, Time-0.2411, Train-MSE-0.0209, Train-L2-0.0461, Test-L2-1.5736
# Epoch-372, Time-0.2359, Train-MSE-0.0209, Train-L2-0.0461, Test-L2-1.5736
# Epoch-373, Time-0.2362, Train-MSE-0.0209, Train-L2-0.0461, Test-L2-1.5737
# Epoch-374, Time-0.2235, Train-MSE-0.0209, Train-L2-0.0460, Test-L2-1.5736
# Epoch-375, Time-0.2473, Train-MSE-0.0209, Train-L2-0.0460, Test-L2-1.5738
# Epoch-376, Time-0.2344, Train-MSE-0.0209, Train-L2-0.0460, Test-L2-1.5738
# Epoch-377, Time-0.2412, Train-MSE-0.0209, Train-L2-0.0460, Test-L2-1.5737
# Epoch-378, Time-0.2243, Train-MSE-0.0209, Train-L2-0.0460, Test-L2-1.5738
# Epoch-379, Time-0.2356, Train-MSE-0.0208, Train-L2-0.0460, Test-L2-1.5739
# Epoch-380, Time-0.2540, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5739
# Epoch-381, Time-0.2557, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5739
# Epoch-382, Time-0.2533, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5740
# Epoch-383, Time-0.2473, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5741
# Epoch-384, Time-0.2189, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5740
# Epoch-385, Time-0.2153, Train-MSE-0.0208, Train-L2-0.0459, Test-L2-1.5741
# Epoch-386, Time-0.2087, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5741
# Epoch-387, Time-0.2139, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5741
# Epoch-388, Time-0.2037, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5740
# Epoch-389, Time-0.2150, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5741
# Epoch-390, Time-0.1993, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5744
# Epoch-391, Time-0.2043, Train-MSE-0.0208, Train-L2-0.0458, Test-L2-1.5743
# Epoch-392, Time-0.2249, Train-MSE-0.0207, Train-L2-0.0458, Test-L2-1.5743
# Epoch-393, Time-0.2438, Train-MSE-0.0207, Train-L2-0.0458, Test-L2-1.5741
# Epoch-394, Time-0.2370, Train-MSE-0.0207, Train-L2-0.0457, Test-L2-1.5743
# Epoch-395, Time-0.2458, Train-MSE-0.0207, Train-L2-0.0457, Test-L2-1.5746
# Epoch-396, Time-0.2443, Train-MSE-0.0207, Train-L2-0.0457, Test-L2-1.5745
# Epoch-397, Time-0.2421, Train-MSE-0.0207, Train-L2-0.0457, Test-L2-1.5744
# Epoch-398, Time-0.1931, Train-MSE-0.0207, Train-L2-0.0457, Test-L2-1.5744
# Epoch-399, Time-0.2098, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5746
# Epoch-400, Time-0.2266, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5746
# Epoch-401, Time-0.2265, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5745
# Epoch-402, Time-0.2240, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5745
# Epoch-403, Time-0.2213, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5745
# Epoch-404, Time-0.2259, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5746
# Epoch-405, Time-0.2220, Train-MSE-0.0207, Train-L2-0.0456, Test-L2-1.5746
# Epoch-406, Time-0.2278, Train-MSE-0.0206, Train-L2-0.0456, Test-L2-1.5748
# Epoch-407, Time-0.2252, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-408, Time-0.2235, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-409, Time-0.2210, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5746
# Epoch-410, Time-0.2235, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-411, Time-0.2235, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-412, Time-0.2219, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-413, Time-0.2312, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5749
# Epoch-414, Time-0.2548, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5748
# Epoch-415, Time-0.2483, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5747
# Epoch-416, Time-0.2425, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5748
# Epoch-417, Time-0.2517, Train-MSE-0.0206, Train-L2-0.0455, Test-L2-1.5748
# Epoch-418, Time-0.2483, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5748
# Epoch-419, Time-0.2553, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5749
# Epoch-420, Time-0.2448, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5749
# Epoch-421, Time-0.2494, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5749
# Epoch-422, Time-0.2504, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-423, Time-0.2341, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-424, Time-0.2254, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-425, Time-0.2217, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-426, Time-0.2214, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-427, Time-0.1961, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5750
# Epoch-428, Time-0.1798, Train-MSE-0.0206, Train-L2-0.0454, Test-L2-1.5751
# Epoch-429, Time-0.2079, Train-MSE-0.0206, Train-L2-0.0453, Test-L2-1.5750
# Epoch-430, Time-0.2186, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5751
# Epoch-431, Time-0.2452, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5751
# Epoch-432, Time-0.2415, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5750
# Epoch-433, Time-0.2379, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5751
# Epoch-434, Time-0.2443, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5752
# Epoch-435, Time-0.2397, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5752
# Epoch-436, Time-0.2389, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5753
# Epoch-437, Time-0.2419, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5752
# Epoch-438, Time-0.2391, Train-MSE-0.0205, Train-L2-0.0453, Test-L2-1.5752
# Epoch-439, Time-0.1776, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5753
# Epoch-440, Time-0.1837, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5753
# Epoch-441, Time-0.1857, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5753
# Epoch-442, Time-0.1770, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5753
# Epoch-443, Time-0.1766, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5754
# Epoch-444, Time-0.1731, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5752
# Epoch-445, Time-0.1797, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5753
# Epoch-446, Time-0.1792, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5754
# Epoch-447, Time-0.1801, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5754
# Epoch-448, Time-0.1770, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5755
# Epoch-449, Time-0.1807, Train-MSE-0.0205, Train-L2-0.0452, Test-L2-1.5754
# Epoch-450, Time-0.1820, Train-MSE-0.0205, Train-L2-0.0451, Test-L2-1.5754
# Epoch-451, Time-0.1846, Train-MSE-0.0205, Train-L2-0.0451, Test-L2-1.5754
# Epoch-452, Time-0.1775, Train-MSE-0.0205, Train-L2-0.0451, Test-L2-1.5754
# Epoch-453, Time-0.1833, Train-MSE-0.0205, Train-L2-0.0451, Test-L2-1.5754
# Epoch-454, Time-0.1779, Train-MSE-0.0205, Train-L2-0.0451, Test-L2-1.5755
# Epoch-455, Time-0.1791, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-456, Time-0.1809, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-457, Time-0.1812, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-458, Time-0.1833, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-459, Time-0.1831, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-460, Time-0.1774, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-461, Time-0.1763, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-462, Time-0.1795, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5755
# Epoch-463, Time-0.1745, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5756
# Epoch-464, Time-0.1745, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5756
# Epoch-465, Time-0.1792, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5756
# Epoch-466, Time-0.1802, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5756
# Epoch-467, Time-0.1765, Train-MSE-0.0204, Train-L2-0.0451, Test-L2-1.5756
# Epoch-468, Time-0.1792, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5756
# Epoch-469, Time-0.1794, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5756
# Epoch-470, Time-0.2330, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5756
# Epoch-471, Time-0.2398, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5756
# Epoch-472, Time-0.2380, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-473, Time-0.2357, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-474, Time-0.2491, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-475, Time-0.2368, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5756
# Epoch-476, Time-0.2408, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-477, Time-0.2374, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-478, Time-0.2414, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-479, Time-0.2507, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-480, Time-0.2432, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-481, Time-0.2593, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-482, Time-0.2364, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-483, Time-0.2427, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5757
# Epoch-484, Time-0.2463, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5758
# Epoch-485, Time-0.2403, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5758
# Epoch-486, Time-0.2377, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5758
# Epoch-487, Time-0.2419, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5758
# Epoch-488, Time-0.2437, Train-MSE-0.0204, Train-L2-0.0450, Test-L2-1.5758
# Epoch-489, Time-0.2458, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5758
# Epoch-490, Time-0.2484, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5758
# Epoch-491, Time-0.2539, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5758
# Epoch-492, Time-0.2437, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5758
# Epoch-493, Time-0.2530, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5759
# Epoch-494, Time-0.2510, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5758
# Epoch-495, Time-0.2547, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5759
# Epoch-496, Time-0.2476, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5759
# Epoch-497, Time-0.2527, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5759
# Epoch-498, Time-0.2395, Train-MSE-0.0204, Train-L2-0.0449, Test-L2-1.5759
# Epoch-499, Time-0.2550, Train-MSE-0.0203, Train-L2-0.0449, Test-L2-1.5759

# %%
# Save the HF-WNO model

torch.save(model_hf, 'model/HF_WNO_poisson1D_20')

# %%
# Prediction:
pred_hf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_hf(x[:,:,0:1]).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_hf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_hf = torch.cat(( pred_hf ))
# print('Mean mse_mf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
inp = x_test_mf
real_hf = y_test_mf + inp[:,:,1] 
output_hf = pred_hf

# %%
mse_pred_hf = F.mse_loss(output_hf, real_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_hf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_hf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
fig5, axs = plt.subplots(2, 2,figsize=(18,10), dpi=100)
plt.subplots_adjust(wspace=0.25)

n0 = 15
axs[0, 0].plot(x_coords,real_mf[n0], linestyle='-', color='tab:green', lw=2)
axs[0, 0].plot(x_coords,inp_mf[n0,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 0].plot(x_coords,output_hf[n0], linestyle='-.', color='tab:orange', lw=2)
axs[0, 0].plot(x_coords,output_mf[n0], linestyle='--', color='tab:red', lw=3)
axs[0, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 0].margins(0)
axs[0, 0].grid(True, alpha=0.3)

n1 = 28
axs[0, 1].plot(x_coords,real_mf[n1], linestyle='-', color='tab:green', lw=2)
axs[0, 1].plot(x_coords,inp_mf[n1,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 1].plot(x_coords,output_hf[n1], linestyle='-.', color='tab:orange', lw=2)
axs[0, 1].plot(x_coords,output_mf[n1], linestyle='--', color='tab:red', lw=3)
axs[0, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 1].margins(0)
axs[0, 1].grid(True, alpha=0.3)

n2 = 37
axs[1, 0].plot(x_coords,real_mf[n2], linestyle='-', color='tab:green', lw=2)
axs[1, 0].plot(x_coords,inp_mf[n2,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 0].plot(x_coords,output_hf[n2], linestyle='-.', color='tab:orange', lw=2)
axs[1, 0].plot(x_coords,output_mf[n2], linestyle='--', color='tab:red', lw=3)
axs[1, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 0].margins(0)
axs[1, 0].grid(True, alpha=0.3)

n3 = 38
axs[1, 1].plot(x_coords,real_mf[n3], linestyle='-', color='tab:green', lw=2)
axs[1, 1].plot(x_coords,inp_mf[n3,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 1].plot(x_coords,output_hf[n3], linestyle='-.', color='tab:orange', lw=2)
axs[1, 1].plot(x_coords,output_mf[n3], linestyle='--', color='tab:red', lw=3)
axs[1, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 1].margins(0)
axs[1, 1].grid(True, alpha=0.3)
