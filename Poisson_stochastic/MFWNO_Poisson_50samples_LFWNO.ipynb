# %% [markdown]
# # Example for training MFWNO from LFWNO, on the MF 1D Poisson's data (time-independent problem).
# ### It shows data from LFWNO is equivalent to a LF numerical solver
# ### HF data size = 50

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from utils import *
import matplotlib.pyplot as plt

from timeit import default_timer
from pytorch_wavelets import DWT1D, IDWT1D

# %%
torch.manual_seed(10)
np.random.seed(10)

# %% [markdown]
# # WNO

# %%
class WaveConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv1d, self).__init__()

        """
        1D Wavelet layer. It does Wavelet Transform, linear transform, and
        Inverse Wavelet Transform.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet 
        self.dwt_ = DWT1D(wave=self.wavelet, J=self.level, mode='zero')
        dummy_data = torch.randn( 1,1,size ) 
        mode_data, _ = self.dwt_(dummy_data)
        self.modes1 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))

    # Convolution
    def mul1d(self, input, weights):
        # (batch, in_channel, x ), (in_channel, out_channel, x) -> (batch, out_channel, x)
        return torch.einsum("bix,iox->box", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet     
        dwt = DWT1D(wave=self.wavelet, J=self.level, mode='zero').to(x.device)
        x_ft, x_coeff = dwt(x)
        
        # Multiply the final low pass wavelet coefficients
        out_ft = self.mul1d(x_ft, self.weights1)
        # Multiply the final high pass wavelet coefficients
        x_coeff[-1] = self.mul1d(x_coeff[-1].clone(), self.weights2)
        
        # Reconstruct the signal
        idwt = IDWT1D(wave=self.wavelet, mode='zero').to(x.device)
        x = idwt((out_ft, x_coeff)) 
        return x

# %%
class WNO1d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        if self.padding != 0:
            x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)
        
        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        if self.padding != 0:
            x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class WNO1d_linear(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d_linear, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2

        x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class MFWNO(nn.Module):
  def __init__(self, width, level, size, wavelet, in_channel, grid_range):
    super(MFWNO, self).__init__()
    
    self.width = width
    self.level = level 
    self.size = size
    self.wavelet = wavelet 
    self.in_channel = in_channel 
    self.grid_range = grid_range
    
    self.conv1 = WNO1d_linear(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.conv2 = WNO1d(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.fc0 = nn.Linear(1,12)
    self.fc1 = nn.Linear(12,1)

  def forward(self, x):
    x = self.conv1(x) + self.conv2(x)
    x = self.fc0(x)
    x = F.gelu(x)
    x = self.fc1(x)
    return x

# %% [markdown]
# # LF-WNO

# %%
ntrain = 50
ntest = 40
n_total = ntrain + ntest
last_m = 400
s = 100

batch_size = 20
learning_rate = 0.001

w_decay = 1e-4
epochs = 500
step_size = 50   # weight-decay step size
gamma = 0.5      # weight-decay rate

wavelet = 'db6'  # wavelet basis function
level = 3        # lavel of wavelet decomposition
width = 64       # uplifting dimension
layers = 4       # no of wavelet layers

h = 100           # total grid size divided by the subsampling rate
grid_range = 1
in_channel = 3   # (a(x), x) for this case

ntrain_l = 2000
ntest_l = 2000
ntotal_l = ntrain_l + ntest_l

# %%
""" Read data """
PATH = 'data/possion_10pt_100pt__lscale_01.npz'
data = np.load(PATH)

x_data_h = data['f_stoch'][:ntotal_l, ...]
y_data_l = data['y_low_100'][:ntotal_l, ...]
y_data_h = data['yhi'][:ntotal_l, ...]
x_coords = data['xhi'].reshape((s,))

# %%
x_data_h.shape

# %%
# read data
x_lf = x_data_h[..., None]
y_lf = y_data_l

x_train_lf, y_train_lf = x_lf, y_lf
x_test_lf, y_test_lf = x_lf, y_lf

x_train_lf = torch.tensor( x_train_lf, dtype=torch.float )
y_train_lf = torch.tensor( y_train_lf, dtype=torch.float ) 
x_test_lf = torch.tensor( x_test_lf, dtype=torch.float ) 
y_test_lf = torch.tensor( y_test_lf, dtype=torch.float ) 

train_loader_lf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_lf, y_train_lf),
                                              batch_size=batch_size, shuffle=True)
test_loader_lf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_lf, y_test_lf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_train_lf.shape, y_train_lf.shape, x_test_lf.shape, y_test_lf.shape)

# %%
# model
model_lf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=2, grid_range=grid_range).to(device)
print(count_params(model_lf))

optimizer = torch.optim.Adam(model_lf.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_lf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_lf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_lf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_lf.eval()
    test_l2 = 0.0
    test_mse = 0
    with torch.no_grad():
        for x, y in test_loader_lf:
            x, y = x.cuda(), y.cuda()

            out = model_lf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
            tmse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
            test_mse += tmse.item()

    train_mse /= len(train_loader_mf)
    train_l2 /= ntrain_l
    test_l2 /= ntest_l
    test_mse /= len(test_loader_mf)
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}, Test-MSE-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2, test_mse))
# Out:
# Epoch-92, Time-4.2528, Train-MSE-0.0003, Train-L2-0.7881, Test-L2-0.0123, Test-MSE-0.0001
# Epoch-93, Time-4.3120, Train-MSE-0.0002, Train-L2-0.6412, Test-L2-0.0144, Test-MSE-0.0001
# Epoch-94, Time-4.1700, Train-MSE-0.0003, Train-L2-0.7729, Test-L2-0.0126, Test-MSE-0.0001
# Epoch-95, Time-4.2130, Train-MSE-0.0002, Train-L2-0.6396, Test-L2-0.0136, Test-MSE-0.0001
# Epoch-96, Time-4.4681, Train-MSE-0.0002, Train-L2-0.6956, Test-L2-0.0121, Test-MSE-0.0001
# Epoch-97, Time-4.3790, Train-MSE-0.0002, Train-L2-0.5779, Test-L2-0.0116, Test-MSE-0.0001
# Epoch-98, Time-4.4208, Train-MSE-0.0002, Train-L2-0.6717, Test-L2-0.0168, Test-MSE-0.0001
# Epoch-99, Time-4.5239, Train-MSE-0.0002, Train-L2-0.6330, Test-L2-0.0104, Test-MSE-0.0000
# Epoch-100, Time-4.1946, Train-MSE-0.0001, Train-L2-0.3658, Test-L2-0.0095, Test-MSE-0.0001
# Epoch-101, Time-4.2980, Train-MSE-0.0001, Train-L2-0.4177, Test-L2-0.0124, Test-MSE-0.0001
# Epoch-102, Time-4.3724, Train-MSE-0.0001, Train-L2-0.4236, Test-L2-0.0073, Test-MSE-0.0000
# Epoch-103, Time-4.4580, Train-MSE-0.0001, Train-L2-0.3802, Test-L2-0.0081, Test-MSE-0.0000
# Epoch-104, Time-3.9128, Train-MSE-0.0001, Train-L2-0.3980, Test-L2-0.0075, Test-MSE-0.0000
# Epoch-105, Time-4.1390, Train-MSE-0.0001, Train-L2-0.3631, Test-L2-0.0095, Test-MSE-0.0000
# Epoch-106, Time-4.3352, Train-MSE-0.0001, Train-L2-0.3497, Test-L2-0.0126, Test-MSE-0.0001
# Epoch-107, Time-3.6618, Train-MSE-0.0001, Train-L2-0.3699, Test-L2-0.0075, Test-MSE-0.0000
# Epoch-108, Time-4.0567, Train-MSE-0.0001, Train-L2-0.3774, Test-L2-0.0098, Test-MSE-0.0000
# Epoch-109, Time-4.1256, Train-MSE-0.0001, Train-L2-0.4564, Test-L2-0.0088, Test-MSE-0.0000
# Epoch-110, Time-4.0478, Train-MSE-0.0001, Train-L2-0.4427, Test-L2-0.0078, Test-MSE-0.0000
# Epoch-111, Time-4.2900, Train-MSE-0.0001, Train-L2-0.4524, Test-L2-0.0136, Test-MSE-0.0001
# Epoch-112, Time-4.4215, Train-MSE-0.0001, Train-L2-0.4327, Test-L2-0.0076, Test-MSE-0.0000
# Epoch-113, Time-4.0479, Train-MSE-0.0001, Train-L2-0.3993, Test-L2-0.0082, Test-MSE-0.0000
# Epoch-114, Time-4.4150, Train-MSE-0.0001, Train-L2-0.4244, Test-L2-0.0092, Test-MSE-0.0001
# Epoch-115, Time-4.3037, Train-MSE-0.0001, Train-L2-0.4368, Test-L2-0.0089, Test-MSE-0.0001
# Epoch-116, Time-4.2708, Train-MSE-0.0001, Train-L2-0.4763, Test-L2-0.0134, Test-MSE-0.0001
# Epoch-117, Time-4.0185, Train-MSE-0.0001, Train-L2-0.3786, Test-L2-0.0081, Test-MSE-0.0000
# Epoch-118, Time-4.1841, Train-MSE-0.0001, Train-L2-0.4818, Test-L2-0.0100, Test-MSE-0.0001
# Epoch-119, Time-4.2192, Train-MSE-0.0001, Train-L2-0.3716, Test-L2-0.0076, Test-MSE-0.0000
# Epoch-120, Time-4.0869, Train-MSE-0.0001, Train-L2-0.3679, Test-L2-0.0071, Test-MSE-0.0000
# Epoch-121, Time-4.1430, Train-MSE-0.0001, Train-L2-0.3806, Test-L2-0.0082, Test-MSE-0.0000
# Epoch-122, Time-4.3295, Train-MSE-0.0001, Train-L2-0.3655, Test-L2-0.0086, Test-MSE-0.0000
# Epoch-123, Time-4.3109, Train-MSE-0.0001, Train-L2-0.4275, Test-L2-0.0149, Test-MSE-0.0001
# Epoch-124, Time-4.3195, Train-MSE-0.0001, Train-L2-0.4706, Test-L2-0.0076, Test-MSE-0.0000
# Epoch-125, Time-4.4022, Train-MSE-0.0001, Train-L2-0.3611, Test-L2-0.0101, Test-MSE-0.0001
# Epoch-126, Time-4.0436, Train-MSE-0.0001, Train-L2-0.4285, Test-L2-0.0072, Test-MSE-0.0000
# Epoch-127, Time-4.3048, Train-MSE-0.0001, Train-L2-0.4029, Test-L2-0.0093, Test-MSE-0.0001
# Epoch-128, Time-4.4004, Train-MSE-0.0001, Train-L2-0.4144, Test-L2-0.0086, Test-MSE-0.0001
# Epoch-129, Time-4.2533, Train-MSE-0.0001, Train-L2-0.4124, Test-L2-0.0083, Test-MSE-0.0000
# Epoch-130, Time-4.2227, Train-MSE-0.0001, Train-L2-0.3673, Test-L2-0.0077, Test-MSE-0.0000
# Epoch-131, Time-4.2823, Train-MSE-0.0001, Train-L2-0.5452, Test-L2-0.0103, Test-MSE-0.0001
# Epoch-132, Time-4.0980, Train-MSE-0.0001, Train-L2-0.3748, Test-L2-0.0088, Test-MSE-0.0000
# Epoch-133, Time-4.3194, Train-MSE-0.0001, Train-L2-0.4083, Test-L2-0.0094, Test-MSE-0.0000
# Epoch-134, Time-4.2654, Train-MSE-0.0001, Train-L2-0.3786, Test-L2-0.0104, Test-MSE-0.0001
# Epoch-135, Time-4.4227, Train-MSE-0.0001, Train-L2-0.4591, Test-L2-0.0069, Test-MSE-0.0000
# Epoch-136, Time-4.4936, Train-MSE-0.0000, Train-L2-0.3378, Test-L2-0.0091, Test-MSE-0.0001
# Epoch-137, Time-4.2971, Train-MSE-0.0001, Train-L2-0.3692, Test-L2-0.0090, Test-MSE-0.0000
# Epoch-138, Time-4.2024, Train-MSE-0.0001, Train-L2-0.3712, Test-L2-0.0087, Test-MSE-0.0000
# Epoch-139, Time-4.0627, Train-MSE-0.0001, Train-L2-0.4305, Test-L2-0.0164, Test-MSE-0.0001
# Epoch-140, Time-3.9508, Train-MSE-0.0001, Train-L2-0.4153, Test-L2-0.0100, Test-MSE-0.0000
# Epoch-141, Time-4.0943, Train-MSE-0.0001, Train-L2-0.4165, Test-L2-0.0080, Test-MSE-0.0000
# Epoch-142, Time-4.3685, Train-MSE-0.0001, Train-L2-0.3607, Test-L2-0.0069, Test-MSE-0.0000
# Epoch-143, Time-4.3116, Train-MSE-0.0001, Train-L2-0.3786, Test-L2-0.0079, Test-MSE-0.0000
# Epoch-144, Time-4.2968, Train-MSE-0.0001, Train-L2-0.3729, Test-L2-0.0078, Test-MSE-0.0000
# Epoch-145, Time-4.1879, Train-MSE-0.0001, Train-L2-0.4129, Test-L2-0.0120, Test-MSE-0.0001
# Epoch-146, Time-4.1396, Train-MSE-0.0001, Train-L2-0.4448, Test-L2-0.0089, Test-MSE-0.0000
# Epoch-147, Time-4.0600, Train-MSE-0.0001, Train-L2-0.4054, Test-L2-0.0070, Test-MSE-0.0000
# Epoch-148, Time-3.8998, Train-MSE-0.0001, Train-L2-0.3656, Test-L2-0.0093, Test-MSE-0.0000
# Epoch-149, Time-4.1558, Train-MSE-0.0001, Train-L2-0.4034, Test-L2-0.0075, Test-MSE-0.0000
# Epoch-150, Time-3.5617, Train-MSE-0.0000, Train-L2-0.2662, Test-L2-0.0065, Test-MSE-0.0000
# Epoch-151, Time-3.8821, Train-MSE-0.0000, Train-L2-0.2773, Test-L2-0.0064, Test-MSE-0.0000
# Epoch-152, Time-3.8772, Train-MSE-0.0000, Train-L2-0.2518, Test-L2-0.0059, Test-MSE-0.0000
# Epoch-153, Time-4.2849, Train-MSE-0.0000, Train-L2-0.2489, Test-L2-0.0057, Test-MSE-0.0000
# Epoch-154, Time-4.3037, Train-MSE-0.0000, Train-L2-0.2678, Test-L2-0.0053, Test-MSE-0.0000
# Epoch-155, Time-4.0192, Train-MSE-0.0000, Train-L2-0.2453, Test-L2-0.0066, Test-MSE-0.0000
# Epoch-156, Time-4.2266, Train-MSE-0.0000, Train-L2-0.2538, Test-L2-0.0051, Test-MSE-0.0000
# Epoch-157, Time-4.2219, Train-MSE-0.0000, Train-L2-0.2789, Test-L2-0.0064, Test-MSE-0.0000
# Epoch-158, Time-4.0224, Train-MSE-0.0000, Train-L2-0.2607, Test-L2-0.0061, Test-MSE-0.0000
# Epoch-159, Time-4.3592, Train-MSE-0.0000, Train-L2-0.2612, Test-L2-0.0055, Test-MSE-0.0000
# Epoch-160, Time-4.4198, Train-MSE-0.0000, Train-L2-0.2525, Test-L2-0.0052, Test-MSE-0.0000
# Epoch-161, Time-4.1330, Train-MSE-0.0000, Train-L2-0.2547, Test-L2-0.0074, Test-MSE-0.0000
# Epoch-162, Time-4.3021, Train-MSE-0.0000, Train-L2-0.2886, Test-L2-0.0060, Test-MSE-0.0000
# Epoch-163, Time-4.0507, Train-MSE-0.0000, Train-L2-0.2749, Test-L2-0.0078, Test-MSE-0.0000
# Epoch-164, Time-4.4252, Train-MSE-0.0000, Train-L2-0.2856, Test-L2-0.0070, Test-MSE-0.0000
# Epoch-165, Time-4.0704, Train-MSE-0.0000, Train-L2-0.3083, Test-L2-0.0081, Test-MSE-0.0000
# Epoch-166, Time-3.9983, Train-MSE-0.0000, Train-L2-0.2680, Test-L2-0.0057, Test-MSE-0.0000
# Epoch-167, Time-3.8825, Train-MSE-0.0000, Train-L2-0.2932, Test-L2-0.0056, Test-MSE-0.0000
# Epoch-168, Time-4.1260, Train-MSE-0.0000, Train-L2-0.2985, Test-L2-0.0071, Test-MSE-0.0000
# Epoch-169, Time-4.3065, Train-MSE-0.0000, Train-L2-0.2589, Test-L2-0.0050, Test-MSE-0.0000
# Epoch-170, Time-4.4253, Train-MSE-0.0000, Train-L2-0.2655, Test-L2-0.0057, Test-MSE-0.0000
# Epoch-171, Time-4.2519, Train-MSE-0.0000, Train-L2-0.2502, Test-L2-0.0070, Test-MSE-0.0000
# Epoch-172, Time-3.8898, Train-MSE-0.0000, Train-L2-0.2678, Test-L2-0.0059, Test-MSE-0.0000
# Epoch-173, Time-4.2898, Train-MSE-0.0000, Train-L2-0.2571, Test-L2-0.0054, Test-MSE-0.0000
# Epoch-174, Time-4.0973, Train-MSE-0.0000, Train-L2-0.2866, Test-L2-0.0052, Test-MSE-0.0000
# Epoch-175, Time-4.3560, Train-MSE-0.0000, Train-L2-0.2636, Test-L2-0.0060, Test-MSE-0.0000
# Epoch-176, Time-4.4215, Train-MSE-0.0000, Train-L2-0.2826, Test-L2-0.0053, Test-MSE-0.0000
# Epoch-177, Time-4.2050, Train-MSE-0.0000, Train-L2-0.2542, Test-L2-0.0061, Test-MSE-0.0000
# Epoch-178, Time-4.1032, Train-MSE-0.0000, Train-L2-0.2482, Test-L2-0.0055, Test-MSE-0.0000
# Epoch-179, Time-4.2490, Train-MSE-0.0000, Train-L2-0.2580, Test-L2-0.0066, Test-MSE-0.0000
# Epoch-180, Time-3.6801, Train-MSE-0.0000, Train-L2-0.2694, Test-L2-0.0051, Test-MSE-0.0000
# Epoch-181, Time-4.1241, Train-MSE-0.0000, Train-L2-0.3074, Test-L2-0.0070, Test-MSE-0.0000
# Epoch-182, Time-4.1706, Train-MSE-0.0000, Train-L2-0.2908, Test-L2-0.0055, Test-MSE-0.0000
# Epoch-183, Time-4.0075, Train-MSE-0.0000, Train-L2-0.2534, Test-L2-0.0055, Test-MSE-0.0000
# Epoch-184, Time-4.3014, Train-MSE-0.0000, Train-L2-0.2484, Test-L2-0.0049, Test-MSE-0.0000
# Epoch-185, Time-3.9291, Train-MSE-0.0000, Train-L2-0.2578, Test-L2-0.0058, Test-MSE-0.0000
# Epoch-186, Time-4.3969, Train-MSE-0.0000, Train-L2-0.2478, Test-L2-0.0078, Test-MSE-0.0000
# Epoch-187, Time-4.3983, Train-MSE-0.0000, Train-L2-0.2613, Test-L2-0.0071, Test-MSE-0.0000
# Epoch-188, Time-4.1009, Train-MSE-0.0000, Train-L2-0.2587, Test-L2-0.0109, Test-MSE-0.0001
# Epoch-189, Time-3.6789, Train-MSE-0.0000, Train-L2-0.2580, Test-L2-0.0058, Test-MSE-0.0000
# Epoch-190, Time-4.2704, Train-MSE-0.0000, Train-L2-0.2563, Test-L2-0.0049, Test-MSE-0.0000
# Epoch-191, Time-4.1673, Train-MSE-0.0000, Train-L2-0.2477, Test-L2-0.0076, Test-MSE-0.0000
# Epoch-192, Time-4.3089, Train-MSE-0.0000, Train-L2-0.2787, Test-L2-0.0060, Test-MSE-0.0000
# Epoch-193, Time-4.3449, Train-MSE-0.0000, Train-L2-0.2426, Test-L2-0.0050, Test-MSE-0.0000
# Epoch-194, Time-4.2373, Train-MSE-0.0000, Train-L2-0.2441, Test-L2-0.0067, Test-MSE-0.0000
# Epoch-195, Time-4.2431, Train-MSE-0.0000, Train-L2-0.2516, Test-L2-0.0051, Test-MSE-0.0000
# Epoch-196, Time-4.2867, Train-MSE-0.0000, Train-L2-0.2705, Test-L2-0.0081, Test-MSE-0.0000
# Epoch-197, Time-4.1905, Train-MSE-0.0000, Train-L2-0.2630, Test-L2-0.0057, Test-MSE-0.0000
# Epoch-198, Time-4.4873, Train-MSE-0.0000, Train-L2-0.2461, Test-L2-0.0068, Test-MSE-0.0000
# Epoch-199, Time-3.8676, Train-MSE-0.0000, Train-L2-0.2814, Test-L2-0.0055, Test-MSE-0.0000
# Epoch-200, Time-4.3673, Train-MSE-0.0000, Train-L2-0.1996, Test-L2-0.0042, Test-MSE-0.0000
# Epoch-201, Time-4.3635, Train-MSE-0.0000, Train-L2-0.1955, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-202, Time-4.0784, Train-MSE-0.0000, Train-L2-0.1946, Test-L2-0.0045, Test-MSE-0.0000
# Epoch-203, Time-3.8933, Train-MSE-0.0000, Train-L2-0.2048, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-204, Time-3.6780, Train-MSE-0.0000, Train-L2-0.1894, Test-L2-0.0045, Test-MSE-0.0000
# Epoch-205, Time-4.1504, Train-MSE-0.0000, Train-L2-0.2005, Test-L2-0.0060, Test-MSE-0.0000
# Epoch-206, Time-4.1847, Train-MSE-0.0000, Train-L2-0.2182, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-207, Time-4.0360, Train-MSE-0.0000, Train-L2-0.1986, Test-L2-0.0045, Test-MSE-0.0000
# Epoch-208, Time-4.1695, Train-MSE-0.0000, Train-L2-0.1930, Test-L2-0.0049, Test-MSE-0.0000
# Epoch-209, Time-4.0114, Train-MSE-0.0000, Train-L2-0.2121, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-210, Time-4.2386, Train-MSE-0.0000, Train-L2-0.2056, Test-L2-0.0052, Test-MSE-0.0000
# Epoch-211, Time-4.2175, Train-MSE-0.0000, Train-L2-0.1984, Test-L2-0.0062, Test-MSE-0.0000
# Epoch-212, Time-4.0785, Train-MSE-0.0000, Train-L2-0.2095, Test-L2-0.0047, Test-MSE-0.0000
# Epoch-213, Time-4.3422, Train-MSE-0.0000, Train-L2-0.1980, Test-L2-0.0047, Test-MSE-0.0000
# Epoch-214, Time-4.0739, Train-MSE-0.0000, Train-L2-0.2016, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-215, Time-4.3610, Train-MSE-0.0000, Train-L2-0.1934, Test-L2-0.0049, Test-MSE-0.0000
# Epoch-216, Time-4.3425, Train-MSE-0.0000, Train-L2-0.1974, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-217, Time-4.3739, Train-MSE-0.0000, Train-L2-0.1952, Test-L2-0.0041, Test-MSE-0.0000
# Epoch-218, Time-4.1292, Train-MSE-0.0000, Train-L2-0.2137, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-219, Time-4.3611, Train-MSE-0.0000, Train-L2-0.2094, Test-L2-0.0049, Test-MSE-0.0000
# Epoch-220, Time-3.8470, Train-MSE-0.0000, Train-L2-0.2060, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-221, Time-4.1530, Train-MSE-0.0000, Train-L2-0.2081, Test-L2-0.0052, Test-MSE-0.0000
# Epoch-222, Time-4.2691, Train-MSE-0.0000, Train-L2-0.2034, Test-L2-0.0047, Test-MSE-0.0000
# Epoch-223, Time-4.2861, Train-MSE-0.0000, Train-L2-0.1988, Test-L2-0.0054, Test-MSE-0.0000
# Epoch-224, Time-4.1601, Train-MSE-0.0000, Train-L2-0.2237, Test-L2-0.0069, Test-MSE-0.0000
# Epoch-225, Time-4.2333, Train-MSE-0.0000, Train-L2-0.2031, Test-L2-0.0041, Test-MSE-0.0000
# Epoch-226, Time-4.3023, Train-MSE-0.0000, Train-L2-0.1984, Test-L2-0.0041, Test-MSE-0.0000
# Epoch-227, Time-4.2509, Train-MSE-0.0000, Train-L2-0.2027, Test-L2-0.0042, Test-MSE-0.0000
# Epoch-228, Time-4.3403, Train-MSE-0.0000, Train-L2-0.2031, Test-L2-0.0047, Test-MSE-0.0000
# Epoch-229, Time-4.3864, Train-MSE-0.0000, Train-L2-0.2159, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-230, Time-4.2501, Train-MSE-0.0000, Train-L2-0.2038, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-231, Time-4.0206, Train-MSE-0.0000, Train-L2-0.1952, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-232, Time-4.2340, Train-MSE-0.0000, Train-L2-0.1974, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-233, Time-4.0958, Train-MSE-0.0000, Train-L2-0.2007, Test-L2-0.0045, Test-MSE-0.0000
# Epoch-234, Time-4.2158, Train-MSE-0.0000, Train-L2-0.2009, Test-L2-0.0053, Test-MSE-0.0000
# Epoch-235, Time-4.1148, Train-MSE-0.0000, Train-L2-0.1981, Test-L2-0.0044, Test-MSE-0.0000
# Epoch-236, Time-4.0758, Train-MSE-0.0000, Train-L2-0.2069, Test-L2-0.0041, Test-MSE-0.0000
# Epoch-237, Time-4.1810, Train-MSE-0.0000, Train-L2-0.2010, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-238, Time-4.2521, Train-MSE-0.0000, Train-L2-0.2020, Test-L2-0.0047, Test-MSE-0.0000
# Epoch-239, Time-4.2609, Train-MSE-0.0000, Train-L2-0.1963, Test-L2-0.0042, Test-MSE-0.0000
# Epoch-240, Time-4.2026, Train-MSE-0.0000, Train-L2-0.2085, Test-L2-0.0048, Test-MSE-0.0000
# Epoch-241, Time-3.8740, Train-MSE-0.0000, Train-L2-0.1898, Test-L2-0.0043, Test-MSE-0.0000
# Epoch-242, Time-4.2563, Train-MSE-0.0000, Train-L2-0.1867, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-243, Time-4.4291, Train-MSE-0.0000, Train-L2-0.1901, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-244, Time-4.0002, Train-MSE-0.0000, Train-L2-0.2107, Test-L2-0.0051, Test-MSE-0.0000
# Epoch-245, Time-4.1938, Train-MSE-0.0000, Train-L2-0.2056, Test-L2-0.0046, Test-MSE-0.0000
# Epoch-246, Time-4.3604, Train-MSE-0.0000, Train-L2-0.1988, Test-L2-0.0043, Test-MSE-0.0000
# Epoch-247, Time-4.3009, Train-MSE-0.0000, Train-L2-0.1928, Test-L2-0.0045, Test-MSE-0.0000
# Epoch-248, Time-4.2456, Train-MSE-0.0000, Train-L2-0.1917, Test-L2-0.0050, Test-MSE-0.0000
# Epoch-249, Time-4.4695, Train-MSE-0.0000, Train-L2-0.2043, Test-L2-0.0042, Test-MSE-0.0000
# Epoch-250, Time-4.1263, Train-MSE-0.0000, Train-L2-0.1715, Test-L2-0.0038, Test-MSE-0.0000
# Epoch
Test-L2-0.0034, Test-MSE-0.0000
# Epoch-474, Time-4.1433, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0035, Test-MSE-0.0000
# Epoch-475, Time-4.5764, Train-MSE-0.0000, Train-L2-0.1431, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-476, Time-4.3137, Train-MSE-0.0000, Train-L2-0.1436, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-477, Time-4.3386, Train-MSE-0.0000, Train-L2-0.1431, Test-L2-0.0035, Test-MSE-0.0000
# Epoch-478, Time-4.0800, Train-MSE-0.0000, Train-L2-0.1437, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-479, Time-4.4623, Train-MSE-0.0000, Train-L2-0.1434, Test-L2-0.0035, Test-MSE-0.0000
# Epoch-480, Time-4.4019, Train-MSE-0.0000, Train-L2-0.1432, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-481, Time-4.2554, Train-MSE-0.0000, Train-L2-0.1426, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-482, Time-4.0712, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0035, Test-MSE-0.0000
# Epoch-483, Time-4.2254, Train-MSE-0.0000, Train-L2-0.1431, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-484, Time-3.9963, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-485, Time-4.0705, Train-MSE-0.0000, Train-L2-0.1428, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-486, Time-4.3825, Train-MSE-0.0000, Train-L2-0.1429, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-487, Time-4.3474, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-488, Time-4.2542, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-489, Time-4.1615, Train-MSE-0.0000, Train-L2-0.1432, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-490, Time-4.1470, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-491, Time-4.1492, Train-MSE-0.0000, Train-L2-0.1431, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-492, Time-4.1731, Train-MSE-0.0000, Train-L2-0.1427, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-493, Time-4.3360, Train-MSE-0.0000, Train-L2-0.1428, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-494, Time-4.1725, Train-MSE-0.0000, Train-L2-0.1434, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-495, Time-4.1847, Train-MSE-0.0000, Train-L2-0.1430, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-496, Time-4.4317, Train-MSE-0.0000, Train-L2-0.1435, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-497, Time-4.3575, Train-MSE-0.0000, Train-L2-0.1427, Test-L2-0.0034, Test-MSE-0.0000
# Epoch-498, Time-4.1853, Train-MSE-0.0000, Train-L2-0.1433, Test-L2-0.0035, Test-MSE-0.0000
# Epoch-499, Time-4.3475, Train-MSE-0.0000, Train-L2-0.1429, Test-L2-0.0035, Test-MSE-0.0000

# %%
# Save the LF-WNO model

torch.save(model_lf, 'model/LF_WNO_poisson1D')

# %%
# Prediction:
pred_lf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_lf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_lf(x).squeeze(-1)
        test_l2 = myloss(out.view(x.shape[0], -1), y.view(x.shape[0], -1)).item()
        test_l2 /= x.shape[0]
        pred_lf.append( out.cpu() )
        if index % 50 == 0:
            print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_lf = torch.cat(( pred_lf ))
print('Mean L2-{}'.format(myloss(y_test_lf, pred_lf).item()/ntest_l))

# %%
mse_pred = F.mse_loss(y_test_lf, pred_lf).item()

print('MSE-Predicted solution-{:0.6f}'.format(mse_pred))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, pred_lf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, y_test_lf[i,:], '--', color=colors[index], linewidth=4, label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
# If required, save the data 
# data = scipy.io.loadmat('data/wnosheat_lowfiddata.mat')
scipy.io.savemat('data/wno_poisson_lowfiddata.mat', mdict={'x_data_h':x_data_h,
                                                    'y_data_h':y_data_h,
                                                    'y_data_l':y_data_l,  
                                                    'pred_lf':pred_lf.cpu().numpy()})

# %% [markdown]
# # Multifidelity

# %%
ntrain = 50
ntest = 40
n_total = ntrain + ntest
last_m = 400
s = 100

batch_size = 5
learning_rate = 0.001

w_decay = 1e-4
epochs = 500
step_size = 50   # weight-decay step size
gamma = 0.5      # weight-decay rate

wavelet = 'db6'  # wavelet basis function
level = 3        # lavel of wavelet decomposition
width = 64       # uplifting dimension
layers = 4       # no of wavelet layers

h = 100           # total grid size divided by the subsampling rate
grid_range = 1
in_channel = 3   # (a(x), x) for this case

# %%
PATH = 'data/possion_10pt_100pt__lscale_01.npz'
data = np.load(PATH)

x_data_h = data['f_stoch'][last_m-n_total:last_m]
y_data_l = data['y_low_100'][last_m-n_total:last_m]
y_data_h = data['yhi'][last_m-n_total:last_m]
x_coords = data['xhi'].reshape((s,))

# %%
 data['f_stoch'].shape

# %%
# read data

x_mf = np.stack((x_data_h, y_data_l), axis=-1)
y_mf = y_data_h - y_data_l

x_train_mf, y_train_mf = x_mf[:ntrain, ...], y_mf[:ntrain, ...]
x_test_mf, y_test_mf = x_mf[-ntest:, ...], y_mf[-ntest:, ...]

x_train_mf = torch.tensor( x_train_mf, dtype=torch.float )
y_train_mf = torch.tensor( y_train_mf, dtype=torch.float ) 
x_test_mf = torch.tensor( x_test_mf, dtype=torch.float ) 
y_test_mf = torch.tensor( y_test_mf, dtype=torch.float ) 

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                              batch_size=batch_size, shuffle=True)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_mf.shape, y_mf.shape, x_train_mf.shape, y_train_mf.shape, x_test_mf.shape, y_test_mf.shape)

# %%
# model
model_mf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=3, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_mf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    test_mse = 0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.cuda(), y.cuda()

            out = model_mf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
            tmse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
            test_mse += tmse.item()

    train_mse /= len(train_loader_mf)
    train_l2 /= ntrain
    test_l2 /= ntest
    test_mse /= len(test_loader_mf)
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}, Test-MSE-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2, test_mse))
# Out:
# Epoch-92, Time-0.4096, Train-MSE-0.0000, Train-L2-0.0764, Test-L2-0.5392, Test-MSE-0.0005
# Epoch-93, Time-0.4097, Train-MSE-0.0000, Train-L2-0.0835, Test-L2-0.5352, Test-MSE-0.0005
# Epoch-94, Time-0.3971, Train-MSE-0.0000, Train-L2-0.0920, Test-L2-0.5376, Test-MSE-0.0005
# Epoch-95, Time-0.3863, Train-MSE-0.0000, Train-L2-0.1037, Test-L2-0.5341, Test-MSE-0.0005
# Epoch-96, Time-0.4043, Train-MSE-0.0000, Train-L2-0.0934, Test-L2-0.5321, Test-MSE-0.0005
# Epoch-97, Time-0.4085, Train-MSE-0.0000, Train-L2-0.0965, Test-L2-0.5367, Test-MSE-0.0005
# Epoch-98, Time-0.3920, Train-MSE-0.0000, Train-L2-0.0832, Test-L2-0.5333, Test-MSE-0.0005
# Epoch-99, Time-0.3790, Train-MSE-0.0000, Train-L2-0.0886, Test-L2-0.5240, Test-MSE-0.0005
# Epoch-100, Time-0.3953, Train-MSE-0.0000, Train-L2-0.0734, Test-L2-0.5277, Test-MSE-0.0005
# Epoch-101, Time-0.3997, Train-MSE-0.0000, Train-L2-0.0618, Test-L2-0.5284, Test-MSE-0.0005
# Epoch-102, Time-0.3885, Train-MSE-0.0000, Train-L2-0.0561, Test-L2-0.5308, Test-MSE-0.0005
# Epoch-103, Time-0.4049, Train-MSE-0.0000, Train-L2-0.0513, Test-L2-0.5282, Test-MSE-0.0005
# Epoch-104, Time-0.3988, Train-MSE-0.0000, Train-L2-0.0486, Test-L2-0.5350, Test-MSE-0.0005
# Epoch-105, Time-0.4139, Train-MSE-0.0000, Train-L2-0.0421, Test-L2-0.5296, Test-MSE-0.0005
# Epoch-106, Time-0.4152, Train-MSE-0.0000, Train-L2-0.0421, Test-L2-0.5304, Test-MSE-0.0005
# Epoch-107, Time-0.3908, Train-MSE-0.0000, Train-L2-0.0420, Test-L2-0.5289, Test-MSE-0.0005
# Epoch-108, Time-0.4267, Train-MSE-0.0000, Train-L2-0.0461, Test-L2-0.5354, Test-MSE-0.0005
# Epoch-109, Time-0.3940, Train-MSE-0.0000, Train-L2-0.0497, Test-L2-0.5303, Test-MSE-0.0005
# Epoch-110, Time-0.3779, Train-MSE-0.0000, Train-L2-0.0439, Test-L2-0.5310, Test-MSE-0.0005
# Epoch-111, Time-0.3894, Train-MSE-0.0000, Train-L2-0.0385, Test-L2-0.5275, Test-MSE-0.0005
# Epoch-112, Time-0.3749, Train-MSE-0.0000, Train-L2-0.0378, Test-L2-0.5312, Test-MSE-0.0005
Train-MSE-0.0000, Train-L2-0.0071, Test-L2-0.5306, Test-MSE-0.0005
# Epoch-498, Time-0.4004, Train-MSE-0.0000, Train-L2-0.0071, Test-L2-0.5306, Test-MSE-0.0005
# Epoch-499, Time-0.3977, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-0.5306, Test-MSE-0.0005

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_poisson1D_50')

# %%
# Prediction:
pred_mf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_mf(x).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_mf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_mf = torch.cat(( pred_mf ))
print('Mean mse_mf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
pred_mf.shape

# %%
inp_mf  = x_test_mf 
real_mf = y_test_mf + inp_mf[:,:,1]
output_mf  =  pred_mf + inp_mf[:,:,1]

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()

print('MSE-Predicted solution-{:0.6f}'.format(mse_pred))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_mf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_mf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
colormap = plt.cm.jet  
colors2 = [colormap(i) for i in np.linspace(0, 1, 5)]

fig1 = plt.figure(figsize = (10, 4), dpi=300)
fig1.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, inp_mf[i, :, 0], color=colors2[index], label='Forcing-{}'.format(i))
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %% [markdown]
# # High Fidelity

# %%
# read data
x_hf = torch.tensor( x_data_h, dtype=torch.float ).unsqueeze(-1)
y_hf = torch.tensor( y_data_h, dtype=torch.float ) 

x_train_hf, y_train_hf = x_hf[:ntrain, ...], y_hf[:ntrain, ...]
x_test_hf, y_test_hf = x_hf[-ntest:, ...], y_hf[-ntest:, ...]

train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                              batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, x_test_hf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_train_hf.shape, y_train_hf.shape, x_test_hf.shape, y_test_hf.shape)

# %%
# model
model_hf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=2, grid_range=grid_range).to(device)
print(count_params(model_hf))

optimizer = torch.optim.Adam(model_hf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_hf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_hf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_hf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.cuda(), y.cuda()

            out = model_hf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()

    train_mse /= len(train_loader_hf)
    train_l2 /= ntrain
    test_l2 /= ntest

    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-113, Time-0.4042, Train-MSE-0.0017, Train-L2-0.0450, Test-L2-1.5263
# Epoch-114, Time-0.3791, Train-MSE-0.0015, Train-L2-0.0417, Test-L2-1.5394
# Epoch-115, Time-0.4040, Train-MSE-0.0012, Train-L2-0.0342, Test-L2-1.5465
# Epoch-116, Time-0.4003, Train-MSE-0.0011, Train-L2-0.0340, Test-L2-1.5406
# Epoch-117, Time-0.3992, Train-MSE-0.0012, Train-L2-0.0415, Test-L2-1.5569
# Epoch-118, Time-0.4027, Train-MSE-0.0014, Train-L2-0.0474, Test-L2-1.5358
# Epoch-119, Time-0.3988, Train-MSE-0.0016, Train-L2-0.0484, Test-L2-1.5553
# Epoch-120, Time-0.4033, Train-MSE-0.0016, Train-L2-0.0476, Test-L2-1.5487
# Epoch-121, Time-0.4037, Train-MSE-0.0013, Train-L2-0.0431, Test-L2-1.5336
# Epoch-122, Time-0.4123, Train-MSE-0.0012, Train-L2-0.0385, Test-L2-1.5431
# Epoch-123, Time-0.4031, Train-MSE-0.0011, Train-L2-0.0347, Test-L2-1.5376
# Epoch-124, Time-0.4142, Train-MSE-0.0014, Train-L2-0.0417, Test-L2-1.5397
# Epoch-125, Time-0.4132, Train-MSE-0.0012, Train-L2-0.0450, Test-L2-1.5394
# Epoch-126, Time-0.3953, Train-MSE-0.0013, Train-L2-0.0442, Test-L2-1.5482
# Epoch-127, Time-0.4001, Train-MSE-0.0014, Train-L2-0.0448, Test-L2-1.5449
# Epoch-128, Time-0.4120, Train-MSE-0.0011, Train-L2-0.0411, Test-L2-1.5447
# Epoch-129, Time-0.4232, Train-MSE-0.0010, Train-L2-0.0352, Test-L2-1.5427
# Epoch-130, Time-0.4234, Train-MSE-0.0009, Train-L2-0.0372, Test-L2-1.5375
# Epoch-131, Time-0.3905, Train-MSE-0.0010, Train-L2-0.0384, Test-L2-1.5353
# Epoch-132, Time-0.3803, Train-MSE-0.0010, Train-L2-0.0389, Test-L2-1.5446
# Epoch-133, Time-0.3756, Train-MSE-0.0010, Train-L2-0.0379, Test-L2-1.5435
# Epoch-134, Time-0.3718, Train-MSE-0.0009, Train-L2-0.0336, Test-L2-1.5361
# Epoch-135, Time-0.3713, Train-MSE-0.0009, Train-L2-0.0367, Test-L2-1.5463
# Epoch-136, Time-0.3766, Train-MSE-0.0012, Train-L2-0.0414, Test-L2-1.5307
# Epoch-137, Time-0.4004, Train-MSE-0.0012, Train-L2-0.0443, Test-L2-1.5492
# Epoch-138, Time-0.4053, Train-MSE-0.0016, Train-L2-0.0449, Test-L2-1.5428
# Epoch-139, Time-0.4240, Train-MSE-0.0012, Train-L2-0.0465, Test-L2-1.5403
# Epoch-140, Time-0.4072, Train-MSE-0.0011, Train-L2-0.0410, Test-L2-1.5461
# Epoch-141, Time-0.4013, Train-MSE-0.0008, Train-L2-0.0376, Test-L2-1.5436
# Epoch-142, Time-0.4059, Train-MSE-0.0008, Train-L2-0.0339, Test-L2-1.5567
# Epoch-143, Time-0.4009, Train-MSE-0.0008, Train-L2-0.0317, Test-L2-1.5492
# Epoch-144, Time-0.3957, Train-MSE-0.0008, Train-L2-0.0365, Test-L2-1.5518
# Epoch-145, Time-0.3882, Train-MSE-0.0007, Train-L2-0.0369, Test-L2-1.5420
# Epoch-146, Time-0.3915, Train-MSE-0.0008, Train-L2-0.0344, Test-L2-1.5431
# Epoch-147, Time-0.3751, Train-MSE-0.0007, Train-L2-0.0333, Test-L2-1.5357
# Epoch-148, Time-0.3591, Train-MSE-0.0009, Train-L2-0.0383, Test-L2-1.5569
# Epoch-149, Time-0.3949, Train-MSE-0.0009, Train-L2-0.0360, Test-L2-1.5505
# Epoch-150, Time-0.3933, Train-MSE-0.0006, Train-L2-0.0274, Test-L2-1.5435
# Epoch-151, Time-0.3670, Train-MSE-0.0005, Train-L2-0.0233, Test-L2-1.5450
# Epoch-152, Time-0.3976, Train-MSE-0.0004, Train-L2-0.0211, Test-L2-1.5483
# Epoch-153, Time-0.4119, Train-MSE-0.0004, Train-L2-0.0200, Test-L2-1.5460
# Epoch-154, Time-0.3913, Train-MSE-0.0004, Train-L2-0.0196, Test-L2-1.5440
# Epoch-155, Time-0.3878, Train-MSE-0.0004, Train-L2-0.0216, Test-L2-1.5447
# Epoch-156, Time-0.4116, Train-MSE-0.0004, Train-L2-0.0207, Test-L2-1.5374
# Epoch-157, Time-0.3923, Train-MSE-0.0005, Train-L2-0.0228, Test-L2-1.5499
# Epoch-158, Time-0.3792, Train-MSE-0.0004, Train-L2-0.0226, Test-L2-1.5463
# Epoch-159, Time-0.3855, Train-MSE-0.0004, Train-L2-0.0217, Test-L2-1.5430
# Epoch-160, Time-0.3655, Train-MSE-0.0005, Train-L2-0.0228, Test-L2-1.5487
# Epoch-161, Time-0.3765, Train-MSE-0.0004, Train-L2-0.0219, Test-L2-1.5397
# Epoch-162, Time-0.4002, Train-MSE-0.0004, Train-L2-0.0222, Test-L2-1.5447
# Epoch-163, Time-0.4081, Train-MSE-0.0005, Train-L2-0.0240, Test-L2-1.5522
# Epoch-164, Time-0.3867, Train-MSE-0.0004, Train-L2-0.0223, Test-L2-1.5437
# Epoch-165, Time-0.4208, Train-MSE-0.0004, Train-L2-0.0206, Test-L2-1.5473
# Epoch-166, Time-0.3769, Train-MSE-0.0003, Train-L2-0.0195, Test-L2-1.5420
# Epoch-167, Time-0.3881, Train-MSE-0.0004, Train-L2-0.0193, Test-L2-1.5449
# Epoch-168, Time-0.3853, Train-MSE-0.0003, Train-L2-0.0197, Test-L2-1.5452
# Epoch-169, Time-0.3885, Train-MSE-0.0007, Train-L2-0.0316, Test-L2-1.5459
# Epoch-170, Time-0.4083, Train-MSE-0.0005, Train-L2-0.0270, Test-L2-1.5442
# Epoch-171, Time-0.3976, Train-MSE-0.0004, Train-L2-0.0221, Test-L2-1.5434
# Epoch-172, Time-0.3757, Train-MSE-0.0004, Train-L2-0.0252, Test-L2-1.5506
# Epoch-173, Time-0.3732, Train-MSE-0.0004, Train-L2-0.0207, Test-L2-1.5504
# Epoch-174, Time-0.3840, Train-MSE-0.0004, Train-L2-0.0222, Test-L2-1.5377
# Epoch-175, Time-0.4011, Train-MSE-0.0004, Train-L2-0.0209, Test-L2-1.5440
# Epoch-176, Time-0.3631, Train-MSE-0.0004, Train-L2-0.0203, Test-L2-1.5446
# Epoch-177, Time-0.3677, Train-MSE-0.0005, Train-L2-0.0252, Test-L2-1.5526
# Epoch-178, Time-0.3831, Train-MSE-0.0005, Train-L2-0.0275, Test-L2-1.5441
# Epoch-179, Time-0.4059, Train-MSE-0.0007, Train-L2-0.0339, Test-L2-1.5421
# Epoch-180, Time-0.3801, Train-MSE-0.0009, Train-L2-0.0335, Test-L2-1.5433
# Epoch-181, Time-0.3906, Train-MSE-0.0005, Train-L2-0.0306, Test-L2-1.5506
# Epoch-182, Time-0.3804, Train-MSE-0.0011, Train-L2-0.0421, Test-L2-1.5453
# Epoch-183, Time-0.3553, Train-MSE-0.0009, Train-L2-0.0365, Test-L2-1.5411
# Epoch-184, Time-0.3600, Train-MSE-0.0004, Train-L2-0.0240, Test-L2-1.5503
# Epoch-185, Time-0.3655, Train-MSE-0.0003, Train-L2-0.0217, Test-L2-1.5454
# Epoch-186, Time-0.3945, Train-MSE-0.0005, Train-L2-0.0239, Test-L2-1.5484
# Epoch-187, Time-0.3868, Train-MSE-0.0004, Train-L2-0.0231, Test-L2-1.5483
# Epoch-188, Time-0.3643, Train-MSE-0.0003, Train-L2-0.0210, Test-L2-1.5434
# Epoch-189, Time-0.3768, Train-MSE-0.0003, Train-L2-0.0178, Test-L2-1.5460
# Epoch-190, Time-0.3990, Train-MSE-0.0003, Train-L2-0.0189, Test-L2-1.5483
# Epoch-191, Time-0.3848, Train-MSE-0.0003, Train-L2-0.0177, Test-L2-1.5454
# Epoch-192, Time-0.3793, Train-MSE-0.0003, Train-L2-0.0208, Test-L2-1.5507
# Epoch-193, Time-0.3792, Train-MSE-0.0003, Train-L2-0.0208, Test-L2-1.5446
# Epoch-194, Time-0.3849, Train-MSE-0.0003, Train-L2-0.0191, Test-L2-1.5453
# Epoch-195, Time-0.4040, Train-MSE-0.0003, Train-L2-0.0183, Test-L2-1.5464
# Epoch-196, Time-0.4264, Train-MSE-0.0003, Train-L2-0.0189, Test-L2-1.5476
# Epoch-197, Time-0.4048, Train-MSE-0.0003, Train-L2-0.0174, Test-L2-1.5435
# Epoch-198, Time-0.3813, Train-MSE-0.0003, Train-L2-0.0177, Test-L2-1.5506
# Epoch-199, Time-0.3729, Train-MSE-0.0003, Train-L2-0.0222, Test-L2-1.5417
# Epoch-200, Time-0.3941, Train-MSE-0.0003, Train-L2-0.0218, Test-L2-1.5493
# Epoch-201, Time-0.3980, Train-MSE-0.0002, Train-L2-0.0174, Test-L2-1.5446
# Epoch-202, Time-0.4050, Train-MSE-0.0002, Train-L2-0.0149, Test-L2-1.5479
# Epoch-203, Time-0.3689, Train-MSE-0.0002, Train-L2-0.0142, Test-L2-1.5463
# Epoch-204, Time-0.3985, Train-MSE-0.0002, Train-L2-0.0140, Test-L2-1.5455
# Epoch-205, Time-0.3760, Train-MSE-0.0002, Train-L2-0.0140, Test-L2-1.5444
# Epoch-206, Time-0.3742, Train-MSE-0.0002, Train-L2-0.0142, Test-L2-1.5495
# Epoch-207, Time-0.3766, Train-MSE-0.0002, Train-L2-0.0138, Test-L2-1.5438
# Epoch-208, Time-0.3591, Train-MSE-0.0002, Train-L2-0.0140, Test-L2-1.5449
# Epoch-209, Time-0.3758, Train-MSE-0.0002, Train-L2-0.0129, Test-L2-1.5470
# Epoch-210, Time-0.3930, Train-MSE-0.0002, Train-L2-0.0125, Test-L2-1.5477
# Epoch-211, Time-0.3615, Train-MSE-0.0002, Train-L2-0.0136, Test-L2-1.5449
# Epoch-212, Time-0.3993, Train-MSE-0.0002, Train-L2-0.0136, Test-L2-1.5452
# Epoch-213, Time-0.3861, Train-MSE-0.0002, Train-L2-0.0139, Test-L2-1.5466
# Epoch-214, Time-0.3799, Train-MSE-0.0002, Train-L2-0.0129, Test-L2-1.5496
# Epoch-215, Time-0.3800, Train-MSE-0.0002, Train-L2-0.0127, Test-L2-1.5457
# Epoch-216, Time-0.3482, Train-MSE-0.0002, Train-L2-0.0123, Test-L2-1.5458
# Epoch-217, Time-0.3337, Train-MSE-0.0002, Train-L2-0.0128, Test-L2-1.5462
# Epoch-218, Time-0.3565, Train-MSE-0.0002, Train-L2-0.0135, Test-L2-1.5479
# Epoch-219, Time-0.3801, Train-MSE-0.0002, Train-L2-0.0136, Test-L2-1.5451
# Epoch-220, Time-0.3757, Train-MSE-0.0002, Train-L2-0.0136, Test-L2-1.5475
# Epoch-221, Time-0.3671, Train-MSE-0.0002, Train-L2-0.0123, Test-L2-1.5469
# Epoch-222, Time-0.3520, Train-MSE-0.0002, Train-L2-0.0116, Test-L2-1.5463
# Epoch-223, Time-0.3705, Train-MSE-0.0002, Train-L2-0.0113, Test-L2-1.5468
# Epoch-224, Time-0.3995, Train-MSE-0.0002, Train-L2-0.0113, Test-L2-1.5466
# Epoch-225, Time-0.4111, Train-MSE-0.0002, Train-L2-0.0114, Test-L2-1.5464
# Epoch-226, Time-0.3956, Train-MSE-0.0002, Train-L2-0.0112, Test-L2-1.5478
# Epoch-227, Time-0.3909, Train-MSE-0.0002, Train-L2-0.0118, Test-L2-1.5489
# Epoch-228, Time-0.3820, Train-MSE-0.0002, Train-L2-0.0126, Test-L2-1.5444
# Epoch-229, Time-0.3782, Train-MSE-0.0002, Train-L2-0.0132, Test-L2-1.5481
# Epoch-230, Time-0.3898, Train-MSE-0.0002, Train-L2-0.0162, Test-L2-1.5438
# Epoch-231, Time-0.3686, Train-MSE-0.0002, Train-L2-0.0151, Test-L2-1.5497
# Epoch-232, Time-0.3726, Train-MSE-0.0002, Train-L2-0.0140, Test-L2-1.5463
# Epoch-233, Time-0.3718, Train-MSE-0.0002, Train-L2-0.0126, Test-L2-1.5459
# Epoch-234, Time-0.3692, Train-MSE-0.0002, Train-L2-0.0136, Test-L2-1.5470
# Epoch-235, Time-0.3981, Train-MSE-0.0002, Train-L2-0.0128, Test-L2-1.5465
# Epoch-236, Time-0.3437, Train-MSE-0.0002, Train-L2-0.0129, Test-L2-1.5455
# Epoch-237, Time-0.3361, Train-MSE-0.0002, Train-L2-0.0147, Test-L2-1.5437
# Epoch-238, Time-0.3397, Train-MSE-0.0002, Train-L2-0.0133, Test-L2-1.5477
# Epoch-239, Time-0.3332, Train-MSE-0.0002, Train-L2-0.0123, Test-L2-1.5453
# Epoch-240, Time-0.3329, Train-MSE-0.0002, Train-L2-0.0132, Test-L2-1.5463
# Epoch-241, Time-0.4003, Train-MSE-0.0002, Train-L2-0.0132, Test-L2-1.5503
# Epoch-242, Time-0.3865, Train-MSE-0.0002, Train-L2-0.0145, Test-L2-1.5414
# Epoch-243, Time-0.4013, Train-MSE-0.0002, Train-L2-0.0158, Test-L2-1.5488
# Epoch-244, Time-0.4037, Train-MSE-0.0002, Train-L2-0.0160, Test-L2-1.5468
# Epoch-245, Time-0.3934, Train-MSE-0.0002, Train-L2-0.0153, Test-L2-1.5457
# Epoch-246, Time-0.4069, Train-MSE-0.0002, Train-L2-0.0140, Test-L2-1.5481
# Epoch-247, Time-0.3717, Train-MSE-0.0003, Train-L2-0.0195, Test-L2-1.5444
# Epoch-248, Time-0.3615, Train-MSE-0.0002, Train-L2-0.0152, Test-L2-1.5469
# Epoch-249, Time-0.3347, Train-MSE-0.0001, Train-L2-0.0131, Test-L2-1.5481
# Epoch-250, Time-0.3334, Train-MSE-0.0001, Train-L2-0.0112, Test-L2-1.5463
# Epoch-251, Time-0.3365, Train-MSE-0.0001, Train-L2-0.0101, Test-L2-1.5469
# Epoch-252, Time-0.3345, Train-MSE-0.0001, Train-L2-0.0101, Test-L2-1.5469
# Epoch-253, Time-0.3332, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5470
# Epoch-254, Time-0.3335, Train-MSE-0.0001, Train-L2-0.0094, Test-L2-1.5464
# Epoch-255, Time-0.3346, Train-MSE-0.0001, Train-L2-0.0098, Test-L2-1.5468
# Epoch-256, Time-0.3348, Train-MSE-0.0001, Train-L2-0.0100, Test-L2-1.5476
# Epoch-257, Time-0.3685, Train-MSE-0.0001, Train-L2-0.0107, Test-L2-1.5464
# Epoch-258, Time-0.4157, Train-MSE-0.0001, Train-L2-0.0108, Test-L2-1.5462
# Epoch-259, Time-0.4085, Train-MSE-0.0001, Train-L2-0.0101, Test-L2-1.5471
# Epoch-260, Time-0.4080, Train-MSE-0.0001, Train-L2-0.0102, Test-L2-1.5467
# Epoch-261, Time-0.3782, Train-MSE-0.0001, Train-L2-0.0103, Test-L2-1.5466
# Epoch-262, Time-0.3336, Train-MSE-0.0001, Train-L2-0.0102, Test-L2-1.5481
# Epoch-263, Time-0.3379, Train-MSE-0.0001, Train-L2-0.0106, Test-L2-1.5453
# Epoch-264, Time-0.3429, Train-MSE-0.0001, Train-L2-0.0102, Test-L2-1.5471
# Epoch-265, Time-0.3992, Train-MSE-0.0001, Train-L2-0.0094, Test-L2-1.5471
# Epoch-266, Time-0.3800, Train-MSE-0.0001, Train-L2-0.0098, Test-L2-1.5463
# Epoch-267, Time-0.4067, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5465
# Epoch-268, Time-0.3768, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5477
# Epoch-269, Time-0.4028, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5466
# Epoch-270, Time-0.3997, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5461
# Epoch-271, Time-0.3804, Train-MSE-0.0001, Train-L2-0.0099, Test-L2-1.5474
# Epoch-272, Time-0.3873, Train-MSE-0.0001, Train-L2-0.0093, Test-L2-1.5475
# Epoch-273, Time-0.3802, Train-MSE-0.0001, Train-L2-0.0093, Test-L2-1.5462
# Epoch-274, Time-0.4007, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5466
# Epoch-275, Time-0.3880, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5472
# Epoch-276, Time-0.3623, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5460
# Epoch-277, Time-0.3640, Train-MSE-0.0001, Train-L2-0.0093, Test-L2-1.5478
# Epoch-278, Time-0.3816, Train-MSE-0.0001, Train-L2-0.0094, Test-L2-1.5457
# Epoch-279, Time-0.3883, Train-MSE-0.0001, Train-L2-0.0093, Test-L2-1.5467
# Epoch-280, Time-0.3989, Train-MSE-0.0001, Train-L2-0.0094, Test-L2-1.5476
# Epoch-281, Time-0.4032, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5460
# Epoch-282, Time-0.3954, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5472
# Epoch-283, Time-0.3811, Train-MSE-0.0001, Train-L2-0.0091, Test-L2-1.5466
# Epoch-284, Time-0.4117, Train-MSE-0.0001, Train-L2-0.0090, Test-L2-1.5471
# Epoch-285, Time-0.4147, Train-MSE-0.0001, Train-L2-0.0089, Test-L2-1.5466
# Epoch-286, Time-0.4017, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5471
# Epoch-287, Time-0.4069, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5475
# Epoch-288, Time-0.4081, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5458
# Epoch-289, Time-0.4238, Train-MSE-0.0001, Train-L2-0.0094, Test-L2-1.5475
# Epoch-290, Time-0.4116, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5468
# Epoch-291, Time-0.4312, Train-MSE-0.0001, Train-L2-0.0100, Test-L2-1.5466
# Epoch-292, Time-0.4130, Train-MSE-0.0001, Train-L2-0.0093, Test-L2-1.5472
# Epoch-293, Time-0.4111, Train-MSE-0.0001, Train-L2-0.0089, Test-L2-1.5467
# Epoch-294, Time-0.3975, Train-MSE-0.0001, Train-L2-0.0091, Test-L2-1.5463
# Epoch-295, Time-0.3939, Train-MSE-0.0001, Train-L2-0.0089, Test-L2-1.5475
# Epoch-296, Time-0.4087, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5468
# Epoch-297, Time-0.4007, Train-MSE-0.0001, Train-L2-0.0092, Test-L2-1.5469
# Epoch-298, Time-0.4250, Train-MSE-0.0001, Train-L2-0.0095, Test-L2-1.5477
# Epoch-299, Time-0.4139, Train-MSE-0.0001, Train-L2-0.0096, Test-L2-1.5467
# Epoch-300, Time-0.3902, Train-MSE-0.0001, Train-L2-0.0091, Test-L2-1.5475
# Epoch-301, Time-0.3949, Train-MSE-0.0001, Train-L2-0.0086, Test-L2-1.5465
# Epoch-302, Time-0.3955, Train-MSE-0.0001, Train-L2-0.0085, Test-L2-1.5469
# Epoch-303, Time-0.4111, Train-MSE-0.0001, Train-L2-0.0083, Test-L2-1.5470
# Epoch-304, Time-0.4192, Train-MSE-0.0001, Train-L2-0.0084, Test-L2-1.5469
# Epoch-305, Time-0.4032, Train-MSE-0.0001, Train-L2-0.0087, Test-L2-1.5472
# Epoch-306, Time-0.4094, Train-MSE-0.0001, Train-L2-0.0084, Test-L2-1.5470
# Epoch-307, Time-0.4118, Train-MSE-0.0001, Train-L2-0.0084, Test-L2-1.5469
# Epoch-308, Time-0.4045, Train-MSE-0.0001, Train-L2-0.0083, Test-L2-1.5469
# Epoch-309, Time-0.4091, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5468
# Epoch-310, Time-0.3809, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5471
# Epoch-311, Time-0.4398, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5469
# Epoch-312, Time-0.3845, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5469
# Epoch-313, Time-0.3901, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5468
# Epoch-314, Time-0.4007, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5473
# Epoch-315, Time-0.4005, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5469
# Epoch-316, Time-0.3935, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5470
# Epoch-317, Time-0.3985, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5471
# Epoch-318, Time-0.3850, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5470
# Epoch-319, Time-0.4263, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5473
# Epoch-320, Time-0.4229, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5464
# Epoch-321, Time-0.4004, Train-MSE-0.0001, Train-L2-0.0086, Test-L2-1.5477
# Epoch-322, Time-0.4126, Train-MSE-0.0001, Train-L2-0.0084, Test-L2-1.5464
# Epoch-323, Time-0.3816, Train-MSE-0.0001, Train-L2-0.0082, Test-L2-1.5475
# Epoch-324, Time-0.4371, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5464
# Epoch-325, Time-0.4155, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5474
# Epoch-326, Time-0.3918, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5467
# Epoch-327, Time-0.4124, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5468
# Epoch-328, Time-0.3962, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5473
# Epoch-329, Time-0.3895, Train-MSE-0.0001, Train-L2-0.0081, Test-L2-1.5469
# Epoch-330, Time-0.4065, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5470
# Epoch-331, Time-0.3959, Train-MSE-0.0001, Train-L2-0.0079, Test-L2-1.5469
# Epoch-332, Time-0.3947, Train-MSE-0.0001, Train-L2-0.0079, Test-L2-1.5470
# Epoch-333, Time-0.4169, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5470
# Epoch-334, Time-0.3822, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5468
# Epoch-335, Time-0.4042, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5471
# Epoch-336, Time-0.4022, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5471
# Epoch-337, Time-0.4082, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5471
# Epoch-338, Time-0.4019, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5469
# Epoch-339, Time-0.4126, Train-MSE-0.0001, Train-L2-0.0079, Test-L2-1.5471
# Epoch-340, Time-0.4154, Train-MSE-0.0001, Train-L2-0.0079, Test-L2-1.5473
# Epoch-341, Time-0.4315, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5466
# Epoch-342, Time-0.4036, Train-MSE-0.0001, Train-L2-0.0080, Test-L2-1.5474
# Epoch-343, Time-0.3925, Train-MSE-0.0001, Train-L2-0.0079, Test-L2-1.5469
# Epoch-344, Time-0.4056, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5471
# Epoch-345, Time-0.4170, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5471
# Epoch-346, Time-0.4101, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5472
# Epoch-347, Time-0.4152, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5470
# Epoch-348, Time-0.4158, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5469
# Epoch-349, Time-0.4201, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5476
# Epoch-350, Time-0.4279, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5468
# Epoch-351, Time-0.3991, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5470
# Epoch-352, Time-0.3781, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5471
# Epoch-353, Time-0.4214, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5470
# Epoch-354, Time-0.4072, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5471
# Epoch-355, Time-0.4009, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5472
# Epoch-356, Time-0.4012, Train-MSE-0.0001, Train-L2-0.0078, Test-L2-1.5469
# Epoch-357, Time-0.3992, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5471
# Epoch-358, Time-0.4063, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5468
# Epoch-359, Time-0.4051, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5474
# Epoch-360, Time-0.4199, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5468
# Epoch-361, Time-0.4076, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5471
# Epoch-362, Time-0.4015, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-363, Time-0.4177, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5471
# Epoch-364, Time-0.3961, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5471
# Epoch-365, Time-0.3999, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5470
# Epoch-366, Time-0.3818, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5472
# Epoch-367, Time-0.4016, Train-MSE-0.0001, Train-L2-0.0077, Test-L2-1.5469
# Epoch-368, Time-0.4206, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5472
# Epoch-369, Time-0.3997, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5470
# Epoch-370, Time-0.4132, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5471
# Epoch-371, Time-0.4057, Train-MSE-0.0001, Train-L2-0.0076, Test-L2-1.5471
# Epoch-372, Time-0.4020, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-373, Time-0.4224, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-374, Time-0.4033, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-375, Time-0.4047, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-376, Time-0.4112, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5471
# Epoch-377, Time-0.4008, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5472
# Epoch-378, Time-0.3983, Train-MSE-0.0001, Train-L2-0.0075, Test-L2-1.5470
# Epoch-379, Time-0.4205, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5472
# Epoch-380, Time-0.4254, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-381, Time-0.4068, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-382, Time-0.4159, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5470
# Epoch-383, Time-0.3956, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5473
# Epoch-384, Time-0.4120, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5469
# Epoch-385, Time-0.4246, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5472
# Epoch-386, Time-0.3776, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5469
# Epoch-387, Time-0.4045, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-388, Time-0.3809, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-389, Time-0.4047, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-390, Time-0.4073, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-391, Time-0.3795, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5472
# Epoch-392, Time-0.4116, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5470
# Epoch-393, Time-0.4074, Train-MSE-0.0001, Train-L2-0.0074, Test-L2-1.5471
# Epoch-394, Time-0.4010, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-395, Time-0.4032, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-396, Time-0.3892, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-397, Time-0.3888, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5472
# Epoch-398, Time-0.3733, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5470
# Epoch-399, Time-0.3753, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5472
# Epoch-400, Time-0.3683, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-401, Time-0.3748, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-402, Time-0.3869, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-403, Time-0.3821, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-404, Time-0.3904, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-405, Time-0.3891, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-406, Time-0.3921, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-407, Time-0.3865, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-408, Time-0.4040, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5472
# Epoch-409, Time-0.4007, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-410, Time-0.3845, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-411, Time-0.4289, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5472
# Epoch-412, Time-0.4095, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-413, Time-0.3981, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-414, Time-0.3989, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-415, Time-0.4395, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-416, Time-0.4117, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-417, Time-0.4232, Train-MSE-0.0001, Train-L2-0.0073, Test-L2-1.5471
# Epoch-418, Time-0.4108, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-419, Time-0.4231, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-420, Time-0.4281, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-421, Time-0.3993, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-422, Time-0.4318, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-423, Time-0.4021, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-424, Time-0.4136, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-425, Time-0.4146, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5470
# Epoch-426, Time-0.4091, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-427, Time-0.4279, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-428, Time-0.4231, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-429, Time-0.4271, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-430, Time-0.4125, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-431, Time-0.3927, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-432, Time-0.3843, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-433, Time-0.3870, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-434, Time-0.4001, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-435, Time-0.3880, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-436, Time-0.4071, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-437, Time-0.3922, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-438, Time-0.4191, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-439, Time-0.3892, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-440, Time-0.4029, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-441, Time-0.4108, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-442, Time-0.3942, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-443, Time-0.3849, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5472
# Epoch-444, Time-0.4306, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-445, Time-0.4104, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-446, Time-0.4012, Train-MSE-0.0001, Train-L2-0.0072, Test-L2-1.5471
# Epoch-447, Time-0.4144, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-448, Time-0.3824, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-449, Time-0.3856, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-450, Time-0.4274, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-451, Time-0.4238, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-452, Time-0.4119, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-453, Time-0.4127, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-454, Time-0.3836, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-455, Time-0.3922, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-456, Time-0.4035, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-457, Time-0.3999, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-458, Time-0.3903, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-459, Time-0.3764, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-460, Time-0.3751, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-461, Time-0.3884, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-462, Time-0.3888, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-463, Time-0.3985, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-464, Time-0.3845, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-465, Time-0.3730, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-466, Time-0.3701, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-467, Time-0.3930, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-468, Time-0.3631, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-469, Time-0.4121, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-470, Time-0.3796, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-471, Time-0.3878, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-472, Time-0.3858, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-473, Time-0.3725, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-474, Time-0.3835, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-475, Time-0.3900, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-476, Time-0.4000, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-477, Time-0.4166, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-478, Time-0.3985, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-479, Time-0.4128, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-480, Time-0.3891, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-481, Time-0.3695, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-482, Time-0.3715, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-483, Time-0.3716, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-484, Time-0.3650, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-485, Time-0.3579, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-486, Time-0.3534, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-487, Time-0.3757, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5471
# Epoch-488, Time-0.3967, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-489, Time-0.3789, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-490, Time-0.3769, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-491, Time-0.4083, Train-MSE-0.0001, Train-L2-0.0071, Test-L2-1.5472
# Epoch-492, Time-0.3998, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-493, Time-0.3806, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-494, Time-0.4018, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-495, Time-0.3966, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5471
# Epoch-496, Time-0.3873, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-497, Time-0.3928, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-498, Time-0.3923, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472
# Epoch-499, Time-0.3864, Train-MSE-0.0001, Train-L2-0.0070, Test-L2-1.5472

# %%
# Save the HF-WNO model

torch.save(model_hf, 'model/HF_WNO_poisson1D_50')

# %%
# Prediction:
pred_hf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_hf(x[:,:,0:1]).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_hf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_hf = torch.cat(( pred_hf ))
# print('Mean mse_mf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
inp = x_test_mf
real_hf = y_test_mf + inp[:,:,1] 
output_hf = pred_hf

# %%
mse_pred_hf = F.mse_loss(output_hf, real_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_hf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_hf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
fig5, axs = plt.subplots(2, 2,figsize=(18,10), dpi=100)
plt.subplots_adjust(wspace=0.25)

n0 = 15
axs[0, 0].plot(x_coords,real_mf[n0], linestyle='-', color='tab:green', lw=2)
axs[0, 0].plot(x_coords,inp_mf[n0,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 0].plot(x_coords,output_hf[n0], linestyle='-.', color='tab:orange', lw=2)
axs[0, 0].plot(x_coords,output_mf[n0], linestyle='--', color='tab:red', lw=3)
axs[0, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 0].margins(0)
axs[0, 0].grid(True, alpha=0.3)

n1 = 28
axs[0, 1].plot(x_coords,real_mf[n1], linestyle='-', color='tab:green', lw=2)
axs[0, 1].plot(x_coords,inp_mf[n1,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 1].plot(x_coords,output_hf[n1], linestyle='-.', color='tab:orange', lw=2)
axs[0, 1].plot(x_coords,output_mf[n1], linestyle='--', color='tab:red', lw=3)
axs[0, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 1].margins(0)
axs[0, 1].grid(True, alpha=0.3)

n2 = 37
axs[1, 0].plot(x_coords,real_mf[n2], linestyle='-', color='tab:green', lw=2)
axs[1, 0].plot(x_coords,inp_mf[n2,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 0].plot(x_coords,output_hf[n2], linestyle='-.', color='tab:orange', lw=2)
axs[1, 0].plot(x_coords,output_mf[n2], linestyle='--', color='tab:red', lw=3)
axs[1, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 0].margins(0)
axs[1, 0].grid(True, alpha=0.3)

n3 = 38
axs[1, 1].plot(x_coords,real_mf[n3], linestyle='-', color='tab:green', lw=2)
axs[1, 1].plot(x_coords,inp_mf[n3,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 1].plot(x_coords,output_hf[n3], linestyle='-.', color='tab:orange', lw=2)
axs[1, 1].plot(x_coords,output_mf[n3], linestyle='--', color='tab:red', lw=3)
axs[1, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 1].margins(0)
axs[1, 1].grid(True, alpha=0.3)
