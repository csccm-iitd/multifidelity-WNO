# %% [markdown]
# # It trains MFWNO on the MF 1D Poisson's data (time-independent problem).
# ### HF data size = 10

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from utils import *
import matplotlib.pyplot as plt

from timeit import default_timer
from pytorch_wavelets import DWT1D, IDWT1D

# %%
torch.manual_seed(10)
np.random.seed(10)

# %% [markdown]
# # WNO

# %%
class WaveConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, level, size, wavelet):
        super(WaveConv1d, self).__init__()

        """
        1D Wavelet layer. It does Wavelet Transform, linear transform, and
        Inverse Wavelet Transform.    
        """

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.level = level
        self.wavelet = wavelet 
        self.dwt_ = DWT1D(wave=self.wavelet, J=self.level, mode='zero')
        dummy_data = torch.randn( 1,1,size ) 
        mode_data, _ = self.dwt_(dummy_data)
        self.modes1 = mode_data.shape[-1]
        
        # Parameter initilization
        self.scale = (1 / (in_channels*out_channels))
        self.weights1 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))
        self.weights2 = nn.Parameter(self.scale * torch.rand(in_channels, out_channels, self.modes1))

    # Convolution
    def mul1d(self, input, weights):
        # (batch, in_channel, x ), (in_channel, out_channel, x) -> (batch, out_channel, x)
        return torch.einsum("bix,iox->box", input, weights)

    def forward(self, x):
        """
        Input parameters: 
        -----------------
        x : tensor, shape-[Batch * Channel * x]
        Output parameters: 
        ------------------
        x : tensor, shape-[Batch * Channel * x]
        """
        # Compute single tree Discrete Wavelet coefficients using some wavelet     
        dwt = DWT1D(wave=self.wavelet, J=self.level, mode='zero').to(x.device)
        x_ft, x_coeff = dwt(x)
        
        # Multiply the final low pass wavelet coefficients
        out_ft = self.mul1d(x_ft, self.weights1)
        # Multiply the final high pass wavelet coefficients
        x_coeff[-1] = self.mul1d(x_coeff[-1].clone(), self.weights2)
        
        # Reconstruct the signal
        idwt = IDWT1D(wave=self.wavelet, mode='zero').to(x.device)
        x = idwt((out_ft, x_coeff)) 
        return x

# %%
class WNO1d(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv2 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv3 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)
        self.w2 = nn.Conv1d(self.width, self.width, 1)
        self.w3 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        if self.padding != 0:
            x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2
        x = F.gelu(x)
        
        x1 = self.conv2(x)
        x2 = self.w2(x)
        x = x1 + x2
        x = F.gelu(x)

        x1 = self.conv3(x)
        x2 = self.w3(x)
        x = x1 + x2

        if self.padding != 0:
            x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class WNO1d_linear(nn.Module):
    def __init__(self, width, level, size, wavelet, in_channel, grid_range):
        super(WNO1d_linear, self).__init__()

        """
        The WNO network. It contains 4 layers of the Wavelet integral layer.
        1. Lift the input using v(x) = self.fc0 .
        2. 4 layers of the integral operators v(+1) = g(K(.) + W)(v).
            W is defined by self.w_; K is defined by self.conv_.
        3. Project the output of last layer using self.fc1 and self.fc2.
        
        input: the solution of the initial condition and location (a(x), x)
        input shape: (batchsize, x=s, c=2)
        output: the solution of a later timestep
        output shape: (batchsize, x=s, c=1)
        """

        self.level = level
        self.width = width
        self.size = size
        self.wavelet = wavelet
        self.in_channel = in_channel
        self.grid_range = grid_range 
        self.padding = 2
        
        self.fc0 = nn.Linear(self.in_channel, self.width) # input channel is 2: (a(x), x)

        self.conv0 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.conv1 = WaveConv1d(self.width, self.width, self.level, self.size, self.wavelet)
        self.w0 = nn.Conv1d(self.width, self.width, 1)
        self.w1 = nn.Conv1d(self.width, self.width, 1)

        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)

    def forward(self, x):
        grid = self.get_grid(x.shape, x.device)
        x = torch.cat((x, grid), dim=-1)
        x = self.fc0(x)
        x = x.permute(0, 2, 1)
        x = F.pad(x, [0,self.padding]) # do padding, if required

        x1 = self.conv0(x)
        x2 = self.w0(x)
        x = x1 + x2

        x1 = self.conv1(x)
        x2 = self.w1(x)
        x = x1 + x2

        x = x[..., :-self.padding] # remove padding, when required
        x = x.permute(0, 2, 1)
        x = self.fc1(x)
        x = F.leaky_relu(x)
        x = self.fc2(x)
        return x

    def get_grid(self, shape, device):
        # The grid of the solution
        batchsize, size_x = shape[0], shape[1]
        gridx = torch.tensor(np.linspace(0, self.grid_range, size_x), dtype=torch.float)
        gridx = gridx.reshape(1, size_x, 1).repeat([batchsize, 1, 1])
        return gridx.to(device)

# %%
class MFWNO(nn.Module):
  def __init__(self, width, level, size, wavelet, in_channel, grid_range):
    super(MFWNO, self).__init__()
    
    self.width = width
    self.level = level 
    self.size = size
    self.wavelet = wavelet 
    self.in_channel = in_channel 
    self.grid_range = grid_range
    
    self.conv1 = WNO1d_linear(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.conv2 = WNO1d(self.width, self.level, self.size, self.wavelet, self.in_channel, self.grid_range)
    self.fc0 = nn.Linear(1,12)
    self.fc1 = nn.Linear(12,1)

  def forward(self, x):
    x = self.conv1(x) + self.conv2(x)
    x = self.fc0(x)
    x = F.gelu(x)
    x = self.fc1(x)
    return x

# %% [markdown]
# # Multifidelity

# %%
ntrain = 10
ntest = 40
n_total = ntrain + ntest
last_m = 400
s = 100

batch_size = 5
learning_rate = 0.001

w_decay = 1e-4
epochs = 500
step_size = 50   # weight-decay step size
gamma = 0.5      # weight-decay rate

wavelet = 'db6'  # wavelet basis function
level = 3        # lavel of wavelet decomposition
width = 64       # uplifting dimension
layers = 4       # no of wavelet layers

h = 100           # total grid size divided by the subsampling rate
grid_range = 1
in_channel = 3   # (a(x), x) for this case

# %%
PATH = 'data/possion_10pt_100pt__lscale_01.npz'
data = np.load(PATH)

x_data_h = data['f_stoch'][last_m-n_total:last_m]
y_data_l = data['y_low_100'][last_m-n_total:last_m]
y_data_h = data['yhi'][last_m-n_total:last_m]
x_coords = data['xhi'].reshape((s,))

# %%
 data['f_stoch'].shape

# %%
# read data

x_mf = np.stack((x_data_h, y_data_l), axis=-1)
y_mf = y_data_h - y_data_l

x_train_mf, y_train_mf = x_mf[:ntrain, ...], y_mf[:ntrain, ...]
x_test_mf, y_test_mf = x_mf[-ntest:, ...], y_mf[-ntest:, ...]

x_train_mf = torch.tensor( x_train_mf, dtype=torch.float )
y_train_mf = torch.tensor( y_train_mf, dtype=torch.float ) 
x_test_mf = torch.tensor( x_test_mf, dtype=torch.float ) 
y_test_mf = torch.tensor( y_test_mf, dtype=torch.float ) 

train_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_mf, y_train_mf),
                                              batch_size=batch_size, shuffle=True)
test_loader_mf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_mf, y_test_mf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_mf.shape, y_mf.shape, x_train_mf.shape, y_train_mf.shape, x_test_mf.shape, y_test_mf.shape)

# %%
# model
model_mf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=3, grid_range=grid_range).to(device)
print(count_params(model_mf))

optimizer = torch.optim.Adam(model_mf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_mf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_mf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_mf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_mf.eval()
    test_l2 = 0.0
    test_mse = 0
    with torch.no_grad():
        for x, y in test_loader_mf:
            x, y = x.cuda(), y.cuda()

            out = model_mf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
            tmse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
            test_mse += tmse.item()

    train_mse /= len(train_loader_mf)
    train_l2 /= ntrain
    test_l2 /= ntest
    test_mse /= len(test_loader_mf)
    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}, Test-MSE-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2, test_mse))
# Out:
# Epoch-92, Time-0.1462, Train-MSE-0.0000, Train-L2-0.0822, Test-L2-1.1496, Test-MSE-0.0021
# Epoch-93, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0713, Test-L2-1.1618, Test-MSE-0.0021
# Epoch-94, Time-0.1457, Train-MSE-0.0000, Train-L2-0.0697, Test-L2-1.1747, Test-MSE-0.0022
# Epoch-95, Time-0.1439, Train-MSE-0.0000, Train-L2-0.0675, Test-L2-1.1606, Test-MSE-0.0021
# Epoch-96, Time-0.1459, Train-MSE-0.0000, Train-L2-0.0702, Test-L2-1.1673, Test-MSE-0.0021
# Epoch-97, Time-0.1443, Train-MSE-0.0000, Train-L2-0.0749, Test-L2-1.1515, Test-MSE-0.0021
# Epoch-98, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0668, Test-L2-1.1704, Test-MSE-0.0022
# Epoch-99, Time-0.1451, Train-MSE-0.0000, Train-L2-0.0587, Test-L2-1.1606, Test-MSE-0.0021
# Epoch-100, Time-0.1447, Train-MSE-0.0000, Train-L2-0.0671, Test-L2-1.1577, Test-MSE-0.0021
# Epoch-101, Time-0.1449, Train-MSE-0.0000, Train-L2-0.0536, Test-L2-1.1542, Test-MSE-0.0021
# Epoch-102, Time-0.1461, Train-MSE-0.0000, Train-L2-0.0452, Test-L2-1.1385, Test-MSE-0.0021
# Epoch-103, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0670, Test-L2-1.1583, Test-MSE-0.0021
# Epoch-104, Time-0.1463, Train-MSE-0.0000, Train-L2-0.0558, Test-L2-1.1706, Test-MSE-0.0021
# Epoch-105, Time-0.1382, Train-MSE-0.0000, Train-L2-0.0429, Test-L2-1.1609, Test-MSE-0.0021
# Epoch-106, Time-0.1366, Train-MSE-0.0000, Train-L2-0.0499, Test-L2-1.1765, Test-MSE-0.0022
# Epoch-107, Time-0.1362, Train-MSE-0.0000, Train-L2-0.0537, Test-L2-1.1646, Test-MSE-0.0021
# Epoch-108, Time-0.1378, Train-MSE-0.0000, Train-L2-0.0430, Test-L2-1.1491, Test-MSE-0.0021
# Epoch-109, Time-0.1389, Train-MSE-0.0000, Train-L2-0.0443, Test-L2-1.1750, Test-MSE-0.0022
# Epoch-110, Time-0.1372, Train-MSE-0.0000, Train-L2-0.0580, Test-L2-1.1567, Test-MSE-0.0021
# Epoch-111, Time-0.1360, Train-MSE-0.0000, Train-L2-0.0480, Test-L2-1.1430, Test-MSE-0.0021
# Epoch-112, Time-0.1407, Train-MSE-0.0000, Train-L2-0.0415, Test-L2-1.1705, Test-MSE-0.0021
# Epoch-113, Time-0.1399, Train-MSE-0.0000, Train-L2-0.0510, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-114, Time-0.1439, Train-MSE-0.0000, Train-L2-0.0424, Test-L2-1.1639, Test-MSE-0.0021
# Epoch-115, Time-0.1464, Train-MSE-0.0000, Train-L2-0.0400, Test-L2-1.1517, Test-MSE-0.0021
# Epoch-116, Time-0.1455, Train-MSE-0.0000, Train-L2-0.0379, Test-L2-1.1457, Test-MSE-0.0021
# Epoch-117, Time-0.1466, Train-MSE-0.0000, Train-L2-0.0403, Test-L2-1.1672, Test-MSE-0.0021
# Epoch-118, Time-0.1468, Train-MSE-0.0000, Train-L2-0.0349, Test-L2-1.1505, Test-MSE-0.0021
# Epoch-119, Time-0.1446, Train-MSE-0.0000, Train-L2-0.0372, Test-L2-1.1583, Test-MSE-0.0021
# Epoch-120, Time-0.1460, Train-MSE-0.0000, Train-L2-0.0446, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-121, Time-0.1458, Train-MSE-0.0000, Train-L2-0.0311, Test-L2-1.1539, Test-MSE-0.0021
# Epoch-122, Time-0.1462, Train-MSE-0.0000, Train-L2-0.0321, Test-L2-1.1601, Test-MSE-0.0021
# Epoch-123, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0323, Test-L2-1.1578, Test-MSE-0.0021
# Epoch-124, Time-0.1456, Train-MSE-0.0000, Train-L2-0.0335, Test-L2-1.1673, Test-MSE-0.0021
# Epoch-125, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0344, Test-L2-1.1519, Test-MSE-0.0021
# Epoch-126, Time-0.1461, Train-MSE-0.0000, Train-L2-0.0422, Test-L2-1.1638, Test-MSE-0.0021
# Epoch-127, Time-0.1463, Train-MSE-0.0000, Train-L2-0.0408, Test-L2-1.1629, Test-MSE-0.0021
# Epoch-128, Time-0.1449, Train-MSE-0.0000, Train-L2-0.0332, Test-L2-1.1403, Test-MSE-0.0021
# Epoch-129, Time-0.1454, Train-MSE-0.0000, Train-L2-0.0443, Test-L2-1.1706, Test-MSE-0.0021
# Epoch-130, Time-0.1464, Train-MSE-0.0000, Train-L2-0.0567, Test-L2-1.1676, Test-MSE-0.0021
# Epoch-131, Time-0.1448, Train-MSE-0.0000, Train-L2-0.0410, Test-L2-1.1334, Test-MSE-0.0021
# Epoch-132, Time-0.1461, Train-MSE-0.0000, Train-L2-0.0562, Test-L2-1.1497, Test-MSE-0.0021
# Epoch-133, Time-0.1452, Train-MSE-0.0000, Train-L2-0.0611, Test-L2-1.1609, Test-MSE-0.0021
# Epoch-134, Time-0.1461, Train-MSE-0.0000, Train-L2-0.0400, Test-L2-1.1533, Test-MSE-0.0021
# Epoch-135, Time-0.1443, Train-MSE-0.0000, Train-L2-0.0465, Test-L2-1.1654, Test-MSE-0.0021
# Epoch-136, Time-0.1455, Train-MSE-0.0000, Train-L2-0.0448, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-137, Time-0.1461, Train-MSE-0.0000, Train-L2-0.0321, Test-L2-1.1386, Test-MSE-0.0021
# Epoch-138, Time-0.1459, Train-MSE-0.0000, Train-L2-0.0374, Test-L2-1.1596, Test-MSE-0.0021
# Epoch-139, Time-0.1459, Train-MSE-0.0000, Train-L2-0.0392, Test-L2-1.1458, Test-MSE-0.0021
# Epoch-140, Time-0.1451, Train-MSE-0.0000, Train-L2-0.0323, Test-L2-1.1570, Test-MSE-0.0021
# Epoch-141, Time-0.1492, Train-MSE-0.0000, Train-L2-0.0336, Test-L2-1.1477, Test-MSE-0.0021
# Epoch-142, Time-0.1496, Train-MSE-0.0000, Train-L2-0.0257, Test-L2-1.1636, Test-MSE-0.0021
# Epoch-143, Time-0.1520, Train-MSE-0.0000, Train-L2-0.0266, Test-L2-1.1551, Test-MSE-0.0021
# Epoch-144, Time-0.1543, Train-MSE-0.0000, Train-L2-0.0229, Test-L2-1.1576, Test-MSE-0.0021
# Epoch-145, Time-0.1577, Train-MSE-0.0000, Train-L2-0.0216, Test-L2-1.1577, Test-MSE-0.0021
# Epoch-146, Time-0.1585, Train-MSE-0.0000, Train-L2-0.0236, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-147, Time-0.1478, Train-MSE-0.0000, Train-L2-0.0214, Test-L2-1.1432, Test-MSE-0.0021
# Epoch-148, Time-0.1550, Train-MSE-0.0000, Train-L2-0.0263, Test-L2-1.1620, Test-MSE-0.0021
# Epoch-149, Time-0.1535, Train-MSE-0.0000, Train-L2-0.0334, Test-L2-1.1477, Test-MSE-0.0021
# Epoch-150, Time-0.1551, Train-MSE-0.0000, Train-L2-0.0247, Test-L2-1.1490, Test-MSE-0.0021
# Epoch-151, Time-0.1544, Train-MSE-0.0000, Train-L2-0.0208, Test-L2-1.1547, Test-MSE-0.0021
# Epoch-152, Time-0.1580, Train-MSE-0.0000, Train-L2-0.0187, Test-L2-1.1546, Test-MSE-0.0021
# Epoch-153, Time-0.1649, Train-MSE-0.0000, Train-L2-0.0181, Test-L2-1.1590, Test-MSE-0.0021
# Epoch-154, Time-0.1654, Train-MSE-0.0000, Train-L2-0.0183, Test-L2-1.1534, Test-MSE-0.0021
# Epoch-155, Time-0.1571, Train-MSE-0.0000, Train-L2-0.0175, Test-L2-1.1574, Test-MSE-0.0021
# Epoch-156, Time-0.1628, Train-MSE-0.0000, Train-L2-0.0170, Test-L2-1.1525, Test-MSE-0.0021
# Epoch-157, Time-0.1584, Train-MSE-0.0000, Train-L2-0.0180, Test-L2-1.1517, Test-MSE-0.0021
# Epoch-158, Time-0.1602, Train-MSE-0.0000, Train-L2-0.0168, Test-L2-1.1567, Test-MSE-0.0021
# Epoch-159, Time-0.1592, Train-MSE-0.0000, Train-L2-0.0153, Test-L2-1.1574, Test-MSE-0.0021
# Epoch-160, Time-0.1656, Train-MSE-0.0000, Train-L2-0.0159, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-161, Time-0.1639, Train-MSE-0.0000, Train-L2-0.0153, Test-L2-1.1575, Test-MSE-0.0021
# Epoch-162, Time-0.1657, Train-MSE-0.0000, Train-L2-0.0156, Test-L2-1.1592, Test-MSE-0.0021
# Epoch-163, Time-0.1708, Train-MSE-0.0000, Train-L2-0.0144, Test-L2-1.1520, Test-MSE-0.0021
# Epoch-164, Time-0.1670, Train-MSE-0.0000, Train-L2-0.0150, Test-L2-1.1587, Test-MSE-0.0021
# Epoch-165, Time-0.1649, Train-MSE-0.0000, Train-L2-0.0156, Test-L2-1.1553, Test-MSE-0.0021
# Epoch-166, Time-0.1640, Train-MSE-0.0000, Train-L2-0.0169, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-167, Time-0.1888, Train-MSE-0.0000, Train-L2-0.0156, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-168, Time-0.1673, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-1.1595, Test-MSE-0.0021
# Epoch-169, Time-0.1577, Train-MSE-0.0000, Train-L2-0.0140, Test-L2-1.1524, Test-MSE-0.0021
# Epoch-170, Time-0.1695, Train-MSE-0.0000, Train-L2-0.0142, Test-L2-1.1570, Test-MSE-0.0021
# Epoch-171, Time-0.1681, Train-MSE-0.0000, Train-L2-0.0154, Test-L2-1.1540, Test-MSE-0.0021
# Epoch-172, Time-0.1676, Train-MSE-0.0000, Train-L2-0.0153, Test-L2-1.1568, Test-MSE-0.0021
# Epoch-173, Time-0.1599, Train-MSE-0.0000, Train-L2-0.0148, Test-L2-1.1572, Test-MSE-0.0021
# Epoch-174, Time-0.1578, Train-MSE-0.0000, Train-L2-0.0164, Test-L2-1.1584, Test-MSE-0.0021
# Epoch-175, Time-0.1593, Train-MSE-0.0000, Train-L2-0.0153, Test-L2-1.1551, Test-MSE-0.0021
# Epoch-176, Time-0.1600, Train-MSE-0.0000, Train-L2-0.0139, Test-L2-1.1565, Test-MSE-0.0021
# Epoch-177, Time-0.1569, Train-MSE-0.0000, Train-L2-0.0130, Test-L2-1.1564, Test-MSE-0.0021
# Epoch-178, Time-0.1387, Train-MSE-0.0000, Train-L2-0.0131, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-179, Time-0.1409, Train-MSE-0.0000, Train-L2-0.0137, Test-L2-1.1572, Test-MSE-0.0021
# Epoch-180, Time-0.1652, Train-MSE-0.0000, Train-L2-0.0128, Test-L2-1.1576, Test-MSE-0.0021
# Epoch-181, Time-0.1665, Train-MSE-0.0000, Train-L2-0.0141, Test-L2-1.1518, Test-MSE-0.0021
# Epoch-182, Time-0.1583, Train-MSE-0.0000, Train-L2-0.0136, Test-L2-1.1607, Test-MSE-0.0021
# Epoch-183, Time-0.1589, Train-MSE-0.0000, Train-L2-0.0162, Test-L2-1.1512, Test-MSE-0.0021
# Epoch-184, Time-0.1661, Train-MSE-0.0000, Train-L2-0.0166, Test-L2-1.1528, Test-MSE-0.0021
# Epoch-185, Time-0.1583, Train-MSE-0.0000, Train-L2-0.0146, Test-L2-1.1549, Test-MSE-0.0021
# Epoch-186, Time-0.1362, Train-MSE-0.0000, Train-L2-0.0146, Test-L2-1.1568, Test-MSE-0.0021
# Epoch-187, Time-0.1440, Train-MSE-0.0000, Train-L2-0.0139, Test-L2-1.1495, Test-MSE-0.0021
# Epoch-188, Time-0.1292, Train-MSE-0.0000, Train-L2-0.0207, Test-L2-1.1580, Test-MSE-0.0021
# Epoch-189, Time-0.1281, Train-MSE-0.0000, Train-L2-0.0162, Test-L2-1.1609, Test-MSE-0.0021
# Epoch-190, Time-0.1465, Train-MSE-0.0000, Train-L2-0.0161, Test-L2-1.1512, Test-MSE-0.0021
# Epoch-191, Time-0.1400, Train-MSE-0.0000, Train-L2-0.0175, Test-L2-1.1628, Test-MSE-0.0021
# Epoch-192, Time-0.1415, Train-MSE-0.0000, Train-L2-0.0185, Test-L2-1.1497, Test-MSE-0.0021
# Epoch-193, Time-0.1383, Train-MSE-0.0000, Train-L2-0.0231, Test-L2-1.1530, Test-MSE-0.0021
# Epoch-194, Time-0.1357, Train-MSE-0.0000, Train-L2-0.0155, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-195, Time-0.1220, Train-MSE-0.0000, Train-L2-0.0135, Test-L2-1.1546, Test-MSE-0.0021
# Epoch-196, Time-0.1297, Train-MSE-0.0000, Train-L2-0.0138, Test-L2-1.1529, Test-MSE-0.0021
# Epoch-197, Time-0.1353, Train-MSE-0.0000, Train-L2-0.0142, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-198, Time-0.1401, Train-MSE-0.0000, Train-L2-0.0131, Test-L2-1.1590, Test-MSE-0.0021
# Epoch-199, Time-0.1226, Train-MSE-0.0000, Train-L2-0.0149, Test-L2-1.1505, Test-MSE-0.0021
# Epoch-200, Time-0.1240, Train-MSE-0.0000, Train-L2-0.0173, Test-L2-1.1574, Test-MSE-0.0021
# Epoch-201, Time-0.1400, Train-MSE-0.0000, Train-L2-0.0134, Test-L2-1.1610, Test-MSE-0.0021
# Epoch-202, Time-0.1350, Train-MSE-0.0000, Train-L2-0.0119, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-203, Time-0.1254, Train-MSE-0.0000, Train-L2-0.0119, Test-L2-1.1550, Test-MSE-0.0021
# Epoch-204, Time-0.1278, Train-MSE-0.0000, Train-L2-0.0129, Test-L2-1.1537, Test-MSE-0.0021
# Epoch-205, Time-0.1294, Train-MSE-0.0000, Train-L2-0.0107, Test-L2-1.1556, Test-MSE-0.0021
# Epoch-206, Time-0.1255, Train-MSE-0.0000, Train-L2-0.0110, Test-L2-1.1565, Test-MSE-0.0021
# Epoch-207, Time-0.1298, Train-MSE-0.0000, Train-L2-0.0108, Test-L2-1.1544, Test-MSE-0.0021
# Epoch-208, Time-0.1316, Train-MSE-0.0000, Train-L2-0.0102, Test-L2-1.1570, Test-MSE-0.0021
# Epoch-209, Time-0.1259, Train-MSE-0.0000, Train-L2-0.0109, Test-L2-1.1580, Test-MSE-0.0021
# Epoch-210, Time-0.1288, Train-MSE-0.0000, Train-L2-0.0108, Test-L2-1.1532, Test-MSE-0.0021
# Epoch-211, Time-0.1326, Train-MSE-0.0000, Train-L2-0.0124, Test-L2-1.1536, Test-MSE-0.0021
# Epoch-212, Time-0.1317, Train-MSE-0.0000, Train-L2-0.0103, Test-L2-1.1567, Test-MSE-0.0021
# Epoch-213, Time-0.1230, Train-MSE-0.0000, Train-L2-0.0117, Test-L2-1.1566, Test-MSE-0.0021
# Epoch-214, Time-0.1239, Train-MSE-0.0000, Train-L2-0.0105, Test-L2-1.1523, Test-MSE-0.0021
# Epoch-215, Time-0.1263, Train-MSE-0.0000, Train-L2-0.0110, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-216, Time-0.1326, Train-MSE-0.0000, Train-L2-0.0094, Test-L2-1.1581, Test-MSE-0.0021
# Epoch-217, Time-0.1295, Train-MSE-0.0000, Train-L2-0.0107, Test-L2-1.1550, Test-MSE-0.0021
# Epoch-218, Time-0.1206, Train-MSE-0.0000, Train-L2-0.0095, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-219, Time-0.1255, Train-MSE-0.0000, Train-L2-0.0097, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-220, Time-0.1321, Train-MSE-0.0000, Train-L2-0.0095, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-221, Time-0.1310, Train-MSE-0.0000, Train-L2-0.0094, Test-L2-1.1549, Test-MSE-0.0021
# Epoch-222, Time-0.1207, Train-MSE-0.0000, Train-L2-0.0095, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-223, Time-0.1259, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-224, Time-0.1305, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-225, Time-0.1359, Train-MSE-0.0000, Train-L2-0.0093, Test-L2-1.1551, Test-MSE-0.0021
# Epoch-226, Time-0.1363, Train-MSE-0.0000, Train-L2-0.0092, Test-L2-1.1568, Test-MSE-0.0021
# Epoch-227, Time-0.1265, Train-MSE-0.0000, Train-L2-0.0095, Test-L2-1.1570, Test-MSE-0.0021
# Epoch-228, Time-0.1340, Train-MSE-0.0000, Train-L2-0.0093, Test-L2-1.1549, Test-MSE-0.0021
# Epoch-229, Time-0.1313, Train-MSE-0.0000, Train-L2-0.0095, Test-L2-1.1553, Test-MSE-0.0021
# Epoch-230, Time-0.1358, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-231, Time-0.1348, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-232, Time-0.1271, Train-MSE-0.0000, Train-L2-0.0090, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-233, Time-0.1315, Train-MSE-0.0000, Train-L2-0.0094, Test-L2-1.1572, Test-MSE-0.0021
# Epoch-234, Time-0.1300, Train-MSE-0.0000, Train-L2-0.0089, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-235, Time-0.1385, Train-MSE-0.0000, Train-L2-0.0089, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-236, Time-0.1383, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-237, Time-0.1328, Train-MSE-0.0000, Train-L2-0.0091, Test-L2-1.1572, Test-MSE-0.0021
# Epoch-238, Time-0.1336, Train-MSE-0.0000, Train-L2-0.0093, Test-L2-1.1548, Test-MSE-0.0021
# Epoch-239, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0099, Test-L2-1.1588, Test-MSE-0.0021
# Epoch-240, Time-0.1603, Train-MSE-0.0000, Train-L2-0.0103, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-241, Time-0.1599, Train-MSE-0.0000, Train-L2-0.0093, Test-L2-1.1553, Test-MSE-0.0021
# Epoch-242, Time-0.1644, Train-MSE-0.0000, Train-L2-0.0090, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-243, Time-0.1592, Train-MSE-0.0000, Train-L2-0.0087, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-244, Time-0.1637, Train-MSE-0.0000, Train-L2-0.0092, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-245, Time-0.1635, Train-MSE-0.0000, Train-L2-0.0083, Test-L2-1.1565, Test-MSE-0.0021
# Epoch-246, Time-0.1600, Train-MSE-0.0000, Train-L2-0.0088, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-247, Time-0.1518, Train-MSE-0.0000, Train-L2-0.0084, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-248, Time-0.1638, Train-MSE-0.0000, Train-L2-0.0086, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-249, Time-0.1632, Train-MSE-0.0000, Train-L2-0.0089, Test-L2-1.1571, Test-MSE-0.0021
# Epoch-250, Time-0.1542, Train-MSE-0.0000, Train-L2-0.0085, Test-L2-1.1554, Test-MSE-0.0021
# Epoch-251, Time-0.1596, Train-MSE-0.0000, Train-L2-0.0084, Test-L2-1.1551, Test-MSE-0.0021
# Epoch-252, Time-0.1611, Train-MSE-0.0000, Train-L2-0.0084, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-253, Time-0.1592, Train-MSE-0.0000, Train-L2-0.0081, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-254, Time-0.1568, Train-MSE-0.0000, Train-L2-0.0082, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-255, Time-0.1656, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1555, Test-MSE-0.0021
# Epoch-256, Time-0.1590, Train-MSE-0.0000, Train-L2-0.0080, Test-L2-1.1556, Test-MSE-0.0021
# Epoch-257, Time-0.1593, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-258, Time-0.1643, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-259, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1556, Test-MSE-0.0021
# Epoch-260, Time-0.1630, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-261, Time-0.1529, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1568, Test-MSE-0.0021
# Epoch-262, Time-0.1606, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1553, Test-MSE-0.0021
# Epoch-263, Time-0.1626, Train-MSE-0.0000, Train-L2-0.0079, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-264, Time-0.1576, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1568, Test-MSE-0.0021
# Epoch-265, Time-0.1512, Train-MSE-0.0000, Train-L2-0.0079, Test-L2-1.1553, Test-MSE-0.0021
# Epoch-266, Time-0.1553, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-267, Time-0.1542, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1550, Test-MSE-0.0021
# Epoch-268, Time-0.1594, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-269, Time-0.1536, Train-MSE-0.0000, Train-L2-0.0076, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-270, Time-0.1627, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1547, Test-MSE-0.0021
# Epoch-271, Time-0.1590, Train-MSE-0.0000, Train-L2-0.0076, Test-L2-1.1564, Test-MSE-0.0021
# Epoch-272, Time-0.1603, Train-MSE-0.0000, Train-L2-0.0079, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-273, Time-0.1568, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1556, Test-MSE-0.0021
# Epoch-274, Time-0.1627, Train-MSE-0.0000, Train-L2-0.0075, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-275, Time-0.1591, Train-MSE-0.0000, Train-L2-0.0076, Test-L2-1.1550, Test-MSE-0.0021
# Epoch-276, Time-0.1514, Train-MSE-0.0000, Train-L2-0.0078, Test-L2-1.1570, Test-MSE-0.0021
# Epoch-277, Time-0.1505, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-278, Time-0.1609, Train-MSE-0.0000, Train-L2-0.0075, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-279, Time-0.1508, Train-MSE-0.0000, Train-L2-0.0075, Test-L2-1.1565, Test-MSE-0.0021
# Epoch-280, Time-0.1684, Train-MSE-0.0000, Train-L2-0.0075, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-281, Time-0.1495, Train-MSE-0.0000, Train-L2-0.0077, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-282, Time-0.1621, Train-MSE-0.0000, Train-L2-0.0075, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-283, Time-0.1606, Train-MSE-0.0000, Train-L2-0.0073, Test-L2-1.1552, Test-MSE-0.0021
# Epoch-284, Time-0.1556, Train-MSE-0.0000, Train-L2-0.0076, Test-L2-1.1574, Test-MSE-0.0021
# Epoch-285, Time-0.1490, Train-MSE-0.0000, Train-L2-0.0076, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-286, Time-0.1509, Train-MSE-0.0000, Train-L2-0.0074, Test-L2-1.1557, Test-MSE-0.0021
# Epoch-287, Time-0.1626, Train-MSE-0.0000, Train-L2-0.0072, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-288, Time-0.1541, Train-MSE-0.0000, Train-L2-0.0072, Test-L2-1.1558, Test-MSE-0.0021
# Epoch-289, Time-0.1613, Train-MSE-0.0000, Train-L2-0.0072, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-290, Time-0.1572, Train-MSE-0.0000, Train-L2-0.0072, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-291, Time-0.1556, Train-MSE-0.0000, Train-L2-0.0072, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-292, Time-0.1582, Train-MSE-0.0000, Train-L2-0.0071, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-293, Time-0.1586, Train-MSE-0.0000, Train-L2-0.0071, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-294, Time-0.1660, Train-MSE-0.0000, Train-L2-0.0071, Test-L2-1.1563, Test-MSE-0.0021
# Epoch-295, Time-0.1594, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-296, Time-0.1620, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-297, Time-0.1559, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-298, Time-0.1602, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-299, Time-0.1588, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-300, Time-0.1655, Train-MSE-0.0000, Train-L2-0.0070, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-301, Time-0.1610, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-302, Time-0.1605, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-303, Time-0.1664, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-304, Time-0.1583, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-305, Time-0.1593, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-306, Time-0.1646, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-307, Time-0.1597, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-308, Time-0.1684, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-309, Time-0.1665, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-310, Time-0.1684, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-311, Time-0.1607, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-312, Time-0.1675, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-313, Time-0.1598, Train-MSE-0.0000, Train-L2-0.0069, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-314, Time-0.1665, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-315, Time-0.1609, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-316, Time-0.1661, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-317, Time-0.1657, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-318, Time-0.1637, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1559, Test-MSE-0.0021
# Epoch-319, Time-0.1674, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-320, Time-0.1638, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-321, Time-0.1635, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-322, Time-0.1628, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-323, Time-0.1613, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-324, Time-0.1659, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-325, Time-0.1618, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-326, Time-0.1650, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-327, Time-0.1605, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-328, Time-0.1617, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-329, Time-0.1611, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-330, Time-0.1642, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-331, Time-0.1583, Train-MSE-0.0000, Train-L2-0.0068, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-332, Time-0.1616, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-333, Time-0.1580, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-334, Time-0.1691, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-335, Time-0.1607, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-336, Time-0.1690, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-337, Time-0.1684, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-338, Time-0.1630, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-339, Time-0.1686, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-340, Time-0.1680, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-341, Time-0.1732, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-342, Time-0.1701, Train-MSE-0.0000, Train-L2-0.0067, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-343, Time-0.1673, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-344, Time-0.1630, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-345, Time-0.1621, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-346, Time-0.1680, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-347, Time-0.1657, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-348, Time-0.1637, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-349, Time-0.1665, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-350, Time-0.1624, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-351, Time-0.1604, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-352, Time-0.1638, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-353, Time-0.1672, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-354, Time-0.1677, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-355, Time-0.1550, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-356, Time-0.1573, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-357, Time-0.1593, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-358, Time-0.1599, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-359, Time-0.1615, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-360, Time-0.1613, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-361, Time-0.1648, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-362, Time-0.1658, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-363, Time-0.1611, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-364, Time-0.1563, Train-MSE-0.0000, Train-L2-0.0066, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-365, Time-0.1561, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-366, Time-0.1567, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-367, Time-0.1589, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-368, Time-0.1639, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-369, Time-0.1552, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-370, Time-0.1563, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-371, Time-0.1664, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-372, Time-0.1652, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-373, Time-0.1634, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-374, Time-0.1574, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-375, Time-0.1587, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-376, Time-0.1560, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-377, Time-0.1597, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-378, Time-0.1539, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-379, Time-0.1533, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-380, Time-0.1488, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-381, Time-0.1596, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-382, Time-0.1562, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-383, Time-0.1487, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-384, Time-0.1628, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-385, Time-0.1508, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-386, Time-0.1605, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-387, Time-0.1550, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-388, Time-0.1589, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-389, Time-0.1573, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-390, Time-0.1566, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1562, Test-MSE-0.0021
# Epoch-391, Time-0.1513, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-392, Time-0.1644, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-393, Time-0.1599, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-394, Time-0.1555, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-395, Time-0.1632, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-396, Time-0.1529, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-397, Time-0.1502, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-398, Time-0.1574, Train-MSE-0.0000, Train-L2-0.0065, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-399, Time-0.1599, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-400, Time-0.1672, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-401, Time-0.1584, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-402, Time-0.1566, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-403, Time-0.1552, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-404, Time-0.1585, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-405, Time-0.1619, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-406, Time-0.1650, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-407, Time-0.1598, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-408, Time-0.1678, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-409, Time-0.1626, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-410, Time-0.1527, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-411, Time-0.1594, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-412, Time-0.1579, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-413, Time-0.1579, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-414, Time-0.1596, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-415, Time-0.1492, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-416, Time-0.1607, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-417, Time-0.1533, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-418, Time-0.1498, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-419, Time-0.1577, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-420, Time-0.1595, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-421, Time-0.1481, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-422, Time-0.1623, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-423, Time-0.1527, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-424, Time-0.1596, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-425, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-426, Time-0.1802, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-427, Time-0.1628, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-428, Time-0.1665, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-429, Time-0.1528, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-430, Time-0.1579, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-431, Time-0.1470, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-432, Time-0.1480, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-433, Time-0.1471, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-434, Time-0.1542, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-435, Time-0.1457, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-436, Time-0.1516, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-437, Time-0.1574, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-438, Time-0.1510, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-439, Time-0.1483, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-440, Time-0.1531, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-441, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-442, Time-0.1582, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-443, Time-0.1484, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-444, Time-0.1504, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-445, Time-0.1633, Train-MSE-0.0000, Train-L2-0.0064, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-446, Time-0.1523, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-447, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-448, Time-0.1562, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-449, Time-0.1600, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-450, Time-0.1543, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-451, Time-0.1606, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-452, Time-0.1547, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-453, Time-0.1564, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-454, Time-0.1503, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-455, Time-0.1656, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-456, Time-0.1605, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-457, Time-0.1633, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-458, Time-0.1543, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-459, Time-0.1586, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-460, Time-0.1607, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-461, Time-0.1542, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-462, Time-0.1649, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-463, Time-0.1594, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-464, Time-0.1640, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-465, Time-0.1548, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-466, Time-0.1620, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-467, Time-0.1496, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-468, Time-0.1643, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-469, Time-0.1557, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-470, Time-0.1615, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-471, Time-0.1540, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-472, Time-0.1572, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-473, Time-0.1504, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-474, Time-0.1570, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-475, Time-0.1597, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-476, Time-0.1555, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-477, Time-0.1605, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-478, Time-0.1511, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-479, Time-0.1608, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-480, Time-0.1567, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-481, Time-0.1524, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-482, Time-0.1591, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-483, Time-0.1617, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-484, Time-0.1546, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-485, Time-0.1612, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-486, Time-0.1337, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-487, Time-0.1286, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-488, Time-0.1315, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-489, Time-0.1234, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-490, Time-0.1274, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-491, Time-0.1469, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-492, Time-0.1233, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-493, Time-0.1171, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-494, Time-0.1170, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-495, Time-0.1227, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-496, Time-0.1211, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-497, Time-0.1078, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1561, Test-MSE-0.0021
# Epoch-498, Time-0.1073, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021
# Epoch-499, Time-0.1089, Train-MSE-0.0000, Train-L2-0.0063, Test-L2-1.1560, Test-MSE-0.0021

# %%
# Save the MF-WNO model

torch.save(model_mf, 'model/MF_WNO_poisson1D_10')

# %%
# Prediction:
pred_mf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_mf(x).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_mf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_mf = torch.cat(( pred_mf ))
print('Mean mse_mf-{}'.format(F.mse_loss(y_test_mf, pred_mf).item()))

# %%
pred_mf.shape

# %%
inp_mf  = x_test_mf 
real_mf = y_test_mf + inp_mf[:,:,1]
output_mf  =  pred_mf + inp_mf[:,:,1]

# %%
mse_pred = F.mse_loss(output_mf, real_mf).item()

print('MSE-Predicted solution-{:0.6f}'.format(mse_pred))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_mf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_mf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
colormap = plt.cm.jet  
colors2 = [colormap(i) for i in np.linspace(0, 1, 5)]

fig1 = plt.figure(figsize = (10, 4), dpi=300)
fig1.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, inp_mf[i, :, 0], color=colors2[index], label='Forcing-{}'.format(i))
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %% [markdown]
# # High Fidelity

# %%
# read data
x_hf = torch.tensor( x_data_h, dtype=torch.float ).unsqueeze(-1)
y_hf = torch.tensor( y_data_h, dtype=torch.float ) 

x_train_hf, y_train_hf = x_hf[:ntrain, ...], y_hf[:ntrain, ...]
x_test_hf, y_test_hf = x_hf[-ntest:, ...], y_hf[-ntest:, ...]

train_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_train_hf, y_train_hf),
                                              batch_size=batch_size, shuffle=True)
test_loader_hf = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(x_test_hf, x_test_hf),
                                             batch_size=batch_size, shuffle=False)

# %%
print(x_train_hf.shape, y_train_hf.shape, x_test_hf.shape, y_test_hf.shape)

# %%
# model
model_hf = WNO1d(width=width, level=4, size=h, wavelet=wavelet,
              in_channel=2, grid_range=grid_range).to(device)
print(count_params(model_hf))

optimizer = torch.optim.Adam(model_hf.parameters(), lr=learning_rate, weight_decay=w_decay)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %%
myloss = LpLoss(size_average=False)
for ep in range(epochs):
    model_hf.train()
    t1 = default_timer()
    train_mse = 0
    train_l2 = 0
    for x, y in train_loader_hf:
        x, y = x.cuda(), y.cuda()

        optimizer.zero_grad()
        out = model_hf(x)

        mse = F.mse_loss(out.view(batch_size, -1), y.view(batch_size, -1), reduction='mean')
        l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1))
        l2.backward() # use the l2 relative loss

        optimizer.step()
        train_mse += mse.item()
        train_l2 += l2.item()

    scheduler.step()
    model_hf.eval()
    test_l2 = 0.0
    with torch.no_grad():
        for x, y in test_loader_hf:
            x, y = x.cuda(), y.cuda()

            out = model_hf(x)
            test_l2 += myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()

    train_mse /= len(train_loader_hf)
    train_l2 /= ntrain
    test_l2 /= ntest

    t2 = default_timer()
    print('Epoch-{}, Time-{:0.4f}, Train-MSE-{:0.4f}, Train-L2-{:0.4f}, Test-L2-{:0.4f}'
          .format(ep, t2-t1, train_mse, train_l2, test_l2))
# Out:
# Epoch-114, Time-0.1440, Train-MSE-0.0218, Train-L2-0.0998, Test-L2-1.4040
# Epoch-115, Time-0.1462, Train-MSE-0.0224, Train-L2-0.0965, Test-L2-1.4042
# Epoch-116, Time-0.1437, Train-MSE-0.0217, Train-L2-0.0969, Test-L2-1.4151
# Epoch-117, Time-0.1431, Train-MSE-0.0209, Train-L2-0.0953, Test-L2-1.4136
# Epoch-118, Time-0.1580, Train-MSE-0.0209, Train-L2-0.0947, Test-L2-1.4084
# Epoch-119, Time-0.1553, Train-MSE-0.0204, Train-L2-0.0947, Test-L2-1.4126
# Epoch-120, Time-0.1410, Train-MSE-0.0194, Train-L2-0.0905, Test-L2-1.4157
# Epoch-121, Time-0.1486, Train-MSE-0.0198, Train-L2-0.0998, Test-L2-1.4113
# Epoch-122, Time-0.1546, Train-MSE-0.0193, Train-L2-0.0927, Test-L2-1.4113
# Epoch-123, Time-0.1505, Train-MSE-0.0184, Train-L2-0.0969, Test-L2-1.4150
# Epoch-124, Time-0.1542, Train-MSE-0.0184, Train-L2-0.0904, Test-L2-1.4174
# Epoch-125, Time-0.1474, Train-MSE-0.0179, Train-L2-0.0867, Test-L2-1.4179
# Epoch-126, Time-0.1569, Train-MSE-0.0173, Train-L2-0.0916, Test-L2-1.4138
# Epoch-127, Time-0.1574, Train-MSE-0.0173, Train-L2-0.0872, Test-L2-1.4197
# Epoch-128, Time-0.1572, Train-MSE-0.0168, Train-L2-0.0825, Test-L2-1.4183
# Epoch-129, Time-0.1528, Train-MSE-0.0168, Train-L2-0.0845, Test-L2-1.4161
# Epoch-130, Time-0.1601, Train-MSE-0.0160, Train-L2-0.0820, Test-L2-1.4204
# Epoch-131, Time-0.1587, Train-MSE-0.0155, Train-L2-0.0911, Test-L2-1.4231
# Epoch-132, Time-0.1564, Train-MSE-0.0155, Train-L2-0.0811, Test-L2-1.4127
# Epoch-133, Time-0.1675, Train-MSE-0.0163, Train-L2-0.0934, Test-L2-1.4145
# Epoch-134, Time-0.1680, Train-MSE-0.0152, Train-L2-0.0911, Test-L2-1.4273
# Epoch-135, Time-0.1755, Train-MSE-0.0147, Train-L2-0.0858, Test-L2-1.4241
# Epoch-136, Time-0.1575, Train-MSE-0.0149, Train-L2-0.0873, Test-L2-1.4170
# Epoch-137, Time-0.1568, Train-MSE-0.0142, Train-L2-0.0838, Test-L2-1.4251
# Epoch-138, Time-0.1557, Train-MSE-0.0140, Train-L2-0.0947, Test-L2-1.4291
# Epoch-139, Time-0.1589, Train-MSE-0.0135, Train-L2-0.0829, Test-L2-1.4227
# Epoch-140, Time-0.1569, Train-MSE-0.0134, Train-L2-0.0832, Test-L2-1.4250
# Epoch-141, Time-0.1626, Train-MSE-0.0130, Train-L2-0.0754, Test-L2-1.4234
# Epoch-142, Time-0.1669, Train-MSE-0.0132, Train-L2-0.0845, Test-L2-1.4258
# Epoch-143, Time-0.1609, Train-MSE-0.0126, Train-L2-0.0762, Test-L2-1.4259
# Epoch-144, Time-0.1904, Train-MSE-0.0120, Train-L2-0.0740, Test-L2-1.4223
# Epoch-145, Time-0.1528, Train-MSE-0.0121, Train-L2-0.0746, Test-L2-1.4281
# Epoch-146, Time-0.1515, Train-MSE-0.0119, Train-L2-0.0675, Test-L2-1.4285
# Epoch-147, Time-0.1598, Train-MSE-0.0117, Train-L2-0.0726, Test-L2-1.4286
# Epoch-148, Time-0.1615, Train-MSE-0.0115, Train-L2-0.0659, Test-L2-1.4262
# Epoch-149, Time-0.1603, Train-MSE-0.0111, Train-L2-0.0761, Test-L2-1.4264
# Epoch-150, Time-0.1566, Train-MSE-0.0108, Train-L2-0.0730, Test-L2-1.4277
# Epoch-151, Time-0.1612, Train-MSE-0.0107, Train-L2-0.0684, Test-L2-1.4297
# Epoch-152, Time-0.1549, Train-MSE-0.0107, Train-L2-0.0660, Test-L2-1.4294
# Epoch-153, Time-0.1583, Train-MSE-0.0107, Train-L2-0.0675, Test-L2-1.4308
# Epoch-154, Time-0.1601, Train-MSE-0.0105, Train-L2-0.0624, Test-L2-1.4302
# Epoch-155, Time-0.1549, Train-MSE-0.0104, Train-L2-0.0623, Test-L2-1.4285
# Epoch-156, Time-0.1582, Train-MSE-0.0103, Train-L2-0.0625, Test-L2-1.4295
# Epoch-157, Time-0.1528, Train-MSE-0.0103, Train-L2-0.0618, Test-L2-1.4310
# Epoch-158, Time-0.1561, Train-MSE-0.0102, Train-L2-0.0616, Test-L2-1.4299
# Epoch-159, Time-0.1583, Train-MSE-0.0100, Train-L2-0.0593, Test-L2-1.4296
# Epoch-160, Time-0.1593, Train-MSE-0.0099, Train-L2-0.0590, Test-L2-1.4315
# Epoch-161, Time-0.1615, Train-MSE-0.0099, Train-L2-0.0593, Test-L2-1.4318
# Epoch-162, Time-0.1643, Train-MSE-0.0098, Train-L2-0.0597, Test-L2-1.4298
# Epoch-163, Time-0.1557, Train-MSE-0.0098, Train-L2-0.0589, Test-L2-1.4305
# Epoch-164, Time-0.1374, Train-MSE-0.0095, Train-L2-0.0605, Test-L2-1.4357
# Epoch-165, Time-0.1235, Train-MSE-0.0094, Train-L2-0.0590, Test-L2-1.4328
# Epoch-166, Time-0.1190, Train-MSE-0.0095, Train-L2-0.0621, Test-L2-1.4289
# Epoch-167, Time-0.1291, Train-MSE-0.0094, Train-L2-0.0600, Test-L2-1.4336
# Epoch-168, Time-0.1222, Train-MSE-0.0092, Train-L2-0.0584, Test-L2-1.4359
# Epoch-169, Time-0.1272, Train-MSE-0.0092, Train-L2-0.0638, Test-L2-1.4320
# Epoch-170, Time-0.1237, Train-MSE-0.0091, Train-L2-0.0635, Test-L2-1.4321
# Epoch-171, Time-0.1247, Train-MSE-0.0089, Train-L2-0.0576, Test-L2-1.4348
# Epoch-172, Time-0.1223, Train-MSE-0.0090, Train-L2-0.0627, Test-L2-1.4331
# Epoch-173, Time-0.1244, Train-MSE-0.0088, Train-L2-0.0620, Test-L2-1.4303
# Epoch-174, Time-0.1260, Train-MSE-0.0086, Train-L2-0.0637, Test-L2-1.4331
# Epoch-175, Time-0.1241, Train-MSE-0.0086, Train-L2-0.0578, Test-L2-1.4363
# Epoch-176, Time-0.1185, Train-MSE-0.0086, Train-L2-0.0618, Test-L2-1.4352
# Epoch-177, Time-0.1297, Train-MSE-0.0085, Train-L2-0.0585, Test-L2-1.4322
# Epoch-178, Time-0.1272, Train-MSE-0.0084, Train-L2-0.0574, Test-L2-1.4339
# Epoch-179, Time-0.1304, Train-MSE-0.0083, Train-L2-0.0577, Test-L2-1.4357
# Epoch-180, Time-0.1265, Train-MSE-0.0082, Train-L2-0.0566, Test-L2-1.4348
# Epoch-181, Time-0.1247, Train-MSE-0.0081, Train-L2-0.0551, Test-L2-1.4342
# Epoch-182, Time-0.1612, Train-MSE-0.0081, Train-L2-0.0538, Test-L2-1.4365
# Epoch-183, Time-0.1646, Train-MSE-0.0079, Train-L2-0.0537, Test-L2-1.4352
# Epoch-184, Time-0.1517, Train-MSE-0.0079, Train-L2-0.0542, Test-L2-1.4346
# Epoch-185, Time-0.1578, Train-MSE-0.0078, Train-L2-0.0529, Test-L2-1.4372
# Epoch-186, Time-0.1511, Train-MSE-0.0078, Train-L2-0.0528, Test-L2-1.4354
# Epoch-187, Time-0.1521, Train-MSE-0.0078, Train-L2-0.0531, Test-L2-1.4356
# Epoch-188, Time-0.1622, Train-MSE-0.0076, Train-L2-0.0520, Test-L2-1.4373
# Epoch-189, Time-0.1546, Train-MSE-0.0075, Train-L2-0.0517, Test-L2-1.4366
# Epoch-190, Time-0.1496, Train-MSE-0.0075, Train-L2-0.0511, Test-L2-1.4361
# Epoch-191, Time-0.1639, Train-MSE-0.0074, Train-L2-0.0500, Test-L2-1.4372
# Epoch-192, Time-0.1599, Train-MSE-0.0074, Train-L2-0.0495, Test-L2-1.4360
# Epoch-193, Time-0.1659, Train-MSE-0.0073, Train-L2-0.0516, Test-L2-1.4393
# Epoch-194, Time-0.1612, Train-MSE-0.0072, Train-L2-0.0523, Test-L2-1.4378
# Epoch-195, Time-0.1664, Train-MSE-0.0071, Train-L2-0.0536, Test-L2-1.4343
# Epoch-196, Time-0.1740, Train-MSE-0.0071, Train-L2-0.0528, Test-L2-1.4392
# Epoch-197, Time-0.1700, Train-MSE-0.0071, Train-L2-0.0568, Test-L2-1.4414
# Epoch-198, Time-0.1600, Train-MSE-0.0070, Train-L2-0.0532, Test-L2-1.4355
# Epoch-199, Time-0.1513, Train-MSE-0.0070, Train-L2-0.0559, Test-L2-1.4335
# Epoch-200, Time-0.1467, Train-MSE-0.0069, Train-L2-0.0513, Test-L2-1.4378
# Epoch-201, Time-0.1467, Train-MSE-0.0068, Train-L2-0.0491, Test-L2-1.4414
# Epoch-202, Time-0.1551, Train-MSE-0.0067, Train-L2-0.0524, Test-L2-1.4409
# Epoch-203, Time-0.1505, Train-MSE-0.0067, Train-L2-0.0500, Test-L2-1.4369
# Epoch-204, Time-0.1465, Train-MSE-0.0067, Train-L2-0.0483, Test-L2-1.4349
# Epoch-205, Time-0.1473, Train-MSE-0.0067, Train-L2-0.0506, Test-L2-1.4384
# Epoch-206, Time-0.1542, Train-MSE-0.0066, Train-L2-0.0478, Test-L2-1.4414
# Epoch-207, Time-0.1616, Train-MSE-0.0066, Train-L2-0.0487, Test-L2-1.4417
# Epoch-208, Time-0.1574, Train-MSE-0.0065, Train-L2-0.0480, Test-L2-1.4381
# Epoch-209, Time-0.1613, Train-MSE-0.0066, Train-L2-0.0473, Test-L2-1.4369
# Epoch-210, Time-0.1633, Train-MSE-0.0065, Train-L2-0.0493, Test-L2-1.4395
# Epoch-211, Time-0.1407, Train-MSE-0.0065, Train-L2-0.0475, Test-L2-1.4405
# Epoch-212, Time-0.1251, Train-MSE-0.0065, Train-L2-0.0471, Test-L2-1.4400
# Epoch-213, Time-0.1262, Train-MSE-0.0064, Train-L2-0.0465, Test-L2-1.4383
# Epoch-214, Time-0.1313, Train-MSE-0.0064, Train-L2-0.0478, Test-L2-1.4389
# Epoch-215, Time-0.1285, Train-MSE-0.0063, Train-L2-0.0471, Test-L2-1.4416
# Epoch-216, Time-0.1297, Train-MSE-0.0063, Train-L2-0.0468, Test-L2-1.4403
# Epoch-217, Time-0.1277, Train-MSE-0.0064, Train-L2-0.0486, Test-L2-1.4378
# Epoch-218, Time-0.1301, Train-MSE-0.0063, Train-L2-0.0459, Test-L2-1.4404
# Epoch-219, Time-0.1301, Train-MSE-0.0062, Train-L2-0.0484, Test-L2-1.4417
# Epoch-220, Time-0.1239, Train-MSE-0.0062, Train-L2-0.0481, Test-L2-1.4402
# Epoch-221, Time-0.1268, Train-MSE-0.0062, Train-L2-0.0470, Test-L2-1.4405
# Epoch-222, Time-0.1354, Train-MSE-0.0062, Train-L2-0.0484, Test-L2-1.4403
# Epoch-223, Time-0.1426, Train-MSE-0.0061, Train-L2-0.0461, Test-L2-1.4400
# Epoch-224, Time-0.1250, Train-MSE-0.0062, Train-L2-0.0474, Test-L2-1.4393
# Epoch-225, Time-0.1229, Train-MSE-0.0061, Train-L2-0.0454, Test-L2-1.4391
# Epoch-226, Time-0.1266, Train-MSE-0.0060, Train-L2-0.0499, Test-L2-1.4404
# Epoch-227, Time-0.1329, Train-MSE-0.0060, Train-L2-0.0477, Test-L2-1.4410
# Epoch-228, Time-0.1343, Train-MSE-0.0060, Train-L2-0.0459, Test-L2-1.4410
# Epoch-229, Time-0.1319, Train-MSE-0.0060, Train-L2-0.0487, Test-L2-1.4411
# Epoch-230, Time-0.1266, Train-MSE-0.0059, Train-L2-0.0461, Test-L2-1.4391
# Epoch-231, Time-0.1318, Train-MSE-0.0059, Train-L2-0.0447, Test-L2-1.4404
# Epoch-232, Time-0.1270, Train-MSE-0.0059, Train-L2-0.0443, Test-L2-1.4429
# Epoch-233, Time-0.1379, Train-MSE-0.0058, Train-L2-0.0448, Test-L2-1.4410
# Epoch-234, Time-0.1312, Train-MSE-0.0059, Train-L2-0.0447, Test-L2-1.4387
# Epoch-235, Time-0.1227, Train-MSE-0.0058, Train-L2-0.0438, Test-L2-1.4418
# Epoch-236, Time-0.1258, Train-MSE-0.0058, Train-L2-0.0435, Test-L2-1.4428
# Epoch-237, Time-0.1293, Train-MSE-0.0057, Train-L2-0.0435, Test-L2-1.4403
# Epoch-238, Time-0.1354, Train-MSE-0.0057, Train-L2-0.0439, Test-L2-1.4406
# Epoch-239, Time-0.1250, Train-MSE-0.0057, Train-L2-0.0435, Test-L2-1.4421
# Epoch-240, Time-0.1261, Train-MSE-0.0057, Train-L2-0.0428, Test-L2-1.4414
# Epoch-241, Time-0.1265, Train-MSE-0.0057, Train-L2-0.0424, Test-L2-1.4410
# Epoch-242, Time-0.1244, Train-MSE-0.0056, Train-L2-0.0426, Test-L2-1.4409
# Epoch-243, Time-0.1412, Train-MSE-0.0056, Train-L2-0.0428, Test-L2-1.4423
# Epoch-244, Time-0.1576, Train-MSE-0.0056, Train-L2-0.0430, Test-L2-1.4417
# Epoch-245, Time-0.1598, Train-MSE-0.0056, Train-L2-0.0418, Test-L2-1.4414
# Epoch-246, Time-0.1502, Train-MSE-0.0055, Train-L2-0.0422, Test-L2-1.4419
# Epoch-247, Time-0.1352, Train-MSE-0.0055, Train-L2-0.0418, Test-L2-1.4414
# Epoch-248, Time-0.1374, Train-MSE-0.0055, Train-L2-0.0428, Test-L2-1.4417
# Epoch-249, Time-0.1306, Train-MSE-0.0054, Train-L2-0.0414, Test-L2-1.4420
# Epoch-250, Time-0.1280, Train-MSE-0.0054, Train-L2-0.0416, Test-L2-1.4419
# Epoch-251, Time-0.1288, Train-MSE-0.0054, Train-L2-0.0412, Test-L2-1.4417
# Epoch-252, Time-0.1295, Train-MSE-0.0054, Train-L2-0.0412, Test-L2-1.4419
# Epoch-253, Time-0.1275, Train-MSE-0.0054, Train-L2-0.0411, Test-L2-1.4420
# Epoch-254, Time-0.1250, Train-MSE-0.0054, Train-L2-0.0409, Test-L2-1.4420
# Epoch-255, Time-0.1253, Train-MSE-0.0054, Train-L2-0.0408, Test-L2-1.4421
# Epoch-256, Time-0.1282, Train-MSE-0.0054, Train-L2-0.0407, Test-L2-1.4421
# Epoch-257, Time-0.1252, Train-MSE-0.0054, Train-L2-0.0407, Test-L2-1.4420
# Epoch-258, Time-0.1328, Train-MSE-0.0053, Train-L2-0.0406, Test-L2-1.4422
# Epoch-259, Time-0.1589, Train-MSE-0.0053, Train-L2-0.0408, Test-L2-1.4423
# Epoch-260, Time-0.1528, Train-MSE-0.0053, Train-L2-0.0405, Test-L2-1.4420
# Epoch-261, Time-0.1234, Train-MSE-0.0053, Train-L2-0.0405, Test-L2-1.4421
# Epoch-262, Time-0.1261, Train-MSE-0.0053, Train-L2-0.0404, Test-L2-1.4424
# Epoch-263, Time-0.1274, Train-MSE-0.0053, Train-L2-0.0407, Test-L2-1.4424
# Epoch-264, Time-0.1214, Train-MSE-0.0053, Train-L2-0.0403, Test-L2-1.4421
# Epoch-265, Time-0.1293, Train-MSE-0.0053, Train-L2-0.0403, Test-L2-1.4425
# Epoch-266, Time-0.1337, Train-MSE-0.0052, Train-L2-0.0402, Test-L2-1.4426
# Epoch-267, Time-0.1530, Train-MSE-0.0052, Train-L2-0.0400, Test-L2-1.4423
# Epoch-268, Time-0.1619, Train-MSE-0.0052, Train-L2-0.0401, Test-L2-1.4423
# Epoch-269, Time-0.1573, Train-MSE-0.0052, Train-L2-0.0399, Test-L2-1.4427
# Epoch-270, Time-0.1604, Train-MSE-0.0052, Train-L2-0.0400, Test-L2-1.4427
# Epoch-271, Time-0.1492, Train-MSE-0.0052, Train-L2-0.0400, Test-L2-1.4425
# Epoch-272, Time-0.1549, Train-MSE-0.0052, Train-L2-0.0399, Test-L2-1.4426
# Epoch-273, Time-0.1571, Train-MSE-0.0051, Train-L2-0.0400, Test-L2-1.4428
# Epoch-274, Time-0.1601, Train-MSE-0.0052, Train-L2-0.0401, Test-L2-1.4428
# Epoch-275, Time-0.1620, Train-MSE-0.0051, Train-L2-0.0399, Test-L2-1.4429
# Epoch-276, Time-0.1704, Train-MSE-0.0051, Train-L2-0.0397, Test-L2-1.4425
# Epoch-277, Time-0.1601, Train-MSE-0.0051, Train-L2-0.0400, Test-L2-1.4429
# Epoch-278, Time-0.1494, Train-MSE-0.0051, Train-L2-0.0398, Test-L2-1.4433
# Epoch-279, Time-0.1559, Train-MSE-0.0051, Train-L2-0.0401, Test-L2-1.4429
# Epoch-280, Time-0.1496, Train-MSE-0.0051, Train-L2-0.0400, Test-L2-1.4426
# Epoch-281, Time-0.1542, Train-MSE-0.0051, Train-L2-0.0396, Test-L2-1.4429
# Epoch-282, Time-0.1501, Train-MSE-0.0050, Train-L2-0.0397, Test-L2-1.4430
# Epoch-283, Time-0.1584, Train-MSE-0.0050, Train-L2-0.0393, Test-L2-1.4432
# Epoch-284, Time-0.1567, Train-MSE-0.0050, Train-L2-0.0396, Test-L2-1.4430
# Epoch-285, Time-0.1535, Train-MSE-0.0050, Train-L2-0.0392, Test-L2-1.4429
# Epoch-286, Time-0.1571, Train-MSE-0.0050, Train-L2-0.0392, Test-L2-1.4430
# Epoch-287, Time-0.1600, Train-MSE-0.0050, Train-L2-0.0393, Test-L2-1.4435
# Epoch-288, Time-0.1547, Train-MSE-0.0050, Train-L2-0.0391, Test-L2-1.4434
# Epoch-289, Time-0.1477, Train-MSE-0.0050, Train-L2-0.0392, Test-L2-1.4431
# Epoch-290, Time-0.1572, Train-MSE-0.0049, Train-L2-0.0389, Test-L2-1.4433
# Epoch-291, Time-0.1551, Train-MSE-0.0049, Train-L2-0.0390, Test-L2-1.4434
# Epoch-292, Time-0.1600, Train-MSE-0.0049, Train-L2-0.0388, Test-L2-1.4434
# Epoch-293, Time-0.1626, Train-MSE-0.0049, Train-L2-0.0393, Test-L2-1.4436
# Epoch-294, Time-0.1542, Train-MSE-0.0049, Train-L2-0.0390, Test-L2-1.4430
# Epoch-295, Time-0.1497, Train-MSE-0.0049, Train-L2-0.0389, Test-L2-1.4434
# Epoch-296, Time-0.1585, Train-MSE-0.0049, Train-L2-0.0388, Test-L2-1.4440
# Epoch-297, Time-0.1667, Train-MSE-0.0049, Train-L2-0.0388, Test-L2-1.4437
# Epoch-298, Time-0.1605, Train-MSE-0.0049, Train-L2-0.0386, Test-L2-1.4429
# Epoch-299, Time-0.1625, Train-MSE-0.0049, Train-L2-0.0385, Test-L2-1.4433
# Epoch-300, Time-0.1636, Train-MSE-0.0048, Train-L2-0.0384, Test-L2-1.4437
# Epoch-301, Time-0.1597, Train-MSE-0.0048, Train-L2-0.0382, Test-L2-1.4439
# Epoch-302, Time-0.1612, Train-MSE-0.0048, Train-L2-0.0382, Test-L2-1.4437
# Epoch-303, Time-0.1566, Train-MSE-0.0048, Train-L2-0.0382, Test-L2-1.4436
# Epoch-304, Time-0.1585, Train-MSE-0.0048, Train-L2-0.0382, Test-L2-1.4435
# Epoch-305, Time-0.1566, Train-MSE-0.0048, Train-L2-0.0381, Test-L2-1.4436
# Epoch-306, Time-0.1596, Train-MSE-0.0048, Train-L2-0.0380, Test-L2-1.4437
# Epoch-307, Time-0.1485, Train-MSE-0.0048, Train-L2-0.0380, Test-L2-1.4438
# Epoch-308, Time-0.1528, Train-MSE-0.0048, Train-L2-0.0380, Test-L2-1.4437
# Epoch-309, Time-0.1567, Train-MSE-0.0048, Train-L2-0.0379, Test-L2-1.4436
# Epoch-310, Time-0.1585, Train-MSE-0.0048, Train-L2-0.0379, Test-L2-1.4437
# Epoch-311, Time-0.1516, Train-MSE-0.0048, Train-L2-0.0379, Test-L2-1.4438
# Epoch-312, Time-0.1646, Train-MSE-0.0048, Train-L2-0.0378, Test-L2-1.4439
# Epoch-313, Time-0.1511, Train-MSE-0.0048, Train-L2-0.0378, Test-L2-1.4438
# Epoch-314, Time-0.1524, Train-MSE-0.0047, Train-L2-0.0378, Test-L2-1.4437
# Epoch-315, Time-0.1690, Train-MSE-0.0047, Train-L2-0.0378, Test-L2-1.4438
# Epoch-316, Time-0.1784, Train-MSE-0.0047, Train-L2-0.0377, Test-L2-1.4438
# Epoch-317, Time-0.1689, Train-MSE-0.0047, Train-L2-0.0377, Test-L2-1.4439
# Epoch-318, Time-0.1576, Train-MSE-0.0047, Train-L2-0.0377, Test-L2-1.4439
# Epoch-319, Time-0.1589, Train-MSE-0.0047, Train-L2-0.0377, Test-L2-1.4439
# Epoch-320, Time-0.1628, Train-MSE-0.0047, Train-L2-0.0376, Test-L2-1.4438
# Epoch-321, Time-0.1547, Train-MSE-0.0047, Train-L2-0.0376, Test-L2-1.4438
# Epoch-322, Time-0.1498, Train-MSE-0.0047, Train-L2-0.0376, Test-L2-1.4440
# Epoch-323, Time-0.1463, Train-MSE-0.0047, Train-L2-0.0375, Test-L2-1.4440
# Epoch-324, Time-0.1478, Train-MSE-0.0047, Train-L2-0.0375, Test-L2-1.4440
# Epoch-325, Time-0.1606, Train-MSE-0.0047, Train-L2-0.0375, Test-L2-1.4439
# Epoch-326, Time-0.1599, Train-MSE-0.0047, Train-L2-0.0374, Test-L2-1.4439
# Epoch-327, Time-0.1533, Train-MSE-0.0047, Train-L2-0.0374, Test-L2-1.4441
# Epoch-328, Time-0.1642, Train-MSE-0.0047, Train-L2-0.0374, Test-L2-1.4441
# Epoch-329, Time-0.1755, Train-MSE-0.0047, Train-L2-0.0374, Test-L2-1.4440
# Epoch-330, Time-0.1621, Train-MSE-0.0047, Train-L2-0.0373, Test-L2-1.4440
# Epoch-331, Time-0.1712, Train-MSE-0.0046, Train-L2-0.0373, Test-L2-1.4440
# Epoch-332, Time-0.1680, Train-MSE-0.0046, Train-L2-0.0373, Test-L2-1.4441
# Epoch-333, Time-0.1719, Train-MSE-0.0046, Train-L2-0.0372, Test-L2-1.4441
# Epoch-334, Time-0.1600, Train-MSE-0.0046, Train-L2-0.0372, Test-L2-1.4440
# Epoch-335, Time-0.1634, Train-MSE-0.0046, Train-L2-0.0372, Test-L2-1.4440
# Epoch-336, Time-0.1634, Train-MSE-0.0046, Train-L2-0.0371, Test-L2-1.4442
# Epoch-337, Time-0.1531, Train-MSE-0.0046, Train-L2-0.0371, Test-L2-1.4442
# Epoch-338, Time-0.1618, Train-MSE-0.0046, Train-L2-0.0371, Test-L2-1.4442
# Epoch-339, Time-0.1607, Train-MSE-0.0046, Train-L2-0.0371, Test-L2-1.4441
# Epoch-340, Time-0.1642, Train-MSE-0.0046, Train-L2-0.0370, Test-L2-1.4441
# Epoch-341, Time-0.1623, Train-MSE-0.0046, Train-L2-0.0370, Test-L2-1.4442
# Epoch-342, Time-0.1846, Train-MSE-0.0046, Train-L2-0.0370, Test-L2-1.4443
# Epoch-343, Time-0.1667, Train-MSE-0.0046, Train-L2-0.0369, Test-L2-1.4443
# Epoch-344, Time-0.1550, Train-MSE-0.0046, Train-L2-0.0369, Test-L2-1.4442
# Epoch-345, Time-0.1652, Train-MSE-0.0046, Train-L2-0.0369, Test-L2-1.4442
# Epoch-346, Time-0.1700, Train-MSE-0.0046, Train-L2-0.0369, Test-L2-1.4443
# Epoch-347, Time-0.1647, Train-MSE-0.0045, Train-L2-0.0368, Test-L2-1.4444
# Epoch-348, Time-0.1595, Train-MSE-0.0045, Train-L2-0.0368, Test-L2-1.4444
# Epoch-349, Time-0.1545, Train-MSE-0.0045, Train-L2-0.0368, Test-L2-1.4444
# Epoch-350, Time-0.1804, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4443
# Epoch-351, Time-0.1591, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4443
# Epoch-352, Time-0.1651, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4443
# Epoch-353, Time-0.1634, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4444
# Epoch-354, Time-0.1609, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4444
# Epoch-355, Time-0.1572, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4444
# Epoch-356, Time-0.1681, Train-MSE-0.0045, Train-L2-0.0367, Test-L2-1.4444
# Epoch-357, Time-0.1603, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-358, Time-0.1556, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-359, Time-0.1533, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-360, Time-0.1579, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-361, Time-0.1585, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-362, Time-0.1559, Train-MSE-0.0045, Train-L2-0.0366, Test-L2-1.4444
# Epoch-363, Time-0.1637, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4444
# Epoch-364, Time-0.1543, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4444
# Epoch-365, Time-0.1460, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4445
# Epoch-366, Time-0.1595, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4445
# Epoch-367, Time-0.1579, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4445
# Epoch-368, Time-0.1585, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4445
# Epoch-369, Time-0.1499, Train-MSE-0.0045, Train-L2-0.0365, Test-L2-1.4445
# Epoch-370, Time-0.1631, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-371, Time-0.1628, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-372, Time-0.1584, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-373, Time-0.1609, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-374, Time-0.1556, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-375, Time-0.1533, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-376, Time-0.1586, Train-MSE-0.0045, Train-L2-0.0364, Test-L2-1.4445
# Epoch-377, Time-0.1551, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-378, Time-0.1595, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-379, Time-0.1615, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-380, Time-0.1663, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-381, Time-0.1568, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-382, Time-0.1587, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-383, Time-0.1504, Train-MSE-0.0044, Train-L2-0.0363, Test-L2-1.4446
# Epoch-384, Time-0.1623, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4446
# Epoch-385, Time-0.1626, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4447
# Epoch-386, Time-0.1642, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4447
# Epoch-387, Time-0.1711, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4446
# Epoch-388, Time-0.1679, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4446
# Epoch-389, Time-0.1465, Train-MSE-0.0044, Train-L2-0.0362, Test-L2-1.4446
# Epoch-390, Time-0.1692, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4446
# Epoch-391, Time-0.1646, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-392, Time-0.1589, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-393, Time-0.1710, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-394, Time-0.1626, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-395, Time-0.1628, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-396, Time-0.1703, Train-MSE-0.0044, Train-L2-0.0361, Test-L2-1.4447
# Epoch-397, Time-0.1648, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-398, Time-0.1643, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-399, Time-0.1639, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-400, Time-0.1579, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4448
# Epoch-401, Time-0.1545, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4448
# Epoch-402, Time-0.1588, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-403, Time-0.1369, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-404, Time-0.1256, Train-MSE-0.0044, Train-L2-0.0360, Test-L2-1.4447
# Epoch-405, Time-0.1242, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4447
# Epoch-406, Time-0.1279, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-407, Time-0.1197, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-408, Time-0.1254, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-409, Time-0.1270, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-410, Time-0.1467, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-411, Time-0.1529, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-412, Time-0.1575, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-413, Time-0.1559, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-414, Time-0.1581, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-415, Time-0.1505, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-416, Time-0.1634, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-417, Time-0.1634, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-418, Time-0.1619, Train-MSE-0.0044, Train-L2-0.0359, Test-L2-1.4448
# Epoch-419, Time-0.1572, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-420, Time-0.1505, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-421, Time-0.1623, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-422, Time-0.1603, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-423, Time-0.1563, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-424, Time-0.1540, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-425, Time-0.1519, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-426, Time-0.1508, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-427, Time-0.1538, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-428, Time-0.1596, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4449
# Epoch-429, Time-0.1642, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4449
# Epoch-430, Time-0.1491, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4448
# Epoch-431, Time-0.1476, Train-MSE-0.0043, Train-L2-0.0358, Test-L2-1.4449
# Epoch-432, Time-0.1501, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-433, Time-0.1528, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-434, Time-0.1588, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-435, Time-0.1592, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-436, Time-0.1590, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-437, Time-0.1607, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-438, Time-0.1646, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-439, Time-0.1570, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-440, Time-0.1566, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-441, Time-0.1537, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-442, Time-0.1599, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-443, Time-0.1589, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-444, Time-0.1393, Train-MSE-0.0043, Train-L2-0.0357, Test-L2-1.4449
# Epoch-445, Time-0.1248, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-446, Time-0.1223, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-447, Time-0.1185, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-448, Time-0.1230, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-449, Time-0.1253, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-450, Time-0.1292, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-451, Time-0.1354, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-452, Time-0.1337, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-453, Time-0.1318, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-454, Time-0.1408, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-455, Time-0.1318, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4449
# Epoch-456, Time-0.1288, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-457, Time-0.1379, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-458, Time-0.1289, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-459, Time-0.1238, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-460, Time-0.1283, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-461, Time-0.1255, Train-MSE-0.0043, Train-L2-0.0356, Test-L2-1.4450
# Epoch-462, Time-0.1265, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-463, Time-0.1286, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-464, Time-0.1250, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-465, Time-0.1240, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-466, Time-0.1250, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-467, Time-0.1277, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-468, Time-0.1341, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-469, Time-0.1245, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-470, Time-0.1220, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-471, Time-0.1257, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-472, Time-0.1484, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-473, Time-0.1650, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-474, Time-0.1614, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-475, Time-0.1589, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-476, Time-0.1602, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-477, Time-0.1588, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-478, Time-0.1689, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-479, Time-0.1614, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-480, Time-0.1491, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-481, Time-0.1481, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-482, Time-0.1564, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-483, Time-0.1589, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-484, Time-0.1616, Train-MSE-0.0043, Train-L2-0.0355, Test-L2-1.4450
# Epoch-485, Time-0.1600, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-486, Time-0.1662, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-487, Time-0.1487, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-488, Time-0.1637, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-489, Time-0.1574, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-490, Time-0.1293, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4451
# Epoch-491, Time-0.1208, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4451
# Epoch-492, Time-0.1242, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-493, Time-0.1254, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-494, Time-0.1232, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-495, Time-0.1237, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-496, Time-0.1231, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4450
# Epoch-497, Time-0.1248, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4451
# Epoch-498, Time-0.1277, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4451
# Epoch-499, Time-0.1242, Train-MSE-0.0043, Train-L2-0.0354, Test-L2-1.4451

# %%
# Save the HF-WNO model

torch.save(model_hf, 'model/HF_WNO_poisson1D_10')

# %%
# Prediction:
pred_hf = []
with torch.no_grad():
    index = 0
    for x, y in test_loader_mf:
        test_l2 = 0 
        x, y = x.to(device), y.to(device)

        out = model_hf(x[:,:,0:1]).squeeze(-1)
        test_l2 = myloss(out.view(batch_size, -1), y.view(batch_size, -1)).item()
        pred_hf.append( out.cpu() )
        print("Batch-{}, Test-loss-{:0.6f}".format( index, test_l2 ))
        index += 1

pred_hf = torch.cat(( pred_hf ))
# print('Mean mse_mf-{}'.format(F.mse_loss(y_test_hf, pred_hf).item()))

# %%
inp = x_test_mf
real_hf = y_test_mf + inp[:,:,1] 
output_hf = pred_hf

# %%
mse_pred_hf = F.mse_loss(output_hf, real_hf).item()

print('MSE-Predicted solution-{:0.4f}'.format(mse_pred_hf))

# %%
plt.rcParams['font.family'] = 'Times New Roman' 
plt.rcParams['font.size'] = 12
plt.rcParams['mathtext.fontset'] = 'dejavuserif'

colormap = plt.cm.jet  
colors = [colormap(i) for i in np.linspace(0, 1, 5)]

fig2 = plt.figure(figsize = (10, 4), dpi=300)
fig2.suptitle('Stochastic Heat - FNO - High fidelity')

index = 0
for i in range(ntest):
    if i % 10 == 1:
        plt.plot(x_coords, real_hf[i, :], color=colors[index], label='Actual')
        plt.plot(x_coords, output_hf[i,:], '--', color=colors[index], label='Prediction')
        index += 1
plt.legend(ncol=4, loc=4, labelspacing=0.25, columnspacing=0.25, handletextpad=0.5, handlelength=1)
plt.grid(True)
plt.margins(0)

# %%
fig5, axs = plt.subplots(2, 2,figsize=(18,10), dpi=100)
plt.subplots_adjust(wspace=0.25)

n0 = 15
axs[0, 0].plot(x_coords,real_mf[n0], linestyle='-', color='tab:green', lw=2)
axs[0, 0].plot(x_coords,inp_mf[n0,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 0].plot(x_coords,output_hf[n0], linestyle='-.', color='tab:orange', lw=2)
axs[0, 0].plot(x_coords,output_mf[n0], linestyle='--', color='tab:red', lw=3)
axs[0, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 0].margins(0)
axs[0, 0].grid(True, alpha=0.3)

n1 = 28
axs[0, 1].plot(x_coords,real_mf[n1], linestyle='-', color='tab:green', lw=2)
axs[0, 1].plot(x_coords,inp_mf[n1,:,0], linestyle=':', color='tab:blue', lw=2)
axs[0, 1].plot(x_coords,output_hf[n1], linestyle='-.', color='tab:orange', lw=2)
axs[0, 1].plot(x_coords,output_mf[n1], linestyle='--', color='tab:red', lw=3)
axs[0, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[0, 1].margins(0)
axs[0, 1].grid(True, alpha=0.3)

n2 = 37
axs[1, 0].plot(x_coords,real_mf[n2], linestyle='-', color='tab:green', lw=2)
axs[1, 0].plot(x_coords,inp_mf[n2,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 0].plot(x_coords,output_hf[n2], linestyle='-.', color='tab:orange', lw=2)
axs[1, 0].plot(x_coords,output_mf[n2], linestyle='--', color='tab:red', lw=3)
axs[1, 0].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 0].margins(0)
axs[1, 0].grid(True, alpha=0.3)

n3 = 38
axs[1, 1].plot(x_coords,real_mf[n3], linestyle='-', color='tab:green', lw=2)
axs[1, 1].plot(x_coords,inp_mf[n3,:,0], linestyle=':', color='tab:blue', lw=2)
axs[1, 1].plot(x_coords,output_hf[n3], linestyle='-.', color='tab:orange', lw=2)
axs[1, 1].plot(x_coords,output_mf[n3], linestyle='--', color='tab:red', lw=3)
axs[1, 1].legend(['HF-Truth','LF-WNO','HF-WNO','MF-WNO'])
axs[1, 1].margins(0)
axs[1, 1].grid(True, alpha=0.3)
